# %% [markdown]
# <!-- Google Fonts -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 20px;
#     background: linear-gradient(125deg, #d73027 7%, #fdae61 47%, #a6d96a 85%, #1a9850 100%);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         🏢 IBM HR Analytics Employee Attrition
#     </h1>
# </div>

# %% [markdown]
# ## 📂 Dataset Overview
#
# Attrition in a company is the situation where employees leave their jobs for voluntary or involuntary reasons, which can be due to retirement, resignation or termination of contract, or when a company decides to make a position redundant. Attrition affects the performance of teams, the quality of output, and increases recruitment and training costs. In this project, the group will focus on finding out what causes attrition in the company.
#
# In this project, I analyze the IBM HR Analytics Employee Attrition & Performance dataset to explore factors associated with employee turnover. Through exploratory data analysis and machine learning algorithms, I build predictive models to identify employees likely to leave, helping organizations take proactive measures to improve retention.
#
# **Key Features**
#
# **1. Age:** Age of the employee in numeric.<br>
# **2. Attrition:** Attrition of employee categorical : Yes/ No.<br>
# **3. BusinessTravel:** It is a categorical column about employee business travel : Travel Frequently/ Rarely Travel/ Non- Travel.<br>
# **4. DailyRate:** It is a numerical column signify daily working rate of employee.<br>
# **5. Department:** It is a categorical column signify employee"s working department.<br>
# **6. DistanceFromHome:** It is a numerical column signify total distance of employee"s home from office.<br>
# **7. Education:** It is a categorical column signify level of employee"s education : (1 "Below College", 2 "College", 3 "Bachelor", 4 "Master", 5 "Doctor")<br>
# **8. EducationField:** It is a categorical column signify education field of employees.<br>
# **9. EmployeeCount:** Number of employees in numerical. It has only one unique value i.e., 1<br>
# **10. EmployeeNumber:** It is a unique numerical Id assigned to every employee.<br>
# **11. EnvironmentSatisfaction:** It is a categorical column having following values : (1 "Low", 2 "Medium", 3 "High", 4 "Very High")<br>
# **12. Gender:** It is a categorical column having only 2 values Male and female.<br>
# **13. HourlyRate:** It is a numerical column signify hourly working rate of employee.<br>
# **14. JobInvolvement:** It is a categorical column having following values : (1 "Low", 2 "Medium", 3 "High", 4 "Very High")<br>
# **15. JobLevel:** It is a categorical column signify level of job i.e., 1,2,3,4 and 5<br>
# **16. JobRole:** It is a categorical column signifying role of employee i.e., sales executive, research scientists etc.<br>
# **17. JobSatisfaction:** It signifies how satisfied an employee is with the job : (1 "Low", 2 "Medium", 3 "High", 4 "Very High")<br>
# **18. MaritalStatus:** It is a categorical column signifies marital status of employee i.e., Married, Single, Divorced etc.<br>
# **19. MonthlyIncome:** It is a numerical column signify monthly income of the employee.<br>
# **20. MonthlyRate:** It is a numerical column signify monthly rate of working by employee.<br>
# **21. NumCompaniesWorked:** It is a numerical column signify number of companies an employee previously worked for.<br>
# **22. Over18:** It is a boolean field signify whether employee age is over 18 or not.<br>
# **23. OverTime:** It is a boolean field signify whether employee work overtime or not.<br>
# **24. PercentSalaryHike:** It is a numerical column signify percentage of hike received recently by an employee.<br>
# **25. PerformanceRating:** It is a categorical column signify performance rating of employee (1 "Low", 2 "Good",
# 3 "Excellent", 4 "Outstanding")<br>
# **26. RelationshipSatisfaction:** It is a categorical column signify relationship bonding status with co workers
# (1 "Low",2 "Medium",3 "High",4 "Very High")<br>
# **27. StandardHours:** It is a numerical column signify standard working hours of employees.<br>
# **28. StockOptionLevel:** It is a categorical column. It has four categories 0, 1, 2 and 3 <br>
# **29. TotalWorkingYears:** It is a numerical column signify total working years of employees. <br>
# **30. TrainingTimesLastYear:** It is a numerical column signify total number of times employee got training. <br>
# **31. WorkLifeBalance:** It is a categorical column signify work life balance (1 "Bad",2 "Good",3 "Better",4 "Best")<br>
# **32. YearsAtCompany:** It is a numerical column signify total number of years spent by employee in current company.<br>
# **33. YearsInCurrentRole:** It is a numerical column signify total number of years spent by employee in current job role in current company.<br>
# **34. YearsSinceLastPromotion:** It is a numerical column signify total number of years since last promotion of employee in current company.<br>
# **35. YearsWithCurrManager:** It is a numerical column signify total number of years employee work under current manager in current company.<br>
#
# **Files Provided**
#
# * `WA_Fn-UseC_-HR-Employee-Attrition.csv` (1470 samples): Contains all features (sources: [Kaggle Dataset](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset))
#
# **Project Objective**
#
# The primary objective of this notebook is to **build machine learning model to predict and EDA**.
#
# Key components of the approach include:
#
# * **Exploratory Data Analysis (EDA):** Understand feature distributions, relationships.
# * **Feature Engineering:** Encode categorical variables and align schema across training and test data.
# * **Modeling:** Train an ensemble model with hyperparameters tuned.
# * **Multi-Label Prediction Strategy:** Generate predictions for each test row.
# * **Evaluation Framework:** <br>
#   * Cross-validation.
#   * Metrics: Accuracy

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Import Libraries
#     </h1>
# </div>

# %%
# Core data manipulation libraries
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import shap

# Statistical functions
from scipy.stats import skew, kurtosis, probplot

# Display utilities for Jupyter notebooks
from IPython.display import display, HTML

# Machine learning preprocessing and modeling
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import confusion_matrix

import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Metrics
from sklearn.metrics import (roc_curve, roc_auc_score, confusion_matrix,
                             precision_recall_curve, average_precision_score, auc, classification_report)

# Statistical
from scipy.stats import chi2_contingency
from scipy.stats import probplot
from scipy.stats import kruskal
import scikit_posthocs as sp
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.formula.api as smf
from scipy.stats import levene
from scipy import stats
import pingouin as pg
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu

# Suppress warnings for cleaner output
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 500) # To display all the columns of dataframe
pd.set_option("max_colwidth", None) # To set the width of the column to maximum

# %%
class Config:
    seed = 42
    max_iter = 50000
    n_split_shuffle = 1
    n_split_kfold = 5
    test_size = 0.2
    data = "WA_Fn-UseC_-HR-Employee-Attrition.csv"
    target_feature = "Attrition"

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Load Data</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Load Data
#     </h1>
# </div>

# %%
# Load the datasets
df_HR_Attrition = pd.read_csv(Config.data)
# Verify shapes
print("[i] Data Shape:", df_HR_Attrition.shape)
# Out:
# [i] Data Shape: (1470, 35)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Data Preview and Info
#     </h1>
# </div>

# %%
# Display few rows of each dataset
print("[i] Data Preview:")
df_HR_Attrition.head()
# Out:
# [i] Data Preview:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
# As per the information "Key Feature" we will convert categorical numerically encoded columns into their categories
# WorkLifeBalance
choices_workLifeBalance = ["Bad", "Good", "Better", "Best"]
conditions = [
    (df_HR_Attrition["WorkLifeBalance"] == 1),
    (df_HR_Attrition["WorkLifeBalance"] == 2),
    (df_HR_Attrition["WorkLifeBalance"] == 3),
    (df_HR_Attrition["WorkLifeBalance"] == 4)
]
df_HR_Attrition["WorkLifeBalance"] = np.select(conditions, choices_workLifeBalance, default="Unknown")

# Education
choices_education = ["Below College", "College", "Bachelor", "Master", "Doctor"]
conditions = [
    (df_HR_Attrition["Education"] == 1),
    (df_HR_Attrition["Education"] == 2),
    (df_HR_Attrition["Education"] == 3),
    (df_HR_Attrition["Education"] == 4),
    (df_HR_Attrition["Education"] == 5)
]
df_HR_Attrition["Education"] = np.select(conditions, choices_education, default="Unknown")

# Environment Satisfaction
choices = ["Low", "Medium", "High", "Very High"]
conditions = [
    (df_HR_Attrition["EnvironmentSatisfaction"] == 1),
    (df_HR_Attrition["EnvironmentSatisfaction"] == 2),
    (df_HR_Attrition["EnvironmentSatisfaction"] == 3),
    (df_HR_Attrition["EnvironmentSatisfaction"] == 4)
]
df_HR_Attrition["EnvironmentSatisfaction"] = np.select(conditions, choices, default="Unknown")

# JobInvolvement
conditions = [
    (df_HR_Attrition["JobInvolvement"] == 1),
    (df_HR_Attrition["JobInvolvement"] == 2),
    (df_HR_Attrition["JobInvolvement"] == 3),
    (df_HR_Attrition["JobInvolvement"] == 4)
]
df_HR_Attrition["JobInvolvement"] = np.select(conditions, choices, default="Unknown")

# JobSatisfaction
conditions = [
    (df_HR_Attrition["JobSatisfaction"] == 1),
    (df_HR_Attrition["JobSatisfaction"] == 2),
    (df_HR_Attrition["JobSatisfaction"] == 3),
    (df_HR_Attrition["JobSatisfaction"] == 4)
]
df_HR_Attrition["JobSatisfaction"] = np.select(conditions, choices, default="Unknown")

# RelationshipSatisfaction
conditions = [
    (df_HR_Attrition["RelationshipSatisfaction"] == 1),
    (df_HR_Attrition["RelationshipSatisfaction"] == 2),
    (df_HR_Attrition["RelationshipSatisfaction"] == 3),
    (df_HR_Attrition["RelationshipSatisfaction"] == 4)
]
df_HR_Attrition["RelationshipSatisfaction"] = np.select(conditions, choices, default="Unknown")

# PerformanceRating
choices_performanceRating = ["Low", "Good", "Excellent", "Outstanding"]
conditions = [
    (df_HR_Attrition["PerformanceRating"] == 1),
    (df_HR_Attrition["PerformanceRating"] == 2),
    (df_HR_Attrition["PerformanceRating"] == 3),
    (df_HR_Attrition["PerformanceRating"] == 4)
]
df_HR_Attrition["PerformanceRating"] = np.select(conditions, choices_performanceRating, default="Unknown")

# StockOptionLevel
choices_stockOptionLevel = ["Basic", "Standard", "Advanced", "Elite"]
conditions = [
    (df_HR_Attrition["StockOptionLevel"] == 0),
    (df_HR_Attrition["StockOptionLevel"] == 1),
    (df_HR_Attrition["StockOptionLevel"] == 2),
    (df_HR_Attrition["StockOptionLevel"] == 3)
]
df_HR_Attrition["StockOptionLevel"] = np.select(conditions, choices_stockOptionLevel, default="Unknown")

# Attrition
choices_attrition = [0, 1]
conditions = [
    (df_HR_Attrition["Attrition"] == "No"),
    (df_HR_Attrition["Attrition"] == "Yes")
]
df_HR_Attrition["Attrition"] = np.select(conditions, choices_attrition, default=-1)

# %%
# Display few rows of each dataset
print("[i] Data Preview:")
df_HR_Attrition.head()
# Out:
# [i] Data Preview:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 4                 2  Below College        Medical              1
#
#    EmployeeNumber EnvironmentSatisfaction  Gender  HourlyRate JobInvolvement  \
# ...

# %% [markdown]
# * There are three columns (`EmployeeCount`, `Over18` and `StandardHours`) which have only 1 unique value which will be of no use in prediction process. <br>
# * The `EmployeeNumber` column is typically a unique identifier used to distinguish employees in a dataset. However, in the context of data analysis or predictive modeling, this column does not provide useful information so we need to drop this column.

# %%
# We need to update the data for the columns, this helps to reduce memory.
df_HR_Attrition = df_HR_Attrition.astype({
    "Age": "int8",
    "Attrition": "int8",
    "DailyRate": "int16",
    "EmployeeCount": "int8",
    "EmployeeNumber": "int16",
    "HourlyRate": "int8",
    "MonthlyIncome": "int16",
    "MonthlyRate": "int16",
    "NumCompaniesWorked": "int8",
    "PercentSalaryHike": "int8",
    "StandardHours": "int8",
    "TotalWorkingYears": "int8",
    "TrainingTimesLastYear": "int8",
    "YearsAtCompany": "int8",
    "YearsInCurrentRole": "int8",
    "YearsSinceLastPromotion": "int8",
    "YearsWithCurrManager": "int8"
})

# Drop columns "StandardHours", "EmployeeCount", "Over18" and "EmployeeNumber"
df_HR_Attrition.drop(columns=["StandardHours", "EmployeeCount", "Over18", "EmployeeNumber"], inplace=True)

# %%
cat_features = ["BusinessTravel", "Department", "Education", "EducationField", "EnvironmentSatisfaction", "Gender", "JobInvolvement",
                "JobLevel", "JobRole", "JobSatisfaction", "MaritalStatus", "OverTime", "PerformanceRating", "RelationshipSatisfaction",
                "StockOptionLevel", "WorkLifeBalance", "TrainingTimesLastYear", "NumCompaniesWorked"]

def convert_cat(features, df):
    """
    Convert specified columns to categorical dtype.
    This helps reduce memory usage and prepares features
    for encoding steps in the ML pipeline.
    """
    for feature in features:
        if feature in df.columns:
            df[feature] = df[feature].astype("category")

convert_cat(cat_features, df=df_HR_Attrition)

# %%
# Display information about the DataFrames
print("\n[i] Displaying Data Info:")
df_HR_Attrition.info()
# Out:
# [i] Displaying Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int8
#  1   Attrition                 1470 non-null   int8
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int16
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   category
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   category
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int8
#  11  JobInvolvement            1470 non-null   category
#  12  JobLevel                  1470 non-null   category
# ...

# %% [markdown]
# **Dataset Size and Structure**
#
# **Dataset Size and Structure**
#    - The **dataset** contains `1479` samples with `31` columns, including the target feature `Attrition`.
#
# **Feature Overview**
#    - **Numerical features:** `Age`, `DailyRate`, `DistanceFromHome`, `HourlyRate`, `MonthlyIncome`, `MonthlyRate`, `PercentSalaryHike`, `TotalWorkingYears`, `YearsAtCompany`, `YearsInCurrentRole`,  `YearsSinceLastPromotion`, `YearsWithCurrManager`.
#    - **Categorical features:** `BusinessTravel`, `Department`, `Education`, `EducationField`, `EnvironmentSatisfaction`, `Gender`, `JobInvolvement`, `JobLevel`, `JobRole`, `JobSatisfaction`, `MaritalStatus`, `OverTime`, `PerformanceRating`, `RelationshipSatisfaction`, `StockOptionLevel`, `WorkLifeBalance`, `NumCompaniesWorked`, `TrainingTimesLastYear`.
#    - **Target variable:** `Attrition`.
#
# **Data Completeness**
#    - Data types are appropriate: numerical features are integer, and categorical features are category.

# %%
num_features = ["Age", "DailyRate", "DistanceFromHome", "HourlyRate", "MonthlyIncome", "MonthlyRate", 
                "PercentSalaryHike", "TotalWorkingYears", "YearsAtCompany", "YearsInCurrentRole",  
                "YearsSinceLastPromotion", "YearsWithCurrManager"]

print("[i] Data describe:")
cm = sns.light_palette("blue", as_cmap=True)
display(df_HR_Attrition[num_features].describe().T.style.background_gradient(cmap=cm))
# Out:
# [i] Data describe:
# <style type="text/css">
# ...

# %% [markdown]
# **Analysis**
#
# * **Age**: Mean ~37; range 18–60; concentrated within the working-age group (30–43).
# * **DailyRate**: Mean ~802; symmetric distribution; 50% fall between 465–1157.
# * **DistanceFromHome**: Mean ~9 km; right-skewed; most live close (2–14 km), some commute far (up to 29 km).
# * **HourlyRate**: Mean ~66; nearly uniform/symmetric; 50% fall between 48–83.
# * **MonthlyIncome**: Mean ~6503; right-skewed; 50% earn 2911–8379; a small high-income group pulls the mean upward.
# * **MonthlyRate**: Mean ~14,313; symmetric; wide variability; median close to mean → relatively even distribution.
# * **PercentSalaryHike**: Mean ~15%; slight right skew; most receive 12–18% raises, with a few up to 25%.
# * **TotalWorkingYears**: Mean ~11; slight right skew; 50% have 6–15 years of experience.
# * **YearsAtCompany**: Mean ~7; right-skewed; most have 2–9 years of tenure.
# * **YearsInCurrentRole**: Mean ~4; right-skewed; most have 2–7 years in their current role.
# * **YearsSinceLastPromotion**: Mean ~2.2; right-skewed; 50% were promoted 0–3 years ago.
# * **YearsWithCurrManager**: Mean ~4; right-skewed; 50% have worked with their current manager for 2–7 years.

# %%
print("[i] Data describe:")
display(df_HR_Attrition[cat_features].describe().T.style.background_gradient(cmap="Blues", subset=["unique", "freq"]))
# Out:
# [i] Data describe:
# <style type="text/css">
# #T_b2126_row0_col1, #T_b2126_row1_col1, #T_b2126_row10_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_b2126_row0_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_b2126_row1_col3 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_b2126_row2_col1, #T_b2126_row7_col1, #T_b2126_row10_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_b2126_row2_col3 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_b2126_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_b2126_row3_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_b2126_row4_col1, #T_b2126_row6_col1, #T_b2126_row9_col1, #T_b2126_row13_col1, #T_b2126_row14_col1, #T_b2126_row15_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b2126_row4_col3 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# ...

# %% [markdown]
# **Analysis:**
#
# * **BusinessTravel:** 3 categories; **Travel_Rarely** dominates → low travel frequency for most employees.
# * **Department:** 3 departments; **R&D** is the majority → technical workforce–heavy.
# * **Education:** 5 levels; **Bachelor** most common → generally well-educated workforce.
# * **EducationField:** 6 fields; **Life Sciences** leads → aligns with R&D-heavy staff composition.
# * **EnvironmentSatisfaction:** 4 levels; **High** is most common → generally positive workplace perception.
# * **Gender:** Binary; **Male** slightly higher → mild demographic imbalance.
# * **JobInvolvement:** 4 levels; majority **High** → employees tend to be strongly engaged.
# * **JobLevel:** 5 levels; **Level 1** dominates → workforce concentrated at entry/mid levels.
# * **JobRole:** 9 roles; **Sales Executive** is most frequent → sales department well-represented.
# * **JobSatisfaction:** 4 levels; **Very High** is most common → strong job satisfaction signal.
# * **MaritalStatus:** 3 categories; **Married** largest group → stable personal demographics.
# * **OverTime:** Binary; **No** is majority → most employees do not work overtime.
# * **PerformanceRating:** Binary; overwhelmingly **Excellent** → extremely skewed performance distribution.
# * **RelationshipSatisfaction:** 4 levels; mainly **High** → positive interpersonal dynamics.
# * **StockOptionLevel:** 4 levels; **Basic** most common → limited equity incentives for most staff.
# * **WorkLifeBalance:** 4 levels; **Better** dominates → relatively healthy balance overall.
# * **TrainingTimesLastYear:** 7 categories (0–6); **2 and 3** are the most common → most employees attend a moderate number of training sessions per year.
# * **NumCompaniesWorked:** 10 categories (0–9); **1 company** is the most frequent → many employees have relatively stable career histories, though some show diverse job changes.

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Quality Checks</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Data Quality Checks
#     </h1>
# </div>

# %% [markdown]
# ## Missing Value

# %%
def displayNULL(df, dataset_name=None):
    total_rows = len(df)

    # Replace blank strings with NaN for completeness
    df_null_check = df.replace(r"^\s*$", np.nan, regex=True)

    missing_df = df_null_check.isnull().sum().reset_index()
    missing_df.columns = ["Feature", "Missing_Count"]
    missing_df = missing_df[missing_df["Missing_Count"] > 0]
    missing_df["Missing_%"] = (missing_df["Missing_Count"] / total_rows * 100).round(2)
    missing_df = missing_df.sort_values(by="Missing_Count", ascending=False).reset_index(drop=True)

    total_missing = missing_df["Missing_Count"].sum()

    print("=" * 80)
    
    if total_missing == 0:
        print(f"[✓] No missing values detected in {total_rows:,} rows.")
    else:
        try:
            from tabulate import tabulate
            print(tabulate(missing_df, headers="keys", tablefmt="pretty", showindex=False, colalign=("left", "left", "left")))
        except ImportError:
            print(missing_df.to_string(index=False))
        
        print(f"\n[!] Total missing values: {total_missing:,} out of {total_rows:,} rows.")

print("[i] Checking missing values for Data...")
displayNULL(df_HR_Attrition, dataset_name="Data")

print("\n[✓] Completed checking for NULL values across datasets.")
# Out:
# [i] Checking missing values for Data...
# ...
# [✓] No missing values detected in 1,470 rows.
#
# [✓] Completed checking for NULL values across datasets.

# %% [markdown]
# ## Checking Duplicate Value

# %%
def check_duplicates_report(df, dataset_name):
    duplicates_count = df.duplicated().sum()
    total_rows = len(df)
    
    print(f"[i] {dataset_name} Duplicate Analysis...")
    print("=" * 80)

    if duplicates_count == 0:
        print(f"[✓] No duplicate rows found out of {total_rows:,} total rows.")
    else:
        print(f"[!] {duplicates_count:,} duplicate rows detected ({duplicates_count/total_rows:.2%}).")
        print(f"[!] Rows affected: {duplicates_count:,} out of {total_rows:,}.")

datasets = {"Data": df_HR_Attrition}

duplicate_summary = {}
for name, data in datasets.items():
    check_duplicates_report(data, name)
    duplicate_summary[name] = {
        "duplicates": data.duplicated().sum(),
        "total_rows": len(data)
    }
    print()

print("[✓] Duplicate value inspection successfully completed across datasets.")
# Out:
# [i] Data Duplicate Analysis...
# ...
# [✓] No duplicate rows found out of 1,470 total rows.
#
# [✓] Duplicate value inspection successfully completed across datasets.

# %% [markdown]
# ## Checking Outlier Value
#
# * Outliers are data points that significantly differ from other observations. Detecting and handling them is important because they can distort analysis and lead to incorrect conclusions. <br>
# * Using the Interquartile Range (IQR) Method : The IQR method identifies outliers as values `below Q1 - 1.5 * IQR` or `above Q3 + 1.5 * IQR`. <br>
# * If the outlier count is 0, that column has no outliers. <br>
# * If the outlier count is greater than 0, that column contains outliers.

# %%
def checking_outlier(list_feature, df, dataset_name):
    print("=" * 40)
    print(f"[i] Checking for outliers in {dataset_name}...")
    print("=" * 40)
    outlier_info = []
    
    for feature in list_feature:
        Q1 = df[feature].quantile(0.25)
        Q3 = df[feature].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)][feature]
        
        if len(outliers) > 0:
            outlier_info.append({
                "Feature": feature,
                "Outlier Count": len(outliers),
                # "Outlier Detail": outliers.tolist()
            })

    if len(outlier_info) == 0:
        print("[✓] No outliers detected in any of the selected features.")
    else:
        return pd.DataFrame(outlier_info)

checking_outlier(list_feature=num_features, df=df_HR_Attrition, dataset_name="Data")
# Out:
# ...
# [i] Checking for outliers in Data...
# ...
#                    Feature  Outlier Count
# 0            MonthlyIncome            114
# 1        TotalWorkingYears             63
# 2           YearsAtCompany            104
# 3       YearsInCurrentRole             21
# 4  YearsSinceLastPromotion            107
# 5     YearsWithCurrManager             14

# %% [markdown]
# **Analysis:**
#
# **Missing Values Analysis**
#
# - **No missing values** were detected in the datasets
#
# **Duplicate Records Analysis**
#
# - We examined the datasets for duplicate rows that could bias the model or inflate performance metrics.
# - **No duplicate records** were found in dataset, confirming the uniqueness and integrity of 0 duplicates out of `1470` rows.
# - The absence of duplicates ensures that the model will not be trained or evaluated on repeated data points, which helps maintain the reliability of results.
#
# **Outliers Records Analysis**
# - We also examined the datasets for checking outliers.
# - **The outliers** were found in dataset at features: `MonthlyIncome`, `TotalWorkingYears`, `YearsAtCompany`, `YearsInCurrentRole`, `YearsSinceLastPromotion`, `YearsWithCurrManager`. But we can not remove them since these outliers reflect reality.

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Exploratory Data Analysis (EDA)</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Exploratory Data Analysis (EDA)
#     </h1>
# </div>

# %%
def color(n_colors=2, tone="diverging"):
    """
    Generate a color palette with flexible tone options for data visualization.

    This function returns a list of colors sampled from a specified Seaborn 
    color palette. It supports a variety of built-in tones (diverging, pastel, 
    muted, husl, etc.) as well as custom-defined palettes. If the selected 
    palette is continuous, colors are interpolated evenly based on `n_colors`.

    Args:
        n_colors (int, optional): 
            Number of colors to return. 
            - For continuous palettes, colors are sampled evenly between 0 and 1.
            - For discrete palettes, the first `n_colors` colors are returned.
            Default is 2.
        
        tone (str, optional): 
            Type of color tone or palette to use. Supported values include:
            - "diverging"
            - "pastel"
            - "muted"
            - "husl"
            - "Dark2"
            - "viridis"
            - "crest"
            - "Paired"
            - "rocket"
            - "rocket_r"
            - "mako"
            - "RdYlGn"
            - "modern"   (custom palette)
            - "custom"   (custom pastel palette)
            Default is "diverging".

    Returns:
        list:
            A list of RGB tuples representing the generated color palette.

    Notes:
        - If `tone` corresponds to a continuous colormap (`as_cmap=True`), 
          the function interpolates colors smoothly.
        - If a discrete palette is selected, it simply slices the requested 
          number of colors.
    """
    if tone == "diverging":
        cmap = sns.diverging_palette(0, 230, as_cmap=True)
    elif tone == "pastel":
        cmap = sns.color_palette("pastel")
    elif tone == "muted":
        cmap = sns.color_palette("muted")
    elif tone == "husl":
        cmap = sns.color_palette("husl")
    elif tone == "Dark2":
        cmap = sns.color_palette("Dark2")
    elif tone == "viridis":
        cmap = sns.color_palette("viridis")
    elif tone == "crest":
        cmap = sns.color_palette("crest")
    elif tone == "Paired":
        cmap = sns.color_palette("Paired")
    elif tone == "rocket":
        cmap = sns.color_palette("rocket")
    elif tone == "rocket_r":
        cmap = sns.color_palette("rocket_r")
    elif tone == "mako":
        cmap = sns.color_palette("mako")
    elif tone == "RdYlGn":
        cmap = sns.color_palette("RdYlGn")
    elif tone == "modern":
        cmap = sns.color_palette(["#E63946","#F1FAEE","#A8DADC","#457B9D","#1D3557"])
    elif tone == "custom":
        cmap = sns.color_palette(["#A077FF","#D6BBFF","#FFCAF8","#FE86C1","#40CBEA", "#9CE8EE"])
    positions = np.linspace(0, 1, n_colors)
    return [cmap(p) for p in positions] if callable(cmap) else cmap[:n_colors]

# %%
def cal_ChiSquare(cat_feature, target_feature, df, show_expected=False, show_residuals=False):
    """
    Perform a Chi-Square test of independence to evaluate whether two categorical variables
    are statistically associated (i.e., dependent) or independent from each other.

    This function tests the null hypothesis that the two categorical variables are independent.
    It prints the test statistic, degrees of freedom, p-value, and an interpretation based on the p-value.
    Optionally, it displays the expected frequency table under independence, and standardized residuals
    (including a heatmap) which help to identify specific group-level deviations.

    Parameters
    ----------
    cat_feature : str
        Name of the first categorical variable (typically the feature).

    target_feature : str
        Name of the second categorical variable (typically the target label).

    df : pd.DataFrame
        The input DataFrame containing the data.

    show_expected : bool, default=False
        If True, prints the expected frequencies under the assumption of independence.

    show_residuals : bool, default=False
        If True, prints the standardized residuals and shows them as a heatmap
        to identify where the strongest associations/deviations occur.

    Returns
    -------
    None
        Prints the Chi-Square test result, including statistical significance interpretation.
        Optionally prints expected values and standardized residuals.

    Notes
    -----
    - Hypotheses:
        H₀ (Null):     The two variables are independent (no association).
        H₁ (Alt.):      There is a dependency or association between the variables.

    - Interpretation:
        If p-value < 0.05 → Reject H₀ → Conclude that the variables are significantly associated.
        If p-value ≥ 0.05 → Fail to reject H₀ → No statistically significant association found.

    - Standardized residuals:
        - Values > +2 or < -2 indicate strong deviation from expected frequency (local dependency).
        - Useful for identifying specific group-level contributions to the overall Chi-Square result.

    References
    ----------
    - https://en.wikipedia.org/wiki/Chi-squared_test
    - https://www.scribbr.com/statistics/chi-square-test-of-independence/
    """
    print(f"\n[i] Chi-Square Test of Independence: '{cat_feature}' vs. '{target_feature}'...")

    # Contingency table
    crosstab = pd.crosstab(df[cat_feature], df[target_feature])
    chi2, p, dof, expected = chi2_contingency(crosstab)

    print(f"[i] Chi-squared statistic: {chi2:.3f}")
    print(f"[i] Degrees of freedom: {dof}")
    print(f"[i] p-value: {p:.6f}")

    if p < 0.05:
        print("[✓] Result: p-value < 0.05 → Reject H₀")
        print(f"[✓] Variables '{cat_feature}' and '{target_feature}' are statistically associated.")
    else:
        print("[!] Result: p-value ≥ 0.05 → Fail to reject H0")
        print(f"[!] No statistically significant association detected between '{cat_feature}' and '{target_feature}'.")

    # Optional: show expected frequencies
    if show_expected:
        print("\n[i] Expected Frequencies:")
        print(pd.DataFrame(expected, index=crosstab.index, columns=crosstab.columns))

    # Optional: show standardized residuals
    if show_residuals:
        residuals = (crosstab - expected) / np.sqrt(expected)
        print("\n[i] Standardized Residuals:")
        print(round(residuals, 2))

        # Heatmap of residuals
        plt.figure(figsize=(10, 7))
        sns.heatmap(residuals, annot=True, cmap=sns.diverging_palette(0, 230, 90, 60, as_cmap=True), center=0, fmt=".2f", linewidths=0.5)
        plt.title(f"Standardized Residuals Heatmap: {cat_feature} vs {target_feature}", weight="bold", fontsize=12, pad=15)
        plt.ylabel(cat_feature)
        plt.xlabel(target_feature)
        plt.tight_layout()
        plt.show()

def perform_kruskal_test(df, categorical_feature, numeric_feature):
    """
    Perform the Kruskal-Wallis H-test to determine whether there are statistically
    significant differences in the distribution of a numeric variable across
    three or more independent groups.

    If the result is significant (p < 0.05), Dunn's post-hoc test with Bonferroni correction
    is performed to identify which group pairs differ.

    Parameters
    ----------
    df : pd.DataFrame
        The input dataset containing the categorical and numerical variables.

    categorical_feature : str
        The name of the categorical feature that defines the groups.

    numeric_feature : str
        The name of the numeric feature to be compared across groups.

    Returns
    -------
    None
        Prints the Kruskal-Wallis H-statistic, p-value, interpretation, and
        optionally the results of Dunn's post-hoc test.

    Notes
    -----
    - H₀ (null hypothesis): The distribution of the numeric variable is the same across all groups.
    - H₁ (alternative hypothesis): At least one group has a different distribution.
    - If p < 0.05 → reject H₀ → use Dunn’s test to explore specific group differences.
    - Kruskal-Wallis is a non-parametric alternative to one-way ANOVA.
    - It does not assume normality, but assumes:
        1. Independent samples
        2. Ordinal or continuous response variable
        3. Similar shapes of distributions

    Requirements
    ------------
    - `scipy.stats.kruskal`
    - `scikit-posthocs` package for Dunn’s test (`import scikit_posthocs as sp`)

    References
    ----------
    - https://www.geeksforgeeks.org/kruskal-wallis-test/
    - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kruskal.html
    - https://scikit-posthocs.readthedocs.io/en/latest/index.html
    """

    # Extract values
    groups = df[categorical_feature].dropna().unique()
    if len(groups) < 3:
        print(f"[x] Error: Kruskal-Wallis H-test requires 3 or more groups.")
        return
    else:
        print(f"\n[i] Kruskal-Wallis Test: {numeric_feature} ~ {categorical_feature}...")
        data_groups = [df[df[categorical_feature] == g][numeric_feature].dropna() for g in groups]

        # Perform kruskal
        stat, p = kruskal(*data_groups)

        print(f"[i] Kruskal-Wallis H-statistic: {stat:.3f}")
        print(f"[i] p-value: {p}")

        if p < 0.05:
            print("[✓] Significant difference detected among groups (p < 0.05).")
            print("[i] Running Dunn's Post-Hoc Test (Bonferroni corrected)...")
            dunn_result = sp.posthoc_dunn(df, val_col=numeric_feature, group_col=categorical_feature, p_adjust="bonferroni")
            print(dunn_result)
        else:
            print("[!] No statistically significant difference detected between groups (p ≥ 0.05).")

def check_normality_with_plots(df, feature, target_feature, threshold_skew_1=0.5, threshold_skew_2=1.0,
                               threshold_kurt=1.5, ncols=2):
    """
    Check the normality of numerical features *within each group* of a categorical feature,
    using Skewness, Kurtosis, and Q–Q plots. 
    If non-normality is detected in any group, automatically perform Kruskal–Wallis test.

    ---
    Parameters
    ----------
    df : pd.DataFrame
        Input dataset containing both numeric and categorical features.

    feature : numeric
        Numerical columns to test (e.g. ["Temparature"]).

    target_feature : str
        Categorical variable name (e.g. "Fertilizer_Name").

    threshold_skew_1 : float, default = 0.5
        Threshold for approximately symmetric (|skew| ≤ 0.5).

    threshold_skew_2 : float, default = 1.0
        Threshold for moderate skewness (0.5 < |skew| ≤ 1.0).

    threshold_kurt : float, default = 1.5
        Absolute kurtosis threshold for approximate normality.

    ncols : int, default = 2
        Number of Q–Q plots per row.
    """

    results = []
    non_normal_detected = False

    print(f"\n[i] Checking normality of feature '{feature}' by groups of '{target_feature}'...")

    # ===  Evaluate normality within each group ===
    print(f"[i] Evaluating distribution characteristics...")

    for grp, subset in df.groupby(target_feature):
        data = subset[feature].dropna()
        sk = skew(data)
        kt = kurtosis(data)
        abs_sk = abs(sk)
        abs_kt = abs(kt)

        # Skewness interpretation
        if abs_sk <= threshold_skew_1:
            skew_remark = "Approximately symmetric"
        elif abs_sk <= threshold_skew_2:
            skew_remark = "Moderately skewed"
        else:
            skew_remark = "Highly skewed"

        # Kurtosis interpretation
        if abs_kt < threshold_kurt:
            kurt_remark = "Normal tails"
        else:
            kurt_remark = "Heavy/light tails"

        remark = f"{skew_remark}, {kurt_remark}"
        results.append({
            "Feature": feature,
            "Group": grp,
            "Skewness": f"{sk:.4f}",
            "Kurtosis": f"{kt:.4f}",
            "Remark": remark
        })

        # Flag if any group is not approximately normal
        if not (abs_sk <= threshold_skew_1 and abs_kt <= threshold_kurt):
            non_normal_detected = True

    # === Visual Q–Q plots ===
    print("[i] Generating Q–Q plots for visual assessment...")

    n_groups = df[target_feature].nunique()
    nrows = int(np.ceil(n_groups / ncols))
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6 * ncols, 4.5 * nrows))
    axes = np.array(axes).reshape(-1)

    for i, grp in enumerate(df[target_feature].unique()):
        ax = axes[i]
        data = df.loc[df[target_feature] == grp, feature].dropna()
        probplot(data, dist="norm", plot=ax)
        ax.set_title(f"{feature} — {grp}", fontsize=12, weight="bold")
        ax.grid(alpha=0.3)

    for j in range(i + 1, len(axes)):
        axes[j].axis("off")

    plt.suptitle(f"Q–Q Plots of {feature} by {target_feature}", fontsize=12, weight="bold", y=1.02)
    plt.tight_layout()
    plt.show()

    # === Display results table ===
    df_result = pd.DataFrame(results)
    cm = sns.light_palette("blue", as_cmap=True)
    styled = (
        df_result.style
        .background_gradient(subset=["Skewness"], cmap=cm, vmin=-1, vmax=1)
        .background_gradient(subset=["Kurtosis"], cmap=cm, vmin=-1.5, vmax=1.5)
        .set_caption(
            f'<b><span style="font-size:14px; text-align:center; display:block;">'
            f'Skewness & Kurtosis of {feature} by {target_feature}'
            f'</span></b>'
        )
        .set_table_attributes('style="width:80%; margin:auto;"')
    )
    display(styled)

    # === Final evaluation ===
    if non_normal_detected:
        print("[!] At least one group deviates from normality.")
        print("[i] Non-normal distribution detected → Consider Kruskal–Wallis or Mann–Whitney U test.")
    else:
        print("[✓] All groups approximately follow a normal distribution.")

    return non_normal_detected

def perform_anova_with_tukey(df, numeric_feature, categorical_feature, typ=2):
    """
    Perform a One-Way ANOVA test to determine whether there are statistically
    significant differences between the means of three or more independent groups.

    If the ANOVA test is significant (p < 0.05), Tukey's HSD post-hoc test is performed
    to identify which specific pairs of groups differ from each other.

    Parameters
    ----------
    df : pd.DataFrame
        The input dataset containing the numeric and categorical features.

    numeric_feature : str
        The name of the numerical (continuous) response variable.

    categorical_feature : str
        The name of the categorical (independent) variable used to group the data.

    typ : int, optional (default=2)
        The type of sum of squares to use in the ANOVA test:
        - Type I (1): Sequential.
        - Type II (2): Default and commonly used for balanced designs.
        - Type III (3): Use when model includes interaction terms or unbalanced data.

    Returns
    -------
    None
        Prints the ANOVA table, p-value, interpretation, and (if significant) the Tukey HSD test summary.

    Notes
    -----
    - H₀ (null hypothesis): All group means are equal.
    - H₁ (alternative hypothesis): At least one group mean is different.
    - If p < 0.05 → reject H₀ → perform Tukey’s HSD to find which groups differ.
    - Assumptions:
        1. Independence of observations
        2. Normally distributed groups (Shapiro or Anderson test can check this)
        3. Homogeneity of variances (Levene's test)

    References
    ----------
    - https://www.scribbr.com/statistics/one-way-anova/
    - https://en.wikipedia.org/wiki/Analysis_of_variance
    - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.tukey_hsd.html
    """

    # Extract unique groups
    groups = df[categorical_feature].dropna().unique()

    if len(groups) < 3:
        print("[x] Error: ANOVA requires at least 3 groups.")
        return
    else:
        print(f"\n[i] Running ANOVA Test: {numeric_feature} ~ {categorical_feature} (Type {typ})...")

        # Fit OLS model
        model = ols(f"{numeric_feature} ~ C({categorical_feature})", data=df).fit()

        # Perform ANOVA
        anova_table = anova_lm(model, typ=typ)
        print("\n[i] ANOVA Table:")
        print(anova_table)

        # Extract p-value
        p_value = anova_table["PR(>F)"].iloc[0]

        if p_value < 0.05:
            print("\n[✓] Significant difference detected (p < 0.05).")
            print("[i] Running Tukey's HSD post-hoc test...")

            tukey = pairwise_tukeyhsd(df[numeric_feature], df[categorical_feature])
            print(tukey.summary())
        else:
            print("\n[!] No statistically significant difference detected (p ≥ 0.05).")

def perform_welch_anova(df, numeric_feature, categorical_feature):
    """
    Perform Welch’s ANOVA test to compare group means when the assumption of equal variances
    is violated but normality approximately holds.

    This version of ANOVA adjusts for unequal variances and sample sizes across groups.
    If the Welch’s ANOVA is significant (p < 0.05), a Games–Howell post-hoc test is performed
    to identify which specific group pairs differ significantly.

    Parameters
    ----------
    df : pd.DataFrame
        The input dataset containing both numeric and categorical variables.

    numeric_feature : str
        The name of the continuous (dependent) variable.

    categorical_feature : str
        The name of the categorical (independent) variable representing group membership.

    Returns
    -------
    None
        Prints Welch’s ANOVA summary, p-value interpretation, and Games–Howell post-hoc results.

    Notes
    -----
    - H₀ (null hypothesis): All group means are equal.
    - H₁ (alternative hypothesis): At least one group mean differs.
    - If p < 0.05 → reject H₀ → perform Games–Howell test.
    - Assumptions:
        1. Groups are independent.
        2. Data within each group are approximately normal.
        3. Variances are not necessarily equal (heteroscedasticity allowed).

    Key Differences vs Classical ANOVA
    ----------------------------------
    - Welch’s ANOVA does **not assume equal variances**.
    - More robust when sample sizes and variances differ across groups.
    - Use **Games–Howell post-hoc test** instead of Tukey HSD.

    References
    ----------
    - Welch, B. L. (1951). "On the comparison of several mean values: an alternative approach."
      Biometrika, 38(3/4), 330–336.
    - Games, P. A., & Howell, J. F. (1976). "Pairwise multiple comparison procedures with unequal N’s and/or variances."
      Journal of Educational Statistics, 1(2), 113–125.
    """

    # Drop NaN rows
    df = df[[numeric_feature, categorical_feature]].dropna()

    # Extract group values
    groups = [df.loc[df[categorical_feature] == g, numeric_feature] for g in df[categorical_feature].unique()]

    if len(groups) < 3:
        print("[x] Error: Welch’s ANOVA requires 3 or more groups.")
        return

    print(f"\n[i] Running Welch’s ANOVA Test: {numeric_feature} ~ {categorical_feature}")
    print("[i] Assessing mean differences under heteroscedastic conditions...")

    # Perform Welch's ANOVA (scipy.stats)
    welch_result = stats.f_oneway(*groups)
    print("\n[i] Welch’s ANOVA Result:")
    print(f"[i] F-statistic: {welch_result.statistic:.4f}")
    print(f"[i] p-value: {welch_result.pvalue:.6f}")

    # Interpret result
    if welch_result.pvalue < 0.05:
        print("\n[✓] Significant difference detected (p < 0.05).")
        print("[i] Performing Games–Howell post-hoc test...\n")

        # Perform Games–Howell post-hoc test (robust for unequal variances)
        gh_result = pg.pairwise_gameshowell(dv=numeric_feature, between=categorical_feature, data=df)

        display(HTML("<b>Games–Howell Post-hoc Test (adjusted p-values)</b>"))
        display(gh_result.style.background_gradient(cmap=cm).format(precision=4).set_table_attributes('style="width:80%; margin:auto;"'))
    else:
        print("\n[!] No statistically significant difference detected (p ≥ 0.05).")

def check_homogeneity_of_variance(df, feature, target_feature, alpha=0.05, ratio_threshold=2.0):
    """
    Check homogeneity of variances across groups using Levene’s test (median-centered).
    Also computes variance ratios and provides practical interpretation.

    ---
    Parameters
    ----------
    df : pd.DataFrame
        Input dataset containing numeric and categorical features.
    feature : str
        Numeric variable to test (e.g. "Temparature").
    target_feature : str
        Categorical grouping variable (e.g. "Fertilizer_Name").
    alpha : float, default = 0.05
        Significance level for hypothesis testing.
    ratio_threshold : float, default = 2.0
        Threshold for maximum acceptable variance ratio (max(var)/min(var)).
        If ratio > threshold → indicates heteroscedasticity in practice.

    ---
    Returns
    -------
    dict
        Dictionary with test statistic, p-value, variance ratio, and recommendation.

    ---
    Interpretation Logic
    ---------------------
    Step 1: Statistical Test
        - H₀: All group variances are equal.
        - H₁: At least one group has a different variance.
        - Levene’s Test (center='median') is robust to non-normality.

    Step 2: Practical Variance Ratio
        - ratio = max(var_i) / min(var_i)
        - < 2 → practically equal
        - 2–4 → moderate difference
        - > 4 → strong heterogeneity

    Step 3: Recommendation
        - If p > 0.05 AND ratio < 2 → Use One-Way ANOVA or Independent Two-Sample T-Test
        - If p < 0.05 BUT ratio < 2 → Statistical diff, but practically negligible → ANOVA or T-Test are acceptable, but Welch’s ANOVA or Welch’s T-Test is recommended.
        - If ratio ≥ 2 OR p < 0.05  →  Use Kruskal–Wallis or Mann–Whitney U test.
    """

    # Group data by category
    groups = [df.loc[df[target_feature] == g, feature].dropna() for g in df[target_feature].unique()]

    # Perform Levene’s Test (robust version)
    stat, p = levene(*groups, center="mean")

    # Compute variance ratio (max/min)
    variances = [np.var(g, ddof=1) for g in groups]
    ratio = max(variances) / min(variances)
    anova_use = False
    is_homogeneous_variances = False
    # Determine interpretation
    if p > alpha and ratio < ratio_threshold:
        status = "[✓] Variances are statistically and practically homogeneous."
        recommendation = "Use One-Way ANOVA or Independent Two-Sample T-Test."
        is_homogeneous_variances = True
        anova_use = True
    elif p < alpha and ratio < ratio_threshold:
        status = "[!] Statistically different variances, but practical difference is small."
        recommendation = "ANOVA or T-Test are acceptable, but Welch’s ANOVA or Welch’s T-Test is recommended."
        anova_use = True
    else:
        status = "[x] Strong variance heterogeneity detected."
        recommendation = "Use Kruskal–Wallis or Mann–Whitney U test."

    # Display summary table
    summary_df = pd.DataFrame({
        "Metric": ["Levene’s Statistic", "p-value", "Max/Min Variance Ratio"],
        "Value": [f"{stat:.4f}", f"{p:.6f}", f"{ratio:.2f}"]
    })
    display(summary_df.style
            .background_gradient(subset=["Value"], cmap="Blues")
            .set_caption(
        f'<b><span style="font-size:14px; text-align:center; display:block;">'
        f'Homogeneity of Variance — {feature} by {target_feature}</span></b>'
    ).set_table_attributes('style="width:70%; margin:auto;"'))

    # Print interpretation
    print("\n[i] Interpretation:")
    print(f"   {status}")
    print(f"   Recommendation → {recommendation}")

    return anova_use, is_homogeneous_variances

def cal_mannwhitneyu(dataframe, categorical_feature, num_feature):
    """
    Perform the Mann–Whitney U test (Wilcoxon rank-sum test) to assess whether there 
    is a statistically significant difference in the distribution of a numerical feature 
    between two independent groups defined by a binary categorical feature.

    The function also compares medians, calculates the effect size (r), provides interpretation,

    Parameters
    ----------
    dataframe : pd.DataFrame
        The input DataFrame containing the data.

    categorical_feature : str
        Column name of the categorical feature (must contain exactly 2 unique values).

    num_feature : str
        Column name of the numerical feature to compare.

    Returns
    -------
    None
        Prints the U statistic, p-value, medians, Z-score, effect size r, and interpretation.

    Notes
    -----
    - H₀ (Null Hypothesis): The two groups have the same distribution.
    - H₁ (Alternative Hypothesis): The distributions are different.
    - If p ≤ 0.05 → reject H₀ → significant difference.
    - Effect size r helps interpret how strong the difference is:
        * Small ~0.1, Medium ~0.3, Large ≥0.5
    """
    groups = dataframe[categorical_feature].dropna().unique()

    # Validation check
    if len(groups) != 2:
        print(f"[x] Error: Mann–Whitney U test requires exactly 2 groups, but found {len(groups)}.")
        return

    print(f"\n[i] Running Mann–Whitney U Test: '{num_feature}' by '{categorical_feature}'...")

    group1 = dataframe[dataframe[categorical_feature] == groups[0]][num_feature].dropna()
    group2 = dataframe[dataframe[categorical_feature] == groups[1]][num_feature].dropna()

    stat, p = mannwhitneyu(group1, group2, alternative="two-sided")

    print(f"[i] U statistic: {stat}")
    print(f"[i] p-value    : {p:.6f}")

    # Interpretation
    if p <= 0.05:
        print("\n[✓] Significant difference detected between the two groups (Reject H0).")
        median1 = group1.median()
        median2 = group2.median()

        print(f"[i] Median of group '{groups[0]}': {median1:.4f}")
        print(f"[i] Median of group '{groups[1]}': {median2:.4f}")

        if median1 > median2:
            print(f"[i] Interpretation: Group '{groups[0]}' has a higher median '{num_feature}'.")
        elif median1 < median2:
            print(f"[i] Interpretation: Group '{groups[1]}' has a higher median '{num_feature}'.")
        else:
            print("[i] Interpretation: Medians are equal, although distributions may still differ.")
    else:
        print("\n[!] No statistically significant difference detected (Fail to reject H0).")

def t_test_with_cohens_d(data, categorical_feature, num_feature, equal_var=False):
    """
    Perform an Independent Two-Sample T-Test and compute Cohen's d to evaluate 
    the difference between two independent groups on a numeric variable.

    Supports both:
    - Student’s T-Test (equal variances)
    - Welch’s T-Test (unequal variances, default)

    Parameters
    ----------
    data : pd.DataFrame
        The input DataFrame containing the categorical and numerical features.

    categorical_feature : str
        The name of the categorical column used to define the two groups (must have exactly 2 unique values).

    num_feature : str
        The name of the numerical feature to compare between the two groups.

    equal_var : bool, optional (default=False)
        If True → Student’s t-test (equal variances).
        If False → Welch’s t-test (unequal variances).

    Returns
    -------
    None
        Prints the t-statistic, p-value, Cohen’s d, and interpretation of the effect size.

    Notes
    -----
    - H₀ (null hypothesis): The two groups have equal means.
    - H₁ (alternative): The group means differ significantly.
    - Cohen's d interpretation:
        - 0.2 → small effect
        - 0.5 → medium effect
        - 0.8+ → large effect
    - Welch’s t-test is recommended when group variances are unequal (default setting).

    References
    ----------
    - https://www.scribbr.com/statistics/t-test/
    - https://en.wikipedia.org/wiki/Welch%27s_t-test
    - https://en.wikipedia.org/wiki/Cohen%27s_d
    """

    # Extract unique groups
    groups = data[categorical_feature].dropna().unique()

    if len(groups) != 2:
        print("[x] Error: Independent T-Test requires exactly 2 groups.")
        return

    test_type = (
        "Student’s T-Test (equal variances)" 
        if equal_var 
        else "Welch’s T-Test (unequal variances)"
    )

    print(f"\n[i] Running Independent Two-Sample T-Test: '{num_feature}' ~ '{categorical_feature}'")
    print(f"[i] Test Type: {test_type}")

    # Extract values
    x1 = data[data[categorical_feature] == groups[0]][num_feature].dropna()
    x2 = data[data[categorical_feature] == groups[1]][num_feature].dropna()

    # Run T-Test
    t_stat, p_value = ttest_ind(x1, x2, equal_var=equal_var)

    # Calculate Cohen's d (different formulas depending on variance assumption)
    nx1, nx2 = len(x1), len(x2)
    s1, s2 = np.var(x1, ddof=1), np.var(x2, ddof=1)

    if equal_var:
        # --- Student’s T-Test version (pooled variance)
        pooled_std = np.sqrt(((nx1 - 1) * s1 + (nx2 - 1) * s2) / (nx1 + nx2 - 2))
        cohens_d = (np.mean(x1) - np.mean(x2)) / pooled_std
    else:
        # --- Welch’s T-Test version (average variance)
        s_pooled = np.sqrt((s1 + s2) / 2)
        cohens_d = (np.mean(x1) - np.mean(x2)) / s_pooled

    # Display results
    print(f"\n[i] Comparing groups: '{groups[0]}' vs '{groups[1]}'")
    print(f"[i] t-statistic: {t_stat:.3f}")
    print(f"[i] p-value: {p_value:.6f}")
    print(f"[i] Cohen's d: {cohens_d:.3f}")

    # Significance interpretation
    if p_value < 0.05:
        print("[✓] Significant difference detected (p < 0.05).")
        # Effect size interpretation
        abs_d = abs(cohens_d)

        if abs_d < 0.2:
            effect_label = "small"
        elif abs_d < 0.5:
            effect_label = "medium"
        else:
            effect_label = "large"
        print(f"[i] Effect size interpretation: {effect_label} effect (|d| = {abs_d:.3f})")
    else:
        print("[!] No statistically significant difference detected (p ≥ 0.05).")

# %% [markdown]
# ## Attrition Distribution

# %%
attri_Distribution  = df_HR_Attrition["Attrition"].value_counts()
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(15, 5))
# ax[0]
ax[0].pie(
    attri_Distribution,
    labels = ["Working Employees","Attrition Employees"],
    colors = color(n_colors=2),
    autopct = "%1.2f%%",
    startangle = 150,
    explode = (0, 0.08),
    shadow= True
)
ax[0].set_title("Attrition Proportion", weight="bold", fontsize=12, pad=15)

# ax[1]
sns.countplot(data=df_HR_Attrition, x = "Attrition", palette=color(n_colors=2), ax=ax[1])
ax[1].set_title("Attrition Count Distribution", weight="bold", fontsize=12, pad=15)
for container in ax[1].containers:
    ax[1].bar_label(container, fmt="%d", label_type="edge", fontsize=10)
ax[1].set_ylabel("Number of Employees")
ax[1].set_xlabel("")
ax[1].set_xticks([0, 1], ["Working Employees", "Attrition Employees"])
sns.despine(ax=ax[1], top=True, right=True, left=False, bottom=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Analysis:**
#
# **Frequency of attrition category**
#
# - The count plot reveal the absolute counts of each type in the dataset:
# - `0` (Working employee) is the most category with 1233 occurrences, accounting for approximately `83.88%` of the dataset.
# - `1` (Attrition employee) is lower then group working employee with 237 occurrences, accounting for approximately `16.12%` of the dataset.
#
# ***Nearly 1 in 6 employees left — which is not negligible and deserves further investigation. In addition, the data is imbalanced, which will affect the prediction (the model will predict in favor of group 0)***

# %% [markdown]
# ## Numerical Feature Distributions

# %%
def plot_numerical_features(df=df_HR_Attrition, numerical_features = num_features):
    fig, ax = plt.subplots(len(numerical_features), 2, figsize=(12, len(numerical_features)*4))
    ax = np.atleast_2d(ax)

    for i, feature in enumerate(numerical_features):
        sns.histplot(data=df[feature], color="#7209b7", bins = 20, kde=True, ax=ax[i, 0])
        ax[i, 0].set_title(f"Histogram of {feature}", weight="bold", pad=15, fontsize=12)
        ax[i, 0].set_ylabel("")
        ax[i, 0].axvline(df[feature].median(), color="#f72585", linestyle="--", label=f"Median: {df[feature].median()}")
        ax[i, 0].legend()
        sns.despine(ax=ax[i, 0])
        sns.boxplot(data=df[feature], color="#f72585", orient="h", ax=ax[i, 1])
        ax[i, 1].set_title(f"Horizontal Box plot of {feature}", weight="bold", pad=15, fontsize=12)
        ax[i, 1].set_xlabel(feature)
        sns.despine(ax=ax[i, 1])
    plt.tight_layout()
    plt.show()

plot_numerical_features()

# %%
def check_skewness(data, dataset_name, numerical_features = num_features, highlight=True, sort=True):
    skewness_dict = {}
    skew_feature = []
    for feature in numerical_features:
        skew = data[feature].skew(skipna=True)
        skewness_dict[feature] = skew

    skew_df = pd.DataFrame.from_dict(skewness_dict, orient="index", columns=["Skewness"])
    if sort:
        skew_df = skew_df.reindex(skew_df["Skewness"].abs().sort_values(ascending=False).index)
    else:
        pass

    print(f"\n[i] Skewness for {dataset_name}...")
    print("-"*80)
    print(f"{'Feature':<40} | {'Skewness':<9} | {'Remark'}")
    print("-"*80)
    for feature, row in skew_df.iterrows():
        skew = row["Skewness"]
        abs_skew = abs(skew)
        if abs_skew > 1:
            remark = "Highly skewed"
            color = "\033[91m"
        elif abs_skew > 0.5:
            remark = "Moderately skewed"
            color = "\033[93m"
        else:
            remark = "Approximately symmetric"
            color = ""
        endc = "\033[0m" if color else ""
        if highlight and color:
            print(f"{color}{feature:<40} | {skew:>+9.4f} | {remark}{endc}")
            skew_feature.append(feature)
        else:
            print(f"{feature:<40} | {skew:>+9.4f} | {remark}")
    print("-"*80)
    return skew_feature, skew_df

skew_feature, skew_df = check_skewness(df_HR_Attrition, "Data")
# Out:
# [i] Skewness for Data...
# --------------------------------------------------------------------------------
# Feature                                  | Skewness  | Remark
# --------------------------------------------------------------------------------
# YearsSinceLastPromotion                  |   +1.9843 | Highly skewed
# YearsAtCompany                           |   +1.7645 | Highly skewed
# MonthlyIncome                            |   +1.3698 | Highly skewed
# TotalWorkingYears                        |   +1.1172 | Highly skewed
# DistanceFromHome                         |   +0.9581 | Moderately skewed
# YearsInCurrentRole                       |   +0.9174 | Moderately skewed
# YearsWithCurrManager                     |   +0.8335 | Moderately skewed
# PercentSalaryHike                        |   +0.8211 | Moderately skewed
# Age                                      |   +0.4133 | Approximately symmetric
# ...

# %% [markdown]
# **Analysis:**
#
# **Shape and Spread of Distributions**
#
# - **Histograms** reveal that all features are distributed fairly evenly across their respective ranges.
# - **Boxplot** confirm that the central 50% of values (the interquartile range), and the whiskers (showing the range).
#
# **Skewness Analysis**
#
# - The **skewness values** for numerical features (Age, HourlyRate, MonthlyRate, DailyRate) in dataset are less than 0.5, indicating that the distributions are **approximately symmetric** which means:
#   - There is no need for transformations like log or Box-Cox to normalize these features.
#   - Most machine learning algorithms will be able to handle these features without bias due to skewed distributions.
#
# - The features: `MonthlyIncome`, `DistanceFromHome`, `YearsAtCompany`, `TotalWorkingYears`, `YearsSinceLastPromotion`, `PercentSalaryHike`, `YearsInCurrentRole` and `YearsWithCurrManager` have **skewness values** greater than 0.5, indicating that the distributions are **Highly/Moderately symmetric**. Many model assumes **normal distribution** but in reality data points may not be perfectly symmetric. If the data are skewed, then this kind of model will always underestimate the skewness risk.The more the data is skewed the less accurate the model will be. We need to handle skewness in chapter **Data Preprocessing**.

# %% [markdown]
# ## Correlation Analysis of Numerical Features

# %%
corr_matrix = df_HR_Attrition.drop(columns="Attrition", axis=1).corr(numeric_only=True)
# one_like can build a matrix of boolean(True, False) with the same shape as our data
ones_corr = np.ones_like(corr_matrix, dtype=bool)
mask = np.triu(ones_corr)
adjusted_mask = mask[1:, :-1]
adjusted_cereal_corr = corr_matrix.iloc[1:, :-1]

fig, ax = plt.subplots(figsize = (10, 9))
# That method uses HUSL colors, so you need hue, saturation, and lightness. 
# I used hsluv.org to select the colors of this chart.
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

sns.heatmap(data=adjusted_cereal_corr, mask=adjusted_mask,
            annot=True, fmt=".2f", cmap=cmap,
            vmin=-1, vmax=1, linecolor="white", linewidths=0.5)

title = "Correlation Matrix Composition\n"
ax.set_title(title, fontsize=12, weight="bold", pad=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Analysis:**
#
# **Overall Weak Correlations:** Most correlation coefficients are close to zero, indicating **little to no linear relationship** between pairs of features.
#
# **Feature Independence**: There are many pairs of features with good correlation coefficients ranging from **weak, moderate and strong** such as:
# - **TotalWorkingYears ↔ Age (0.68)**: Have a linear relationship with each other.
# - **TotalWorkingYears ↔ MonthlyIncome (0.77**): Employees with more experience tend to earn higher salaries. While not surprising, this is solid evidence for use in performance reviews or salary negotiations.
# - **Years at Company ↔ Years in Current Role (0.76)**: Employees who stay longer at the company often remain in the same role, possibly indicating either stability. <br>
# ...
#
# **Implications for Modeling**
#
# * Mostly weak correlations → low multicollinearity → stable linear models.
# * Some correlated feature clusters → moderate redundancy to be regularized.
# * Weak linear relationships → non-linear models may capture richer patterns.
# * Correlation matrix describes feature structure only (no target involved).

# %% [markdown]
# ## Categorical Feature Distributions

# %%
def plot_categorical_distribution(df, cat_features):
    fig, ax = plt.subplots(len(cat_features), 2, figsize=(18, len(cat_features) * 5))
    ax = np.atleast_2d(ax)

    for i, feature in enumerate(cat_features):
        # Use value_counts order so bar labels and pie labels align with sizes
        vc = df[feature].value_counts()
        order = vc.index.tolist()
        sizes = vc.values
        n_cats = len(order)

        # Generate colors once, aligned to `order`
        colors = color(n_colors=n_cats, tone="RdYlGn")

        # ----------------------------
        # LEFT: Countplot
        # ----------------------------
        sns.countplot(
            data=df, x=feature, ax=ax[i, 0], order=order,
            palette=colors
        )
        ax[i, 0].set_title(f"Count of {feature}", fontsize=12, pad=15, weight="bold")
        ax[i, 0].set_xlabel(feature)
        ax[i, 0].set_ylabel("")
        if n_cats > 4:
            ax[i, 0].set_xticklabels(ax[i, 0].get_xticklabels(), rotation=30, ha="right")
        sns.despine(ax=ax[i, 0], top=True, right=True)

        # Add count labels (aligned to bar centers)
        max_count = sizes.max() if len(sizes) else 0
        for p in ax[i, 0].patches:
            height = p.get_height()
            x = p.get_x() + p.get_width() / 2
            ax[i, 0].text(x, height + max_count * 0.01,
                          f"{int(height)}", ha="center", va="bottom",
                          fontsize=10)

        # ----------------------------
        # RIGHT: Pie Chart (aligned order)
        # ----------------------------
        wedges, texts, autotexts = ax[i, 1].pie(
            sizes,
            labels=order,
            autopct="%1.1f%%",
            shadow=True,
            startangle=150,
            colors=colors,
            textprops={"fontsize": 10}
        )
        ax[i, 1].set_title(f"Percentage of {feature}", fontsize=12, pad=15, weight="bold")
        ax[i, 1].axis("equal")

    plt.tight_layout()
    plt.show()

plot_categorical_distribution(df=df_HR_Attrition, cat_features=cat_features)

# %% [markdown]
# **Analysis:**
#
# * **BusinessTravel:** Mostly *Travel_Rarely* → low travel frequency.
# * **Department:** Workforce dominated by *R&D*, followed by *Sales*; HR is very small.
# * **Education:** Majority have *Bachelor* degrees → strong academic background.
# * **EducationField:** *Life Sciences* dominates → aligns with R&D-heavy structure.
# * **EnvironmentSatisfaction:** Mostly *High* → generally positive environment perception.
# * **Gender:** Slightly more *Male* employees.
# * **JobInvolvement:** Majority *High* → strong engagement.
# * **JobLevel:** Mostly *Level 1* → junior-to-mid-level workforce.
# * **JobRole:** *Sales Executive* most common; role distribution diverse.
# * **JobSatisfaction:** Mostly *Very High* → strong job satisfaction.
# * **MaritalStatus:** *Married* is largest group.
# * **OverTime:** Majority *No* → limited overtime culture.
# * **PerformanceRating:** Almost all rated *Excellent* → extremely skewed evaluation system.
# * **RelationshipSatisfaction:** Mostly *High*.
# * **StockOptionLevel:** Mostly *Basic* → low equity incentives.
# * **WorkLifeBalance:** Mostly *Better* → healthy balance.
# * **TrainingTimesLastYear:** Mostly *2–3 sessions* → moderate training exposure.
# * **NumCompaniesWorked:** Most employees worked *1–2 companies* → generally stable career paths.

# %% [markdown]
# ## Bivariate Analysis

# %%
def perform_statical_testing(feature: str, df: pd.DataFrame = df_HR_Attrition,  target_feature: str = Config.target_feature) -> None:
    """
    Perform statistical tests (normality and Kruskal-Wallis) 
    to evaluate whether there are significant differences 
    in the distribution of a numerical feature across categories 
    of the target variable.

    Args:
        feature (str): Name of the numerical feature to be tested.
        df (pd.DataFrame): Dataset containing both numerical and target columns.
        target_feature (str): Name of the target categorical feature.

    Returns:
        None: Prints or displays statistical test results.
    """
    # Perform normality test (e.g., Shapiro-Wilk or D’Agostino test) for feature distribution
    non_normal_detected = check_normality_with_plots(df=df, feature=feature, target_feature=target_feature)
    total_categories = df[target_feature].nunique()
    if total_categories > 2:
        if non_normal_detected == True:
            perform_kruskal_test(df=df, categorical_feature=target_feature,
                                numeric_feature=feature)
        else:
            anove_use, is_homogeneous_variances = check_homogeneity_of_variance(df=df, feature=feature,
                                                                                target_feature=target_feature)
            if anove_use and is_homogeneous_variances:
                perform_anova_with_tukey(df=df, numeric_feature=feature,
                                        categorical_feature=target_feature)
            elif anove_use and is_homogeneous_variances == False:
                perform_welch_anova(df=df, numeric_feature=feature, categorical_feature=target_feature)
            else:
                perform_kruskal_test(df=df, categorical_feature=target_feature,
                        numeric_feature=feature)
    else:
        if non_normal_detected == True:
            cal_mannwhitneyu(dataframe=df, categorical_feature=target_feature, num_feature=feature)
        else:
            anove_use, is_homogeneous_variances = check_homogeneity_of_variance(df=df, feature=feature,
                                                                                target_feature=target_feature)
            if anove_use and is_homogeneous_variances:
                t_test_with_cohens_d(data=df, categorical_feature=target_feature, num_feature=feature, equal_var=True)
            elif anove_use and is_homogeneous_variances == False:
                t_test_with_cohens_d(data=df, categorical_feature=target_feature, num_feature=feature, equal_var=False)
            else:
                cal_mannwhitneyu(dataframe=df, categorical_feature=target_feature, num_feature=feature)

def plot_numerical_distribution(feature: str, df: pd.DataFrame = df_HR_Attrition,
                                target_feature: str = Config.target_feature, order: list = None) -> None:
    """
    Perform statistical testing and visualize the distribution of a numerical feature 
    across different classes of the target variable using violin plots and summary statistics.

    The function executes:
      1. Statistical tests.
      2. Summary table with mean, median, std per category.
      3. Violin plot for visualizing feature distributions across classes.

    Args:
        feature (str): The name of the numerical feature to analyze.
        df (pd.DataFrame): Input dataframe containing numerical & target features.
        target_feature (str): Target variable name (categorical feature).
        order (list, optional): Custom ordering for category display in the plot.

    Returns:
        None: Displays statistical summaries and plots directly.
    """

    # Compute summary statistics for each Fertilizer category
    df_summary_feature = (
        df.groupby(by=target_feature, as_index=False)
        .agg(
            Count=(feature, "count"),
            Mean=(feature, "mean"),
            Median=(feature, "median"),
            Std=(feature, "std")
        )
        .sort_values(by="Mean", ascending=False).reset_index(drop=True)
    )

    # Compute global statistics for the entire feature
    summary_data = [
        ("Overall Mean", f"{df[feature].mean():.2f}"),
        ("Overall Median", f"{df[feature].median()}"),
        ("Overall Std", f"{df[feature].std():.2f}")
    ]

    # Display overall statistics in HTML format for better notebook visualization
    summary_html = "<ul>" + "".join([
        f"<li><b>{k}:</b> {v}</li>" for k, v in summary_data
    ]) + "</ul>"
    display(HTML(summary_html))

    # Display detailed summary per category as styled dataframe
    display(
        df_summary_feature.style.background_gradient(cmap=cm)
        .set_table_attributes('style="width:75%; margin:auto;"')
    )

    # Run statistical significance testing
    perform_statical_testing(feature=feature, target_feature=target_feature)

    # Visualize distribution via violin plot
    plt.figure(figsize=(10, 6))
    sns.violinplot(x=target_feature, y=feature, data=df, hue=target_feature, order=order,
                   palette=color(n_colors=df[target_feature].nunique(), tone="diverging"))
    
    plt.title(f"Violin plot of {feature} distribution by {target_feature}", pad=15, weight="bold", fontsize=12)
    # plt.xlabel(target_feature, labelpad=10)
    plt.ylabel(feature, labelpad=10)
    plt.legend().remove()
    sns.despine(left=False, bottom=False)
    plt.tight_layout()
    plt.show()

for feature in num_features:
    display(HTML(f"<h2 style='text-align:center; font-size:22px; color:blue;'><b>Distribution of {feature} by {Config.target_feature}</b></h2>"))
    plot_numerical_distribution(feature=feature, df = df_HR_Attrition)
# Out:
# <h2 style='text-align:center; font-size:22px; color:blue;'><b>Distribution of Age by Attrition</b></h2>
# <ul><li><b>Overall Mean:</b> 36.92</li><li><b>Overall Median:</b> 36.0</li><li><b>Overall Std:</b> 9.14</li></ul>
# <style type="text/css">
# #T_b29e0_row0_col0, #T_b29e0_row0_col4, #T_b29e0_row1_col1, #T_b29e0_row1_col2, #T_b29e0_row1_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_b29e0_row0_col1, #T_b29e0_row0_col2, #T_b29e0_row0_col3, #T_b29e0_row1_col0, #T_b29e0_row1_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b29e0" style="width:75%; margin:auto;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b29e0_level0_col0" class="col_heading level0 col0" >Attrition</th>
#       <th id="T_b29e0_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_b29e0_level0_col2" class="col_heading level0 col2" >Mean</th>
# ...

# %% [markdown]
# ### Numerical Features — Attrition
#
# **Age**
#
# * Employees who left tend to be **younger** than those who stayed.
#
# **DailyRate**
#
# * Statistically different but **negligible effect** → salary (daily rate) is **not a key driver** of attrition.
#
# **DistanceFromHome**
#
# * Leavers generally live **farther from the workplace** → long commute may slightly contribute to attrition.
#
# **HourlyRate**
#
# * **No meaningful difference** between groups.
#
# **MonthlyIncome**
#
# * Strong pattern: **lower income strongly associated with higher attrition**.
#
# **MonthlyRate**
#
# * **No significant impact** on turnover.
#
# **PercentSalaryHike**
#
# * **No effect** on attrition; salary raises alone do not influence retention.
#
# **TotalWorkingYears**
#
# * Employees with **fewer years of experience** are more likely to leave.
#
# **YearsAtCompany**
#
# * **Shorter company tenure** → higher likelihood of resigning.
#
# **YearsInCurrentRole**
#
# * Employees with **shorter role duration** tend to leave more.
#
# **YearsSinceLastPromotion**
#
# * Those **recently promoted** show higher attrition — may indicate unmet expectations or transitional stress.
#
# **YearsWithCurrManager**
#
# * Shorter time with current manager → **higher attrition risk**, suggesting the importance of manager–employee relationship.

# %%
def bivariate_percent_plot(cat, target_feature, df, figsize=(15, 6), order=None):
    display(HTML(f"<h2 style='text-align:center; font-size:22px; color:blue;'><b>Distribution of {cat} by {target_feature}</b></h2>"))
    fig, ax = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=figsize)

    # Data processing
    grouped = df.groupby([cat, target_feature]).size().unstack(fill_value=0)

    # Define a fixed hue order (adjust if needed)
    target_order = [c for c in ["Attrition Employees", "Working Employees"] if c in grouped.columns]

    # Fallback if the labels are 0/1 or have different names
    if not target_order:
        target_order = list(grouped.columns)

    # Calculate percentages row-wise and reorder columns by target_order
    percentages = grouped.div(grouped.sum(axis=1), axis=0)[target_order] * 100

    # Define X-axis category order
    if order is not None:
        percentages = percentages.loc[order]
        labels = order
    else:
        labels = percentages.index.tolist()

    # Consistent color palette for both charts
    base_colors = color(n_colors=len(target_order), tone="diverging")
    color_map = dict(zip(target_order, base_colors))

    # Plot 1: Stacked bar chart (percentage)
    bottom = np.zeros(len(percentages))
    for cls in target_order:
        ax[0].bar(percentages.index, percentages[cls].values, bottom=bottom,
                  label=cls, color=color_map[cls])
        bottom += percentages[cls].values

    # Add percentage labels
    for container in ax[0].containers:
        ax[0].bar_label(container, fmt="%1.0f%%", label_type="center",
                        fontsize=10, color="black")
    rot = 0
    if cat in ["JobRole", "EducationField"]:
        rot = 45

    ax[0].set_title(f"Attrition Rate Across {cat.replace('_', ' ').title()}", fontsize=12, weight="bold", pad=15)
    ax[0].set_xlabel("")
    ax[0].set_ylabel(f"% {target_feature} Rate", fontsize=10)
    sns.despine(left=False, bottom=False, ax=ax[0])
    ax[0].legend().remove()
    ax[0].set_xticklabels(labels = labels, rotation = rot)

    # Plot 2: Count plot (using same color_map + hue_order)
    sns.countplot(data=df, hue=target_feature, x=cat,
                  order=labels, hue_order=target_order,
                  palette=color_map, ax=ax[1])

    for container in ax[1].containers:
        ax[1].bar_label(container, fmt="%d", label_type="edge",
                        fontsize=10, color="black")

    if cat in ["JobRole", "EducationField"]:
        ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=rot)

    ax[1].set_title(f"Customer Count by {cat.replace('_', ' ').title()} and Attrition Status", fontsize=12, weight="bold", pad=15)
    ax[1].set_xlabel("")
    ax[1].set_ylabel("Frequency", fontsize=10)
    ax[1].legend(title=target_feature, bbox_to_anchor=(1.05, 1), loc="upper left")
    sns.despine(left=False, bottom=False, ax=ax[1])

    plt.tight_layout()
    plt.show()

    # Chi-Square Test
    cal_ChiSquare(cat_feature=cat, target_feature=target_feature, df=df, show_residuals=True)

# Run for all categorical features
for feature in cat_features:
    bivariate_percent_plot(cat=feature, target_feature=Config.target_feature, df=df_HR_Attrition)
# Out:
# <h2 style='text-align:center; font-size:22px; color:blue;'><b>Distribution of BusinessTravel by Attrition</b></h2>
# [i] Chi-Square Test of Independence: 'BusinessTravel' vs. 'Attrition'...
# [i] Chi-squared statistic: 24.182
# [i] Degrees of freedom: 2
# [i] p-value: 0.000006
# [✓] Result: p-value < 0.05 → Reject H₀
# [✓] Variables 'BusinessTravel' and 'Attrition' are statistically associated.
#
# [i] Standardized Residuals:
# Attrition             0     1
# BusinessTravel
# Non-Travel         1.09 -2.48
# Travel_Frequently -1.60  3.64
# Travel_Rarely      0.41 -0.94
# <h2 style='text-align:center; font-size:22px; color:blue;'><b>Distribution of Department by Attrition</b></h2>
# [i] Chi-Square Test of Independence: 'Department' vs. 'Attrition'...
# [i] Chi-squared statistic: 10.796
# [i] Degrees of freedom: 2
# [i] p-value: 0.004526
# [✓] Result: p-value < 0.05 → Reject H₀
# [✓] Variables 'Department' and 'Attrition' are statistically associated.
#
# [i] Standardized Residuals:
# ...

# %% [markdown]
# ### Categorical Features — Attrition Insights
#
# **BusinessTravel**
#
# * Frequent travelers show **highest attrition** → travel burden likely contributes to turnover.
#
# **Department**
#
# * **Sales** has higher-than-expected attrition; **R&D** shows stronger retention.
#
# **Education**
#
# * No significant relationship with attrition.
#
# **EducationField**
#
# * HR, Technical Degree, and Marketing fields show **higher attrition** than expected.
#
# **EnvironmentSatisfaction**
#
# * **Low satisfaction** strongly correlates with higher turnover; **very high satisfaction** supports retention.
#
# **Gender**
#
# * No significant difference between males and females.
#
# **JobInvolvement**
#
# * **Low involvement** → highest attrition; **very high involvement** → strong retention.
#
# **JobLevel**
#
# * **Level 1** employees most likely to leave; higher levels show lower attrition.
#
# **JobRole**
#
# * **Sales Representative** and **Laboratory Technician** have highest attrition.
# * **Research Director** shows exceptionally strong retention.
#
# **JobSatisfaction**
#
# * **Low satisfaction** → high attrition; **very high satisfaction** → strong retention.
#
# **MaritalStatus**
#
# * **Single** employees are far more likely to resign; **Divorced** employees show highest retention.
#
# **OverTime**
#
# * Employees working overtime have **very high attrition**; non-overtime employees show strong retention.
#
# **PerformanceRating**
#
# * No significant effect on attrition.
#
# **RelationshipSatisfaction**
#
# * Not statistically significant, but **Low satisfaction** suggests a slight upward trend in attrition.
#
# **StockOptionLevel**
#
# * **Basic** stock option level shows highest attrition; **Advanced** and **Standard** show strong retention.
#
# **WorkLifeBalance**
#
# * **Bad balance** → highest attrition; **Better** balance → lower-than-expected attrition.
#
# **TrainingTimesLastYear**
#
# * Employees with no training show the highest attrition, while moderate training **(1–3 sessions)** aligns with better retention.
#
# **NumCompaniesWorked**
#
# * Employees with a history of switching companies (1, 5, or more past employers) show higher attrition, reflecting stronger job-hopping tendencies.

# %% [markdown]
# ### Overall Picture

# %% [markdown]
# | **Feature**                  | **Summary**                                                                                                                                |
# | ---------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------ |
# | **BusinessTravel**           | Frequent travelers show **much higher attrition**, suggesting travel strain is a relevant turnover driver.                                 |
# | **Department**               | **Sales** shows elevated attrition while **R&D** retains employees better → functional differences meaningfully impact turnover.           |
# | **Education**                | No significant effect → education level is **not a meaningful discriminator** of attrition.                                                |
# | **EducationField**           | HR, Technical Degree, and Marketing show **higher attrition**, indicating field-specific dissatisfaction or mismatch.                      |
# | **EnvironmentSatisfaction**  | Strong pattern: **low satisfaction → high attrition**, while very high satisfaction supports retention.                                    |
# | **Gender**                   | No practical difference → **not a relevant predictor** of attrition.                                                                       |
# | **JobInvolvement**           | **Low involvement** is a strong attrition indicator; very high involvement aligns with retention.                                          |
# | **JobLevel**                 | **Level 1** employees have the highest attrition → job seniority meaningfully differentiates retention.                                    |
# | **JobRole**                  | Sales Reps & Lab Technicians show **highest attrition**; Research Directors are **highly stable** → role strongly shapes turnover risk.    |
# | **JobSatisfaction**          | Clear pattern: **low satisfaction → high attrition**, very high satisfaction → better retention.                                           |
# | **MaritalStatus**            | **Single** employees show substantially higher attrition; divorced employees show the strongest retention pattern.                         |
# | **OverTime**                 | One of the strongest categorical predictors — overtime workers have **very high attrition**.                                               |
# | **PerformanceRating**        | No meaningful difference → performance ratings **do not discriminate** attrition.                                                          |
# | **RelationshipSatisfaction** | Statistically weak, but **low satisfaction shows a mild upward attrition trend**.                                                          |
# | **StockOptionLevel**         | **Basic** stock option users are most likely to quit; **Advanced/Standard** groups show strong retention → compensation structure matters. |
# | **WorkLifeBalance**          | **Bad balance** strongly elevates attrition; better balance supports retention.                                                            |
# | **TrainingTimesLastYear**    | No training → highest attrition; **moderate training (1–3 sessions)** aligns with retention.                                               |
# | **NumCompaniesWorked**       | Job-hopping history (1, 5, or more companies) correlates with higher attrition → reflects mobility tendencies.                             |
# | **Age**                      | Leavers tend to be **younger**, making age a modest but meaningful differentiator.                                                         |
# | **DailyRate**                | Statistical difference but **negligible effect** → not a practical indicator of attrition.                                                 |
# | **DistanceFromHome**         | Slight pattern: leavers live **farther away**, but effect size is small.                                                                   |
# | **HourlyRate**               | No meaningful difference → **not useful** for attrition prediction.                                                                        |
# | **MonthlyIncome**            | Strong and consistent signal: **lower income → higher attrition**.                                                                         |
# | **MonthlyRate**              | No real effect on attrition.                                                                                                               |
# | **PercentSalaryHike**        | Not predictive — raises alone **do not influence** turnover.                                                                               |
# | **TotalWorkingYears**        | Employees with **less experience** show higher attrition; useful moderate predictor.                                                       |
# | **YearsAtCompany**           | **Short tenure** strongly linked to attrition → early-stage retention is critical.                                                         |
# | **YearsInCurrentRole**       | Shorter role duration increases attrition; role stability supports retention.                                                              |
# | **YearsSinceLastPromotion**  | Recently promoted employees show higher attrition — possibly unmet expectations or transitional pressure.                                  |
# | **YearsWithCurrManager**     | Less time with current manager correlates with higher attrition → manager relationship plays a meaningful role.                            |

# %% [markdown]
# ## Some Questions

# %%
df_bq = df_HR_Attrition.copy()

# %% [markdown]
# ### Do lower-income employees within the same job role resign more frequently?

# %%
def monthly_income_group(x):
    if x <= 5000:
        return "Low Income"
    elif x <= 10000:
        return "Lower-Mid Income"
    elif x <= 15000:
        return "Upper-Mid Income"
    else:
        return "High Income"

df_bq["MonthlyIncomeGroup"] = df_bq["MonthlyIncome"].apply(monthly_income_group)

print("[i] Computing percentage table by Monthly Income Group × Job Role...")
df_group = pd.crosstab(
    [df_bq["MonthlyIncomeGroup"], df_bq["JobRole"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (Monthly Income Group × Job Role) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["MonthlyIncomeGroup"], df_bq["JobRole"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(13,8))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: Monthly Income Group or Job Role vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("Monthly Income Group - Job Role | Attrition")
plt.xlabel("")
plt.text(2, 23, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by Monthly Income Group × Job Role...
# Attrition                                              0          1
# MonthlyIncomeGroup JobRole
# High Income        Manager                     96.511628   3.488372
#                    Research Director           95.744681   4.255319
# Low Income         Healthcare Representative   95.000000   5.000000
#                    Human Resources             72.222222  27.777778
#                    Laboratory Technician       74.786325  25.213675
#                    Manufacturing Director      90.625000   9.375000
#                    Research Scientist          82.330827  17.669173
#                    Sales Executive             87.500000  12.500000
#                    Sales Representative        59.259259  40.740741
# Lower-Mid Income   Healthcare Representative   92.771084   7.228916
#                    Human Resources             92.857143   7.142857
# ...

# %% [markdown]
# **Analysis:** <br>
# Lower-income employees consistently exhibit higher-than-expected attrition across multiple job roles, while higher-income employees tend to show strong retention — confirming income as a key turnover differentiator within roles.

# %% [markdown]
# ### Are certain roles underpaid relative to their experience or workload?

# %%
def total_working_years_bin(x):
    if x <= 3:
        return "Entry-Level"
    elif x <= 7:
        return "Early Career"
    elif x <= 15:
        return "Mid Career"
    elif x <= 25:
        return "Senior Career"
    else:
        return "Late Career"

df_bq["TotalWorkingYearsGroup"] = df_bq["TotalWorkingYears"].apply(total_working_years_bin)

print("[i] Computing percentage table by Total Working Years Group × Monthly Income Group × Job Role...")
df_group = pd.crosstab(
    [df_bq["MonthlyIncomeGroup"], df_bq["JobRole"], df_bq["TotalWorkingYearsGroup"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (Total Working Years Group × Monthly Income Group × Job Role) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["MonthlyIncomeGroup"], df_bq["JobRole"], df_bq["TotalWorkingYearsGroup"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,20))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: Total Working Years Group or Monthly Income Group or Job Role vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("Total Working Years Group - Monthly Income Group - Job Role | Attrition")
plt.xlabel("")
plt.text(2, 70, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by Total Working Years Group × Monthly Income Group × Job Role...
# Attrition                                                             0  \
# MonthlyIncomeGroup JobRole           TotalWorkingYearsGroup
# High Income        Manager           Late Career              95.454545
#                                      Mid Career              100.000000
#                                      Senior Career            97.560976
#                    Research Director Late Career              94.736842
#                                      Mid Career              100.000000
# ...                                                                 ...
# Upper-Mid Income   Research Director Mid Career              100.000000
#                                      Senior Career           100.000000
#                    Sales Executive   Late Career              83.333333
#                                      Mid Career               66.666667
# ...

# %% [markdown]
# **Analysis:**
#
# Several roles — especially Sales Representative, Laboratory Technician, and HR (Entry–Early Career) — show strong evidence of being underpaid relative to their experience, as seen by significantly higher-than-expected attrition in lower-income groups.

# %% [markdown]
# ### Is attrition highest among employees who work overtime **and** report poor work–life balance?

# %%
summary = (
    df_bq.groupby(["OverTime","WorkLifeBalance"])["Attrition"]
      .agg(["sum","count","mean"])
      .rename(columns={"sum":"Attrition_Count","count":"Total","mean":"Attrition_Rate"})
)
summary["Attrition_Rate"] = summary["Attrition_Rate"] * 100
print(summary)

heatmap_data = summary.reset_index().pivot(
    index="WorkLifeBalance",
    columns="OverTime",
    values="Attrition_Rate"
)

plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap=cmap, linewidths=0.5, cbar_kws={"label": "Attrition Rate (%)"})
plt.title("Attrition Rate by OverTime & Work-Life Balance", fontsize=12, pad=15, weight="bold")
plt.xlabel("OverTime")
plt.ylabel("Work-Life Balance")
plt.tight_layout()
plt.show()
# Out:
#                           Attrition_Count  Total  Attrition_Rate
# OverTime WorkLifeBalance
# No       Bad                           15     58       25.862069
#          Best                          15    117       12.820513
#          Better                        54    639        8.450704
#          Good                          26    240       10.833333
# Yes      Bad                           10     22       45.454545
#          Best                          12     36       33.333333
#          Better                        73    254       28.740157
#          Good                          32    104       30.769231

# %% [markdown]
# **Analysis:**
#
# Attrition is highest among employees who work overtime and report poor work–life balance (Bad), with a turnover rate of 45.45%—the highest across all OverTime × WorkLifeBalance groups. This indicates that the combination of heavy workload and poor work–life balance represents the greatest risk factor for employee attrition.

# %% [markdown]
# ### Does overtime impact attrition differently across work–life balance categories?

# %% [markdown]
# **Analysis:**
#
# **No clear evidence suggests that overtime impacts attrition *differently* across work–life balance categories.**
# While employees with both *overtime* and *poor work–life balance (Bad)* show the highest attrition rate (45.45%), **the relative increase in attrition due to overtime is fairly similar across all work–life balance groups.**
#
# **Key observations from the data:**
#
# | Work–Life Balance | Attrition OT = No | Attrition OT = Yes | Increase (percentage points) |
# | ----------------- | ----------------- | ------------------ | ---------------------------- |
# | Bad               | 25.86%            | 45.45%             | **+19.59 pp**                |
# | Good              | 10.83%            | 30.77%             | **+19.94 pp**                |
# | Better            | 8.45%             | 28.74%             | **+20.29 pp**                |
# | Best              | 12.82%            | 33.33%             | **+20.51 pp**                |
#
#
# * Overtime consistently increases attrition by **~19–21 percentage points**, regardless of the work–life balance category.
# * The *absolute risk* is highest in the “Bad” group (45.45%), but The *effect of overtime itself* is **similar in size across all groups**.
#
# > **Overtime raises attrition substantially, but the magnitude of its impact does not differ meaningfully across work–life balance categories. Overtime is a strong predictor of attrition in every WLB group, not only in the “Bad” group.**

# %% [markdown]
# ### Are younger employees with fewer working years more likely to leave than older employees with similar experience?

# %%
def age_group_bin(x):
    if x < 30:
        return "18-29 Young Adult"
    elif x < 40:
        return "30-39 Adult"
    elif x < 50:
        return "40-49 Mature Adult"
    else:
        return "50-60 Senior Adult"

df_bq["AgeGroup"] = df_bq["Age"].apply(age_group_bin)

summary = (
    df_bq.groupby(["AgeGroup","TotalWorkingYearsGroup"])["Attrition"]
      .agg(["sum","count","mean"])
      .rename(columns={"sum":"Attrition_Count","count":"Total","mean":"Attrition_Rate"})
)
summary["Attrition_Rate"] = summary["Attrition_Rate"] * 100
print(summary)

heatmap_data = summary.reset_index().pivot(
    index="AgeGroup",
    columns="TotalWorkingYearsGroup",
    values="Attrition_Rate"
)

plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap=cmap, linewidths=0.5, cbar_kws={"label": "Attrition Rate (%)"})
plt.title("Attrition Rate by AgeGroup & TotalWorkingYearsGroup", fontsize=12, pad=15, weight="bold")
plt.ylabel("Age Group")
plt.xlabel("Total Working Years")
plt.tight_layout()
plt.show()
# Out:
#                                            Attrition_Count  Total  \
# AgeGroup           TotalWorkingYearsGroup
# 18-29 Young Adult  Early Career                         34    152
#                    Entry-Level                          45    105
#                    Mid Career                           12     69
# 30-39 Adult        Early Career                         22    146
#                    Entry-Level                          16     53
#                    Mid Career                           42    345
#                    Senior Career                         9     78
# 40-49 Mature Adult Early Career                          8     45
#                    Entry-Level                           0      3
#                    Late Career                           2     28
#                    Mid Career                           15    142
#                    Senior Career                         9    131
# 50-60 Senior Adult Early Career                          4     14
# ...

# %% [markdown]
# **Analysis:**
#
# Younger employees with low total working years show the highest attrition rates, especially at the Entry-Level stage. Older employees with the same level of experience are much more likely to stay. This suggests that age amplifies early-career instability — young employees are more mobile, less committed, and more responsive to job dissatisfaction compared to their older counterparts.

# %% [markdown]
# ### Does age moderate the relationship between experience and attrition?

# %%
print("[i] Computing percentage table by Age Group × Total Working Years Group...")
# df_bq_attrition_only = df_bq[df_bq["Attrition"] == 1].copy()
df_group = pd.crosstab(
    [df_bq["AgeGroup"], df_bq["TotalWorkingYearsGroup"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (Age Group × Total Working Years Group) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["AgeGroup"], df_bq["TotalWorkingYearsGroup"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,15))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: Age Group or Total Working Years Group vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("Age Group - Total Working Years Group | Attrition")
plt.xlabel("")
plt.text(2, 18, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by Age Group × Total Working Years Group...
# Attrition                                           0          1
# AgeGroup           TotalWorkingYearsGroup
# 18-29 Young Adult  Early Career             77.631579  22.368421
#                    Entry-Level              57.142857  42.857143
#                    Mid Career               82.608696  17.391304
# 30-39 Adult        Early Career             84.931507  15.068493
#                    Entry-Level              69.811321  30.188679
#                    Mid Career               87.826087  12.173913
#                    Senior Career            88.461538  11.538462
# 40-49 Mature Adult Early Career             82.222222  17.777778
#                    Entry-Level             100.000000   0.000000
#                    Late Career              92.857143   7.142857
#                    Mid Career               89.436620  10.563380
#                    Senior Career            93.129771   6.870229
# ...

# %% [markdown]
# **Analysis:**
#
# * Age significantly moderates the relationship between experience and attrition.
# * Younger employees with low working years exhibit much higher-than-expected attrition, while older employees with similar experience show stable retention.
# * As experience increases, the influence of age diminishes, indicating that age moderates attrition primarily at early career stages.

# %% [markdown]
# ### Do employees with low job involvement and low/no training show higher attrition?

# %%
summary = (
    df_bq.groupby(["JobInvolvement","TrainingTimesLastYear"])["Attrition"]
      .agg(["sum","count","mean"])
      .rename(columns={"sum":"Attrition_Count","count":"Total","mean":"Attrition_Rate"})
)
summary["Attrition_Rate"] = summary["Attrition_Rate"] * 100
print(summary)

heatmap_data = summary.reset_index().pivot(
    index="JobInvolvement",
    columns="TrainingTimesLastYear",
    values="Attrition_Rate"
)

plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap=cmap, linewidths=0.5, cbar_kws={"label": "Attrition Rate (%)"})
plt.title("Attrition Rate by JobInvolvement & TrainingTimesLastYear", fontsize=12, pad=15, weight="bold")
plt.ylabel("JobInvolvement")
plt.xlabel("TrainingTimesLastYear")
plt.tight_layout()
plt.show()
# Out:
#                                       Attrition_Count  Total  Attrition_Rate
# JobInvolvement TrainingTimesLastYear
# High           0                                    8     31       25.806452
#                1                                    3     43        6.976744
#                2                                   51    315       16.190476
#                3                                   38    290       13.103448
#                4                                   15     78       19.230769
#                5                                    8     69       11.594203
#                6                                    2     42        4.761905
# Low            0                                    0      0             NaN
#                1                                    1      2       50.000000
#                2                                   12     36       33.333333
#                3                                    8     24       33.333333
# ...

# %% [markdown]
# **Analysis:**
#
# Yes. Employees with low job involvement and little/no training show the highest attrition rates. Attrition peaks at 50% among Low-Involvement staff with zero training, while employees with high involvement remain stable even with minimal training. This suggests that training is most critical for disengaged employees.

# %% [markdown]
# ### Do lower-level employees who haven't been promoted recently exit at higher rates than senior employees?

# %%
def YearsSinceLastPromotion_bin(x):
    if x == 0:
        return "Recently Promoted"
    elif x in [1, 3]:
        return "Moderate Wait"
    elif x in [4, 7]:
        return "Extended Wait"
    else:
        return "Long Wait"

df_bq["YearsSinceLastPromotionGroup"] = df_bq["YearsSinceLastPromotion"].apply(YearsSinceLastPromotion_bin)

summary = (
    df_bq.groupby(["JobLevel","YearsSinceLastPromotionGroup"])["Attrition"]
      .agg(["sum","count","mean"])
      .rename(columns={"sum":"Attrition_Count","count":"Total","mean":"Attrition_Rate"})
)
summary["Attrition_Rate"] = summary["Attrition_Rate"] * 100
print(summary)

heatmap_data = summary.reset_index().pivot(
    index="JobLevel",
    columns="YearsSinceLastPromotionGroup",
    values="Attrition_Rate"
)

plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap=cmap, linewidths=0.5, cbar_kws={"label": "Attrition Rate (%)"})
plt.title("Attrition Rate by JobLevel & YearsSinceLastPromotionGroup", fontsize=12, pad=15, weight="bold")
plt.ylabel("JobLevel")
plt.xlabel("YearsSinceLastPromotionGroup")
plt.tight_layout()
plt.show()
# Out:
#                                        Attrition_Count  Total  Attrition_Rate
# JobLevel YearsSinceLastPromotionGroup
# 1        Extended Wait                               7     26       26.923077
#          Long Wait                                  23    102       22.549020
#          Moderate Wait                              35    155       22.580645
#          Recently Promoted                          78    260       30.000000
# 2        Extended Wait                               6     54       11.111111
#          Long Wait                                  11     99       11.111111
#          Moderate Wait                              13    167        7.784431
#          Recently Promoted                          22    214       10.280374
# 3        Extended Wait                               8     32       25.000000
#          Long Wait                                   8     70       11.428571
#          Moderate Wait                               7     47       14.893617
# ...

# %% [markdown]
# **Analysis:**
#
# Attrition rates are significantly higher among lower-level employees, especially those who have not been promoted for extended periods. In contrast, senior employees maintain very low attrition regardless of promotion timing, indicating that promotion delays primarily impact junior staff retention.

# %% [markdown]
# ### Do lower-paid employees with long commutes leave more often?

# %%
def distance_bin(x):
    if x <= 5:
        return "1-5 Very Close"
    elif x <= 10:
        return "6-10 Close"
    elif x <= 15:
        return "11-15 Medium"
    elif x <= 20:
        return "16-20 Far"
    else:
        return "21-29 Very Far"

df_bq["DistanceGroup"] = df_bq["DistanceFromHome"].apply(distance_bin)

print("[i] Computing percentage table by Monthly Income Group × Distance Group...")
df_group = pd.crosstab(
    [df_bq["MonthlyIncomeGroup"], df_bq["DistanceGroup"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (Monthly Income Group × Distance Group) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["MonthlyIncomeGroup"], df_bq["DistanceGroup"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,15))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: Monthly Income Group or Distance Group vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("Monthly Income Group - Distance Group | Attrition")
plt.xlabel("")
plt.text(2, 21, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by Monthly Income Group × Distance Group...
# Attrition                                   0          1
# MonthlyIncomeGroup DistanceGroup
# High Income        1-5 Very Close   94.736842   5.263158
#                    11-15 Medium     91.666667   8.333333
#                    16-20 Far       100.000000   0.000000
#                    21-29 Very Far  100.000000   0.000000
#                    6-10 Close      100.000000   0.000000
# Low Income         1-5 Very Close   80.250784  19.749216
#                    11-15 Medium     76.666667  23.333333
#                    16-20 Far        72.307692  27.692308
#                    21-29 Very Far   74.000000  26.000000
#                    6-10 Close       79.512195  20.487805
# Lower-Mid Income   1-5 Very Close   92.349727   7.650273
#                    11-15 Medium     79.411765  20.588235
#                    16-20 Far        89.130435  10.869565
#                    21-29 Very Far   76.666667  23.333333
# ...

# %%
summary = (
    df_bq.groupby(["DistanceGroup","MonthlyIncomeGroup"])["Attrition"]
      .agg(["sum","count","mean"])
      .rename(columns={"sum":"Attrition_Count","count":"Total","mean":"Attrition_Rate"})
)
summary["Attrition_Rate"] = summary["Attrition_Rate"] * 100
print(summary)

heatmap_data = summary.reset_index().pivot(
    index="DistanceGroup",
    columns="MonthlyIncomeGroup",
    values="Attrition_Rate"
)

plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap=cmap, linewidths=0.5, cbar_kws={"label": "Attrition Rate (%)"})
plt.title("Attrition Rate by DistanceGroup & MonthlyIncomeGroup", fontsize=12, pad=15, weight="bold")
plt.ylabel("DistanceGroup")
plt.xlabel("MonthlyIncomeGroup")
plt.tight_layout()
plt.show()
# Out:
#                                    Attrition_Count  Total  Attrition_Rate
# DistanceGroup  MonthlyIncomeGroup
# 1-5 Very Close High Income                       4     76        5.263158
#                Low Income                       63    319       19.749216
#                Lower-Mid Income                 14    183        7.650273
#                Upper-Mid Income                  6     54       11.111111
# 11-15 Medium   High Income                       1     12        8.333333
#                Low Income                       14     60       23.333333
#                Lower-Mid Income                  7     34       20.588235
#                Upper-Mid Income                  3      9       33.333333
# 16-20 Far      High Income                       0      4        0.000000
#                Low Income                       18     65       27.692308
#                Lower-Mid Income                  5     46       10.869565
# ...

# %% [markdown]
# **Analysis:**
#
# Both the attrition rate and standardized residual heatmaps show that lower-paid employees with long commutes are significantly more likely to leave. Residuals above +2 indicate this pattern is statistically meaningful, while high-income groups consistently show lower-than-expected attrition across all distances.

# %% [markdown]
# ### Is commute distance a stronger attrition factor for certain income groups?

# %% [markdown]
# **Analysis:**
#
# Yes. Commute distance is a much stronger attrition factor for low-income employees. Their attrition increases significantly with longer travel distances, while high-income employees show very low and stable attrition across all distance ranges.

# %% [markdown]
# ### Do employees with both low environment satisfaction and low relationship satisfaction have the highest attrition?

# %%
summary = (
    df_bq.groupby(["EnvironmentSatisfaction","RelationshipSatisfaction"])["Attrition"]
      .agg(["sum","count","mean"])
      .rename(columns={"sum":"Attrition_Count","count":"Total","mean":"Attrition_Rate"})
)
summary["Attrition_Rate"] = summary["Attrition_Rate"] * 100
print(summary)

heatmap_data = summary.reset_index().pivot(
    index="EnvironmentSatisfaction",
    columns="RelationshipSatisfaction",
    values="Attrition_Rate"
)

plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap=cmap, linewidths=0.5, cbar_kws={"label": "Attrition Rate (%)"})
plt.title("Attrition Rate by EnvironmentSatisfaction & RelationshipSatisfaction", fontsize=12, pad=15, weight="bold")
plt.ylabel("EnvironmentSatisfaction")
plt.xlabel("RelationshipSatisfaction")
plt.tight_layout()
plt.show()
# Out:
#                                                   Attrition_Count  Total  \
# EnvironmentSatisfaction RelationshipSatisfaction
# High                    High                                   23    150
#                         Low                                    13     83
#                         Medium                                 10     91
#                         Very High                              16    129
# Low                     High                                   20     86
#                         Low                                    18     58
#                         Medium                                 16     52
#                         Very High                              18     88
# Medium                  High                                   14     83
#                         Low                                     9     57
#                         Medium                                  7     63
# ...

# %%
print("[i] Computing percentage table by EnvironmentSatisfaction × RelationshipSatisfaction...")
df_group = pd.crosstab(
    [df_bq["EnvironmentSatisfaction"], df_bq["RelationshipSatisfaction"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (EnvironmentSatisfaction × RelationshipSatisfaction) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["EnvironmentSatisfaction"], df_bq["RelationshipSatisfaction"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,15))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: EnvironmentSatisfaction or RelationshipSatisfaction vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("EnvironmentSatisfaction - RelationshipSatisfaction | Attrition")
plt.xlabel("")
plt.text(2, 17, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by EnvironmentSatisfaction × RelationshipSatisfaction...
# Attrition                                                 0          1
# EnvironmentSatisfaction RelationshipSatisfaction
# High                    High                      84.666667  15.333333
#                         Low                       84.337349  15.662651
#                         Medium                    89.010989  10.989011
#                         Very High                 87.596899  12.403101
# Low                     High                      76.744186  23.255814
#                         Low                       68.965517  31.034483
#                         Medium                    69.230769  30.769231
#                         Very High                 79.545455  20.454545
# Medium                  High                      83.132530  16.867470
#                         Low                       84.210526  15.789474
# ...

# %% [markdown]
# **Analysis:**
#
# Employees with low environment satisfaction show the highest attrition, regardless of their relationship satisfaction level. Even when they have strong coworker relationships, poor workplace environment still drives them to leave.

# %% [markdown]
# ### Which dimension (environment vs. relationships) is more influential?

# %%
print("[i] Fitting logistic regression model...")
model_two = smf.logit(
    formula=" Attrition ~ EnvironmentSatisfaction + RelationshipSatisfaction",
    data=df_bq
).fit()

print(model_two.summary())

# Compute Odds Ratios (OR)
coef = model_two.params
OR = np.exp(coef)

OR_table = pd.concat([coef, OR], axis=1)
OR_table.columns = ["coef", "OR"]

print("\n[i] Odds Ratios:")
print(OR_table)
# Out:
# [i] Fitting logistic regression model...
# Optimization terminated successfully.
#          Current function value: 0.433125
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                 1470
# Model:                          Logit   Df Residuals:                     1463
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 12 Dec 2025   Pseudo R-squ.:                 0.01940
# Time:                        22:25:25   Log-Likelihood:                -636.69
# converged:                       True   LL-Null:                       -649.29
# Covariance Type:            nonrobust   LLR p-value:                 0.0003141
# ...
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Analysis:**
#
# Low Environment Satisfaction is the strongest predictor of attrition. Employees dissatisfied with their work environment are over twice as likely to leave (OR = 2.13), whereas relationship satisfaction has a weaker and statistically insignificant effect.

# %% [markdown]
# ### Do job hoppers (worked at many companies) leave more often in certain roles (e.g., Sales)?

# %%
print("[i] Computing percentage table by NumCompaniesWorked × JobRole...")
df_group = pd.crosstab(
    [df_bq["NumCompaniesWorked"], df_bq["JobRole"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (NumCompaniesWorked × JobRole) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["NumCompaniesWorked"], df_bq["JobRole"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,20))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: NumCompaniesWorked or JobRole vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("NumCompaniesWorked - JobRole | Attrition")
plt.xlabel("")
plt.text(2, 90, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by NumCompaniesWorked × JobRole...
# Attrition                                              0          1
# NumCompaniesWorked JobRole
# 0                  Healthcare Representative   94.444444   5.555556
#                    Human Resources             72.727273  27.272727
#                    Laboratory Technician       91.176471   8.823529
#                    Manager                    100.000000   0.000000
#                    Manufacturing Director      90.000000  10.000000
# ...                                                  ...        ...
# 9                  Manager                    100.000000   0.000000
#                    Manufacturing Director     100.000000   0.000000
#                    Research Director          100.000000   0.000000
#                    Research Scientist          54.545455  45.454545
#                    Sales Executive             62.500000  37.500000
#
# [89 rows x 2 columns]
# ...

# %% [markdown]
# **Analysis:**
#
# Yes. Job hoppers leave significantly more often in certain roles — especially Sales Representative — where standardized residuals exceed +2 to +4. In contrast, roles like HR, Manager, and Healthcare Representative show no elevated attrition among job hoppers. This suggests that the impact of prior job mobility on turnover is highly role-specific, strongest in Sales, weaker or absent elsewhere.

# %% [markdown]
# ### Is job mobility role-specific?

# %% [markdown]
# **Analysis:**
#
# Job mobility is role-specific. Some roles—especially Sales Representative—show significantly higher attrition among employees with extensive job-hopping history, while other roles such as HR, Manager, or Healthcare exhibit no meaningful increase in turnover.

# %% [markdown]
# ### Do high-performing employees who work overtime still leave at elevated rates?

# %%
print("[i] Computing percentage table by OverTime × PerformanceRating...")
df_group = pd.crosstab(
    [df_bq["OverTime"], df_bq["PerformanceRating"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (OverTime × PerformanceRating) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["OverTime"], df_bq["PerformanceRating"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,7))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: OverTime or PerformanceRating vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("OverTime - PerformanceRating | Attrition")
plt.xlabel("")
plt.text(2, 4.5, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by OverTime × PerformanceRating...
# Attrition                           0          1
# OverTime PerformanceRating
# No       Excellent          89.249720  10.750280
#          Outstanding        91.304348   8.695652
# Yes      Excellent          70.370370  29.629630
#          Outstanding        64.615385  35.384615
# [i] Running Chi-Square Test for combined factors (OverTime × PerformanceRating) vs Attrition...
# [i] Chi2: 90.8129
# [i] dof: 3
# [i] p-value: 0.000000

# %% [markdown]
# **Analysis:**
#
# Yes. High-performing employees who work overtime exhibit significantly elevated attrition levels. Both Excellent and Outstanding performers show positive residuals (+7.89 and +4.32), meaning they leave far more often than expected. Meanwhile, high performers without overtime show significantly lower attrition. This suggests overtime erodes retention even among top talent.

# %% [markdown]
# ### Could excessive workload be pushing top performers out?

# %% [markdown]
# **Analysis:**
#
# Yes. The residual heatmap clearly shows that overtime dramatically increases attrition among top performers. Excellent and Outstanding employees who work overtime leave at significantly higher-than-expected rates, indicating that excessive workload is pushing top talent out.

# %% [markdown]
# ### Do employees who recently changed managers report worse work–life balance and higher attrition?

# %%
def manager_years_bin(x):
    if x <= 1:
        return "0-1 New"
    elif x <= 4:
        return "2-4 Early"
    elif x <= 8:
        return "5-8 Established"
    elif x <= 12:
        return "9-12 Long-Term"
    else:
        return "13-17 Very Long"

df_bq["YearsWithCurrManagerGroup"] = df_bq["YearsWithCurrManager"].apply(manager_years_bin)


print("[i] Computing percentage table by YearsWithCurrManagerGroup × WorkLifeBalance...")
df_group = pd.crosstab(
    [df_bq["YearsWithCurrManagerGroup"], df_bq["WorkLifeBalance"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (YearsWithCurrManagerGroup × WorkLifeBalance) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["YearsWithCurrManagerGroup"], df_bq["WorkLifeBalance"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,10))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: YearsWithCurrManagerGroup or WorkLifeBalance vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("YearsWithCurrManagerGroup - WorkLifeBalance | Attrition")
plt.xlabel("")
plt.text(2, 22, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by YearsWithCurrManagerGroup × WorkLifeBalance...
# Attrition                                           0          1
# YearsWithCurrManagerGroup WorkLifeBalance
# 0-1 New                   Bad               50.000000  50.000000
#                           Best              71.794872  28.205128
#                           Better            74.500000  25.500000
#                           Good              69.512195  30.487805
# 13-17 Very Long           Bad              100.000000   0.000000
#                           Best             100.000000   0.000000
#                           Better            94.444444   5.555556
#                           Good              90.000000  10.000000
# 2-4 Early                 Bad               77.777778  22.222222
#                           Best              86.885246  13.114754
#                           Better            86.324786  13.675214
#                           Good              88.235294  11.764706
# ...

# %% [markdown]
# **Analysis:**
#
# Yes. Employees who recently changed managers (0–1 years) show significantly higher attrition across all work–life balance levels, with extremely high positive residuals (+3.6 to +3.9). They also show strong negative residuals in the “stay” category under poor WLB, suggesting they perceive their work–life balance as worse. This indicates that manager transitions create a high-risk period for turnover.

# %% [markdown]
# ### Is managerial stability connected to better retention?

# %% [markdown]
# **Analysis:**
#
# Yes. Managerial stability is clearly linked to better retention. Employees who have been with the same manager longer show much lower attrition, while those with a new manager (0–1 year) exhibit extremely high and statistically significant turnover. This indicates manager continuity is a strong protective factor against attrition.

# %% [markdown]
# ### Are certain education fields systematically lower paid and more prone to attrition?

# %%
print("[i] Computing percentage table by EducationField × MonthlyIncomeGroup...")
df_group = pd.crosstab(
    [df_bq["EducationField"], df_bq["MonthlyIncomeGroup"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (EducationField × MonthlyIncomeGroup) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["EducationField"], df_bq["MonthlyIncomeGroup"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,10))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: EducationField or MonthlyIncomeGroup vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("EducationField - MonthlyIncomeGroup | Attrition")
plt.xlabel("")
plt.text(2, 25, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by EducationField × MonthlyIncomeGroup...
# Attrition                                     0          1
# EducationField   MonthlyIncomeGroup
# Human Resources  High Income         100.000000   0.000000
#                  Low Income           57.142857  42.857143
#                  Lower-Mid Income     85.714286  14.285714
# Life Sciences    High Income          98.245614   1.754386
#                  Low Income           79.738562  20.261438
#                  Lower-Mid Income     90.909091   9.090909
#                  Upper-Mid Income     83.928571  16.071429
# Marketing        High Income          84.615385  15.384615
#                  Low Income           74.509804  25.490196
#                  Lower-Mid Income     77.922078  22.077922
#                  Upper-Mid Income     83.333333  16.666667
# Medical          High Income          97.777778   2.222222
#                  Low Income           81.200000  18.800000
# ...

# %% [markdown]
# **Analysis:**
#
# Yes. The heatmap shows clear evidence that certain education fields—especially Technical Degree, Life Sciences, and Medical backgrounds—experience significantly higher attrition when salaries are low or lower-mid. Technical Degree employees in low-income brackets exhibit the strongest attrition signal (+4.08), suggesting they are both underpaid and highly prone to leaving. Conversely, HR shows no such pattern, indicating that the pay–attrition relationship is field-specific.

# %% [markdown]
# ### Does income explain attrition differences across fields?

# %% [markdown]
# **Analysis:**
#
# Yes. Income explains many of the attrition differences across fields. Some education fields—such as Technical Degree, Life Sciences, and Medical—show significantly higher attrition in lower-income brackets, whereas others (e.g., HR) do not. This indicates that the role of income in driving attrition varies by field.

# %% [markdown]
# ### Do younger, single employees leave more frequently?

# %%
print("[i] Computing percentage table by MaritalStatus × AgeGroup...")
df_group = pd.crosstab(
    [df_bq["MaritalStatus"], df_bq["AgeGroup"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (MaritalStatus × AgeGroup) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["MaritalStatus"], df_bq["AgeGroup"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,15))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: MaritalStatus or AgeGroup vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("MaritalStatus - AgeGroup | Attrition")
plt.xlabel("")
plt.text(2, 12.5, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by MaritalStatus × AgeGroup...
# Attrition                                 0          1
# MaritalStatus AgeGroup
# Divorced      18-29 Young Adult   84.615385  15.384615
#               30-39 Adult         89.629630  10.370370
#               40-49 Mature Adult  93.406593   6.593407
#               50-60 Senior Adult  91.666667   8.333333
# Married       18-29 Young Adult   79.230769  20.769231
#               30-39 Adult         88.541667  11.458333
#               40-49 Mature Adult  92.024540   7.975460
#               50-60 Senior Adult  88.043478  11.956522
# Single        18-29 Young Adult   58.778626  41.221374
#               30-39 Adult         78.894472  21.105528
#               40-49 Mature Adult  84.210526  15.789474
#               50-60 Senior Adult  80.000000  20.000000
# [i] Running Chi-Square Test for combined factors (MaritalStatus × AgeGroup) vs Attrition...
# [i] Chi2: 92.1309
# [i] dof: 11
# [i] p-value: 0.000000

# %% [markdown]
# **Analysis:**
#
# Yes. Younger single employees—especially those aged 18–29—exhibit the highest attrition levels, far above statistical expectations (residual +8.19). Older single groups also show elevated risk, whereas married employees consistently show lower-than-expected attrition.

# %% [markdown]
# ### Does marital status influence attrition differently across age groups?

# %% [markdown]
# **Analysis:**
#
# Yes. Marital status influences attrition differently across age groups.
# Single employees—especially those aged 18–29—show extremely high attrition risk, while older single employees show little to no elevated risk. Married and divorced employees display more stable and moderate attrition patterns across age groups. This indicates that marital status matters most for younger workers.

# %% [markdown]
# ### Is low job satisfaction more harmful for lower-level employees than for higher-level ones?

# %%
print("[i] Computing percentage table by JobSatisfaction × JobLevel...")
df_group = pd.crosstab(
    [df_bq["JobSatisfaction"], df_bq["JobLevel"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (JobSatisfaction × JobLevel) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["JobSatisfaction"], df_bq["JobLevel"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,15))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: JobSatisfaction or JobLevel vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("JobSatisfaction - JobLevel | Attrition")
plt.xlabel("")
plt.text(2, 21, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by JobSatisfaction × JobLevel...
# Attrition                         0          1
# JobSatisfaction JobLevel
# High            1         73.456790  26.543210
#                 2         87.116564  12.883436
#                 3         90.625000   9.375000
#                 4         92.857143   7.142857
#                 5         96.000000   4.000000
# Low             1         61.320755  38.679245
#                 2         87.254902  12.745098
#                 3         80.000000  20.000000
#                 4         95.238095   4.761905
#                 5         90.000000  10.000000
# Medium          1         73.148148  26.851852
#                 2         90.721649   9.278351
#                 3         86.486486  13.513514
#                 4         95.454545   4.545455
#                 5         87.500000  12.500000
# Very High       1         82.035928  17.964072
#                 2         94.767442   5.232558
# ...

# %% [markdown]
# **Analysis:**
#
# Yes. Low job satisfaction is far more harmful for lower-level employees.
# JobLevel 1 employees with low satisfaction show extremely elevated attrition (residual +6.56), while higher-level employees show minimal or no abnormal attrition under the same dissatisfaction levels. This indicates that job satisfaction is a stronger driver of turnover among lower-level staff.

# %% [markdown]
# ### Do senior employees tolerate dissatisfaction better due to income or stability?

# %% [markdown]
# **Analysis:**
#
# Yes. The heatmap shows that senior employees tolerate dissatisfaction far better than junior employees. Low job satisfaction creates extremely high attrition only at JobLevel 1, while higher-level employees show no unusual attrition under the same dissatisfaction levels. This strongly suggests that higher income and greater job stability buffer senior employees from leaving even when they are unhappy.

# %% [markdown]
# ### Do low-income employees leave even if they receive a salary hike?

# %%
def salary_hike_group(x):
    if x <= 13:
        return "Low Raise"
    elif x <= 17:
        return "Moderate Raise"
    elif x <= 21:
        return "High Raise"
    else:
        return "Exceptional Raise"

df_bq["PercentSalaryHikeGroup"] = df_bq["PercentSalaryHike"].apply(salary_hike_group)

print("[i] Computing percentage table by PercentSalaryHikeGroup × MonthlyIncomeGroup...")
df_group = pd.crosstab(
    [df_bq["PercentSalaryHikeGroup"], df_bq["MonthlyIncomeGroup"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (PercentSalaryHikeGroup × MonthlyIncomeGroup) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["PercentSalaryHikeGroup"], df_bq["MonthlyIncomeGroup"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,10))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: PercentSalaryHikeGroup or MonthlyIncomeGroup vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("PercentSalaryHikeGroup - MonthlyIncomeGroup | Attrition")
plt.xlabel("")
plt.text(2, 17, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by PercentSalaryHikeGroup × MonthlyIncomeGroup...
# Attrition                                           0          1
# PercentSalaryHikeGroup MonthlyIncomeGroup
# Exceptional Raise      High Income         100.000000   0.000000
#                        Low Income           68.656716  31.343284
#                        Lower-Mid Income     86.206897  13.793103
#                        Upper-Mid Income    100.000000   0.000000
# High Raise             High Income         100.000000   0.000000
#                        Low Income           82.269504  17.730496
#                        Lower-Mid Income     88.888889  11.111111
#                        Upper-Mid Income    100.000000   0.000000
# Low Raise              High Income          94.736842   5.263158
#                        Low Income           78.205128  21.794872
#                        Lower-Mid Income     86.885246  13.114754
#                        Upper-Mid Income     80.000000  20.000000
# ...

# %% [markdown]
# **Analysis:**
#
# Yes. Low-income employees remain significantly more likely to leave even when they receive moderate or exceptional salary hikes. Residuals above +3 for multiple hike levels confirm that pay increases do not effectively retain low-income workers. In contrast, higher-income employees stay longer after receiving raises, indicating a different behavioral pattern.

# %% [markdown]
# ### Does salary increase impact retention differently across income tiers?

# %% [markdown]
# **Analysis:**
#
# Yes. Salary increases impact retention very differently across income tiers.
# Low-income employees still exhibit high attrition even after receiving raises (residuals > +3), meaning salary hikes are not effective retention tools for them.
# In contrast, higher-income employees show significantly reduced attrition after raises (negative residuals), indicating that pay increases are far more effective for mid- and high-income groups.

# %% [markdown]
# ### Is poor work–life balance more severe in certain departments (Sales)?

# %%
print("[i] Computing percentage table by Department × WorkLifeBalance...")
df_group = pd.crosstab(
    [df_bq["Department"], df_bq["WorkLifeBalance"]],
    df_bq["Attrition"],
    normalize="index"
) * 100
display(df_group)

print("[i] Running Chi-Square Test for combined factors (Department × WorkLifeBalance) vs Attrition...")
contingency = pd.crosstab(
    [df_bq["Department"], df_bq["WorkLifeBalance"]],
    df_bq["Attrition"]
)

# Chi-square test + expected counts
chi2, p, dof, expected = chi2_contingency(contingency.values)
expected_df = pd.DataFrame(expected, index=contingency.index, columns=contingency.columns)
print(f"[i] Chi2: {chi2:.4f}")
print(f"[i] dof: {dof}")
print(f"[i] p-value: {p:.6f}")

# Standardized residuals (adjusted)
row_sums = contingency.sum(axis=1).values[:, None]        # shape (R,1)
col_sums = contingency.sum(axis=0).values[None, :]        # shape (1,C)
grand_total = contingency.values.sum()

row_prob = row_sums / grand_total               # R x 1
col_prob = col_sums / grand_total               # 1 x C

denom = np.sqrt(expected * (1 - row_prob) * (1 - col_prob))
std_resid = (contingency.values - expected) / denom

std_resid_df = pd.DataFrame(std_resid, index=contingency.index,
                            columns=contingency.columns)
# Heatmap — display nicely the multiindex
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
plt.figure(figsize=(15,10))
sns.heatmap(
    std_resid_df,
    annot=True, fmt=".2f", cmap=cmap, center=0,
    cbar_kws={"label": "Standardized Residual"}
)
plt.title("Standardized Residuals Heatmap: Department or WorkLifeBalance vs Attrition", weight="bold", fontsize=12, pad=15)
plt.ylabel("Department - WorkLifeBalance | Attrition")
plt.xlabel("")
plt.text(2, 13, "Created Thuan Dao.", fontsize=8, color="black", fontweight="bold", style="italic")
plt.tight_layout()
plt.show()
# Out:
# [i] Computing percentage table by Department × WorkLifeBalance...
# Attrition                                        0          1
# Department             WorkLifeBalance
# Human Resources        Bad              100.000000   0.000000
#                        Best              90.000000  10.000000
#                        Better            78.571429  21.428571
#                        Good              71.428571  28.571429
# Research & Development Bad               68.333333  31.666667
#                        Best              84.615385  15.384615
#                        Better            88.173913  11.826087
#                        Good              86.382979  13.617021
# Sales                  Bad               62.500000  37.500000
#                        Best              76.923077  23.076923
#                        Better            81.884058  18.115942
#                        Good              76.470588  23.529412
# ...

# %% [markdown]
# **Analysis:**
#
# Poor work–life balance is most severe in the R&D department, not Sales.
# R&D employees show the strongest over-attrition under poor WLB (residual +3.34), while Sales exhibits only moderate sensitivity (+2.34).
# HR is largely unaffected. This indicates that WLB impacts departments differently, with R&D being the most vulnerable.

# %% [markdown]
# ### Does department-level culture explain attrition differences?

# %% [markdown]
# **Analysis:**
#
# Yes. Department-level culture clearly explains attrition differences.
# R&D shows extreme sensitivity to poor work–life balance, Sales shows moderate sensitivity, and HR shows almost none.
# These different reactions indicate that each department’s internal culture shapes how employees respond to stress and workload, ultimately driving distinct attrition patterns.

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preprocessing</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Data Preprocessing
#     </h1>
# </div>

# %% [markdown]
# ### Handling Skewness
#
# Refer to the [Numerical Feature Distributions](#numerical-feature-distributions) section for more details.

# %%
skew_feature, skew_df = check_skewness(df_HR_Attrition, "Data")
# Out:
# [i] Skewness for Data...
# --------------------------------------------------------------------------------
# Feature                                  | Skewness  | Remark
# --------------------------------------------------------------------------------
# YearsSinceLastPromotion                  |   +1.9843 | Highly skewed
# YearsAtCompany                           |   +1.7645 | Highly skewed
# MonthlyIncome                            |   +1.3698 | Highly skewed
# TotalWorkingYears                        |   +1.1172 | Highly skewed
# DistanceFromHome                         |   +0.9581 | Moderately skewed
# YearsInCurrentRole                       |   +0.9174 | Moderately skewed
# YearsWithCurrManager                     |   +0.8335 | Moderately skewed
# PercentSalaryHike                        |   +0.8211 | Moderately skewed
# Age                                      |   +0.4133 | Approximately symmetric
# ...

# %%
from sklearn.preprocessing import PowerTransformer

def handle_skewed_features(
    df,
    zero_threshold=0.9,
    skew_threshold=0.5,
    num_features=None,
    exclude_cols=None
):
    """
    Handle skewed numerical features by applying appropriate transformations.

    Parameters:
    - df: pandas.DataFrame
    - zero_threshold: float (default=0.9)
    - skew_threshold: float (default=0.5)
    - num_features: list of numerical columns to consider
    - exclude_cols: list of columns to skip entirely

    Returns:
    - df: transformed DataFrame
    - transformed_cols: list of new feature names
    - high_zero_cols: list of sparse features (> zero_threshold)
    - skewed_cols: list of auto‑detected skewed features
    """
    df = df.copy()
    if num_features is None:
        raise ValueError("`num_features` must be provided")
    if exclude_cols is None:
        exclude_cols = []

    # 1) pick the numeric cols to scan
    numerical_cols = [c for c in num_features if c not in exclude_cols]

    # 2) detect ultra‑sparse
    zero_ratios = (df[numerical_cols] == 0).sum() / len(df)
    high_zero_cols = zero_ratios[zero_ratios > zero_threshold].index.tolist()

    # 3) compute skew
    skew_vals = df[numerical_cols].apply(lambda s: skew(s.dropna()))
    auto_skewed = skew_vals[abs(skew_vals) > skew_threshold].index.tolist()

    # 4) union these with your forced list
    to_transform = list(set(auto_skewed))

    transformed_cols = []
    dropped_cols     = []

    for col in to_transform:
        # if it's sparse → binary+log
        if col in high_zero_cols:
            df[f"Has_{col}"] = (df[col] > 0).astype(int)
            df[f"Log_{col}"] = df[col].map(lambda x: np.log1p(x) if x > 0 else 0)
            transformed_cols += [f"Has_{col}", f"Log_{col}"]
            dropped_cols.append(col)
        # if it's discrete small‑cardinality, skip transform but keep
        elif df[col].nunique() <= 5:
            # do nothing (we still keep raw col in df)
            continue
        # otherwise apply Yeo‑Johnson
        else:
            pt = PowerTransformer(method="yeo-johnson")
            arr = df[[col]].values  # shape (n,1)
            df[f"PT_{col}"] = pt.fit_transform(arr)
            transformed_cols.append(f"PT_{col}")
            dropped_cols.append(col)

    # drop originals for any column we did transform
    df.drop(columns=dropped_cols, inplace=True)

    return df, transformed_cols, high_zero_cols, auto_skewed

# %%
processed_df, transformed_columns, sparse_columns, skewed_columns = handle_skewed_features(df=df_HR_Attrition, 
                                                                                           num_features=skew_feature)
num_features = processed_df.select_dtypes(include=["number"]).columns.tolist()
num_features.remove("Attrition")
skew_feature, skew_df = check_skewness(processed_df, "Data", numerical_features=num_features)
# Out:
# [i] Skewness for Data...
# --------------------------------------------------------------------------------
# Feature                                  | Skewness  | Remark
# --------------------------------------------------------------------------------
# Age                                      |   +0.4133 | Approximately symmetric
# PT_YearsSinceLastPromotion               |   +0.2121 | Approximately symmetric
# PT_PercentSalaryHike                     |   +0.1163 | Approximately symmetric
# PT_YearsWithCurrManager                  |   -0.0676 | Approximately symmetric
# PT_YearsInCurrentRole                    |   -0.0608 | Approximately symmetric
# PT_MonthlyIncome                         |   +0.0328 | Approximately symmetric
# HourlyRate                               |   -0.0323 | Approximately symmetric
# MonthlyRate                              |   +0.0186 | Approximately symmetric
# PT_TotalWorkingYears                     |   -0.0107 | Approximately symmetric
# ...

# %% [markdown]
# **Insight:** <br>
#
# **Observations from the Skewness Table (`processed_df`):**
#
# **Approximately Symmetric**: <br>
# Several features, such as: <br>
#   * `PT_YearsSinceLastPromotion`, `PT_PercentSalaryHike`, `PT_YearsWithCurrManager`... show skewness < `0.5` or close to `0`.
#   * This indicates that **Yeo-Johnson transformation was effective** for many variables.

# %% [markdown]
# ## Re-check Outliers

# %%
checking_outlier(list_feature=num_features, df=processed_df, dataset_name="Data")
# Out:
# ...
# [i] Checking for outliers in Data...
# ...
#                 Feature  Outlier Count
# 0  PT_TotalWorkingYears             11
# 1     PT_YearsAtCompany              5

# %% [markdown]
# ## Create Test Set
#
# * Suppose you chatted with experts who told you that the **monthly income** is a very important attribute to predict **attrition**. <br>
# * We may want to ensure that the test set is representative of the various categories of incomes in the whole dataset. Since the monthly income is a continuous numerical attribute, we first need to create an income category attribute.

# %%
processed_df["PT_MonthlyIncome_cat"] = pd.qcut(processed_df["PT_MonthlyIncome"], q=4, labels=[1, 2, 3, 4])
plt.figure(figsize=(8, 5))
sns.histplot(data=processed_df, x="PT_MonthlyIncome_cat", color="lightblue", edgecolor="black")
sns.despine()
plt.title("Distribution of PT_MonthlyIncome_cat", fontsize=12, weight="bold",pad=15)
plt.xlabel("PT_MonthlyIncome_cat")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %%
split = StratifiedShuffleSplit(n_splits=Config.n_split_shuffle, test_size=Config.test_size, random_state=Config.seed)
for train_index, test_index in split.split(processed_df, processed_df["PT_MonthlyIncome_cat"]):
    start_train_set = processed_df.loc[train_index]
    start_test_set = processed_df.loc[test_index]

# Now we should remove the PT_MonthlyIncome_cat attribute so the data is back to its original state:
for set_ in (start_train_set, start_test_set): 
    set_.drop("PT_MonthlyIncome_cat", axis=1, inplace=True)

df_HR_Attrition_new = start_train_set.drop("Attrition", axis=1)
df_HR_Attrition_labels = start_train_set["Attrition"].copy()

# %% [markdown]
# ## Scale and Encode

# %%
# There are no **missing values** into dataset. But we will still handle missing values ​​to check the data in the future.
num_transfomer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

cat_transfomer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")), 
    ("encoder", OneHotEncoder(handle_unknown="ignore")) # Handling Text and Categorical Attributes
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", num_transfomer, num_features),
        ("cat", cat_transfomer, cat_features),
    ]
)

preprocessor.fit(df_HR_Attrition_new)
df_HR_Attrition_prepared = preprocessor.transform(df_HR_Attrition_new)
list_feature_prepared = preprocessor.get_feature_names_out().tolist()
clean_features = [col.replace("num__", "").replace("cat__", "").replace("PT_", "") for col in list_feature_prepared]
clean_features
# Out:
# ['Age',
#  'DailyRate',
#  'HourlyRate',
#  'MonthlyRate',
#  'TotalWorkingYears',
#  'YearsWithCurrManager',
#  'YearsAtCompany',
#  'YearsSinceLastPromotion',
#  'DistanceFromHome',
#  'PercentSalaryHike',
#  'MonthlyIncome',
#  'YearsInCurrentRole',
#  'BusinessTravel_Non-Travel',
#  'BusinessTravel_Travel_Frequently',
#  'BusinessTravel_Travel_Rarely',
#  'Department_Human Resources',
#  'Department_Research & Development',
#  'Department_Sales',
#  'Education_Bachelor',
#  'Education_Below College',
#  'Education_College',
#  'Education_Doctor',
#  'Education_Master',
#  'EducationField_Human Resources',
#  'EducationField_Life Sciences',
#  'EducationField_Marketing',
#  'EducationField_Medical',
#  'EducationField_Other',
#  'EducationField_Technical Degree',
#  'EnvironmentSatisfaction_High',
#  'EnvironmentSatisfaction_Low',
#  'EnvironmentSatisfaction_Medium',
#  'EnvironmentSatisfaction_Very High',
#  'Gender_Female',
#  'Gender_Male',
#  'JobInvolvement_High',
# ...

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Define Metric</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Define Metric
#     </h1>
# </div>

# %% [markdown]
# | Metric        | Definition                                                  | Meaning in Attrition Context                                          |
# | ------------- | ----------------------------------------------------------- | --------------------------------------------------------------------- |
# | **Recall**    | $\frac{TP}{TP + FN}$                                        | **Most important** – how many true leavers you can catch              |
# | **Precision** | $\frac{TP}{TP + FP}$                                        | Among predicted leavers, how many are actually correct                |
# | **Accuracy**  | $\frac{TP + TN}{Total}$                                     | Can be misleading with imbalanced data (e.g., <20% attrition)         |
# | **F1-score**  | $\frac{2 \cdot Precision \cdot Recall}{Precision + Recall}$ | Balanced trade-off between Precision and Recall                       |
# | **AUC-ROC**   | Area under ROC Curve                                        | Measures ability to distinguish leavers vs. stayers at all thresholds |

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Evaluation Using Cross-Validation</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Evaluation Using Cross-Validation
#     </h1>
# </div>

# %%
# Using SMOTE to handling imbalance data.
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=Config.seed)
X_resampled, y_resampled = smote.fit_resample(df_HR_Attrition_prepared, df_HR_Attrition_labels)

# %%
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import (RandomForestClassifier, GradientBoostingClassifier, 
                              ExtraTreesClassifier, AdaBoostClassifier, BaggingClassifier, HistGradientBoostingClassifier)
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

kfold = StratifiedKFold(n_splits=Config.n_split_kfold, shuffle=True, random_state=Config.seed)
models = [
    LinearSVC(random_state=Config.seed, max_iter=Config.max_iter),
    SVC(random_state=Config.seed, max_iter=Config.max_iter),
    KNeighborsClassifier(),
    GaussianNB(),
    LogisticRegression(random_state=Config.seed, max_iter=Config.max_iter),
    DecisionTreeClassifier(random_state=Config.seed),
    RandomForestClassifier(random_state=Config.seed),
    ExtraTreesClassifier(random_state=Config.seed),
    AdaBoostClassifier(random_state=Config.seed),
    XGBClassifier(random_state=Config.seed),
    MLPClassifier(random_state=Config.seed, max_iter=Config.max_iter),
    GradientBoostingClassifier(random_state=Config.seed),
    RidgeClassifier(random_state=Config.seed, max_iter=Config.max_iter),
    CatBoostClassifier(verbose=0, random_seed=Config.seed),
    BaggingClassifier(random_state=Config.seed),
    LGBMClassifier(random_state=Config.seed, verbosity=-1),
    HistGradientBoostingClassifier(random_state=Config.seed, max_iter=Config.max_iter)
]

# %%
def generate_baseline_results(models=models, X=X_resampled, y=y_resampled,
                              metric="accuracy", cv=kfold, plot_result=False):
    entries = []
    for model in models:
        model_name = getattr(model, "name", model.__class__.__name__)
        try:
            scores = cross_val_score(model, X, y, scoring=metric, cv=cv, n_jobs=-1)
        except Exception as e:
            print(f"[!] Model {model_name} failed: {e}")
            continue
        for fold_idx, s in enumerate(scores, start=1):
            entries.append((model_name, fold_idx, s))

    cv_df = pd.DataFrame(entries, columns=["model_name", "fold_id", "score"])

    summary = (cv_df.groupby("model_name")["score"]
                    .agg(Mean="mean", Std="std", N="size")
                    .sort_values("Mean", ascending=False))

    if plot_result:
        order = summary.index.tolist()
        plt.figure(figsize=(18, 8))
        sns.barplot(data=cv_df, x="model_name", y="score", order=order, errorbar=("sd"), palette="viridis")
        title_metric = metric.upper() if isinstance(metric, str) else "Score"
        nfolds = getattr(cv, "n_splits", "CV")
        plt.title(f"Baseline {title_metric} using {nfolds}-fold cross-validation", fontsize=14, weight="bold", pad=20)
        plt.xlabel("Model"); plt.ylabel(title_metric)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

    return summary

display(generate_baseline_results(plot_result = True))
# Out:
#                                     Mean       Std  N
# model_name
# ExtraTreesClassifier            0.966933  0.008457  5
# SVC                             0.943541  0.011710  5
# MLPClassifier                   0.943032  0.009098  5
# RandomForestClassifier          0.941500  0.012229  5
# CatBoostClassifier              0.936387  0.002545  5
# HistGradientBoostingClassifier  0.931329  0.012746  5
# LGBMClassifier                  0.929292  0.016459  5
# XGBClassifier                   0.928782  0.022995  5
# GradientBoostingClassifier      0.924717  0.010912  5
# BaggingClassifier               0.912515  0.009428  5
# AdaBoostClassifier              0.908963  0.012001  5
# DecisionTreeClassifier          0.859623  0.016309  5
# LinearSVC                       0.831640  0.018446  5
# LogisticRegression              0.831136  0.018135  5
# RidgeClassifier                 0.826048  0.010608  5
# GaussianNB                      0.753323  0.022139  5
# ...

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Hyperparameter tuning</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#        Hyperparameter tuning
#     </h1>
# </div>

# %%
def shap_plot(model, X_test, list_feature, type = None):    
     # https://towardsdatascience.com/using-shap-values-to-explain-how-your-machine-learning-model-works-732b3f40e137/
    if hasattr(X_test, "toarray"):
        X_test = X_test.toarray()
    X_test_sample = pd.DataFrame(X_test, columns=list_feature)
    explainer = shap.Explainer(model.predict, X_test_sample)
    shap_values = explainer(X_test_sample)
    if type =="bar":
        shap_importance = np.abs(shap_values.values).mean(axis=0)
        shap_df = pd.DataFrame({"feature": X_test_sample.columns, "importance": shap_importance})
        shap_df = shap_df.sort_values("importance", ascending=False).head(20)
        plt.figure(figsize=(12, 6))
        sns.barplot(x=shap_df["importance"], y=shap_df["feature"], palette="viridis", order=shap_df["feature"])
        plt.xlabel("mean(|SHAP value|)")
        plt.title("SHAP Feature Importance", pad=15, weight="bold", fontsize=12)
        plt.tight_layout()
        plt.show()
    else:
        shap.summary_plot(shap_values, X_test_sample)

# %%
from sklearn.metrics import (
    precision_score, recall_score, f1_score, accuracy_score
)

def plot_metric(estimator, X_test, y_test, figsize=(12, 10), 
                show_threshold_analysis=True, metric = "accuracy", return_best_threshold=False):
    y_pred_prob = estimator.predict_proba(X_test)[:, 1]
    y_pred = estimator.predict(X_test)

    # Setup subplots
    fig, ax = plt.subplots(nrows=2, ncols=2, figsize=figsize)

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    rocScore = roc_auc_score(y_test, y_pred_prob)
    ax[0, 0].plot(fpr, tpr, label=f"AUC = {rocScore:.2f}")
    ax[0, 0].plot([0, 1], [0, 1], "k--")
    ax[0, 0].set_title("ROC Curve", weight="bold")
    ax[0, 0].set_xlabel("False Positive Rate")
    ax[0, 0].set_ylabel("True Positive Rate")
    ax[0, 0].legend()

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax[0, 1])
    ax[0, 1].set_title("Confusion Matrix", weight="bold")
    ax[0, 1].set_xlabel("Predicted")
    ax[0, 1].set_ylabel("Actual")

    # Precision-Recall Curve
    avg_prec = average_precision_score(y_test, y_pred_prob)   
    precision, recall, thresholds_pr = precision_recall_curve(y_test, y_pred_prob)
    ax[1, 0].plot(recall, precision, label=f"PR Curve (AP = {avg_prec:.3f})")
    ax[1, 0].set_xlabel("Recall")
    ax[1, 0].set_ylabel("Precision")
    ax[1, 0].set_title("Precision-Recall Curve", fontsize=14, weight="bold", pad=20)
    ax[1, 0].legend()

    if show_threshold_analysis:
        thresholds = np.arange(0.1, 0.91, 0.05)
        result = {
            "Threshold": [],
            "Precision": [],
            "Recall": [],
            "F1-score": [],
            "Accuracy": []
        }

        for thresh in thresholds:
            y_thresh_pred = (y_pred_prob >= thresh).astype(int)
            p = precision_score(y_test, y_thresh_pred, zero_division=0)
            r = recall_score(y_test, y_thresh_pred, zero_division=0)
            f1 = f1_score(y_test, y_thresh_pred, zero_division=0)
            acc = accuracy_score(y_test, y_thresh_pred)

            result["Threshold"].append(round(thresh, 2))
            result["Precision"].append(round(p, 3))
            result["Recall"].append(round(r, 3))
            result["F1-score"].append(round(f1, 3))
            result["Accuracy"].append(round(acc, 3))

        df_result = pd.DataFrame(result)

        # Select the best threshold by metric
        metric_map = {
            "f1": "F1-score",
            "recall": "Recall",
            "precision": "Precision",
            "accuracy": "Accuracy"
        }

        if metric not in metric_map:
            raise ValueError("metric must be 'f1', 'recall', 'precision' or 'accuracy'")

        metric_col = metric_map[metric]
        best_idx = df_result[metric_col].idxmax()
        best_thresh = df_result.loc[best_idx, "Threshold"]

        # Plot threshold analysis on ax[1, 1]
        ax[1, 1].plot(df_result["Threshold"], df_result["Precision"], label="Precision", marker="o")
        ax[1, 1].plot(df_result["Threshold"], df_result["Recall"], label="Recall", marker="s")
        ax[1, 1].plot(df_result["Threshold"], df_result["F1-score"], label="F1-score", marker="^")
        ax[1, 1].plot(df_result["Threshold"], df_result["Accuracy"], label="Accuracy", marker="x")
        ax[1, 1].axvline(best_thresh, color="red", linestyle="--", label=f"Best ({metric_col}): {best_thresh:.2f}")
        ax[1, 1].set_title("Threshold vs Scores", weight="bold")
        ax[1, 1].set_xlabel("Threshold")
        ax[1, 1].set_ylabel("Score")
        ax[1, 1].legend()
    else:
        ax[1, 1].set_visible(False)

    plt.tight_layout()
    plt.show()

    # In classification report
    print("[i] Classification Report (Threshold = 0.5):\n")
    print(classification_report(y_test, y_pred))

    if show_threshold_analysis:
        print("\n[i] Threshold Tuning Table:\n")
        print(df_result)

    if return_best_threshold:
        return best_thresh

# %%
def predict_with_threshold(model, X, y_true, threshold=0.5, title="Confusion Matrix"):
    y_proba = model.predict_proba(X)[:, 1]
    
    y_pred = (y_proba >= threshold).astype(int)

    # In classification report
    print(f"\n[i] Classification Report (Threshold = {threshold:.2f}):\n")
    print(classification_report(y_true, y_pred, digits=3))

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Vẽ heatmap confusion matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.title(f"{title} (Threshold = {threshold:.2f})", weight="bold", pad=15, fontsize=12)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()
    # return y_pred

# %%
# Function to evaluate models
def evaluate_model(model, X_train, X_test, y_train, y_test, figsize = (15, 6), show_shap_plot = False, metric = "f1", show_threshold_analysis=True):
    global best_threshold
    print(f"Evaluating {model.__class__.__name__}...")
    model.fit(X_train, y_train)
    best_threshold = plot_metric(estimator = model, X_test = X_test, y_test = y_test, figsize = figsize, metric = metric,
                                 show_threshold_analysis = show_threshold_analysis, return_best_threshold = True)

# %%
X_test = start_test_set.drop("Attrition", axis=1)
y_test = start_test_set["Attrition"].copy()
X_test_prepared = preprocessor.transform(X_test)

# %% [markdown]
#   <p align="center">
#     <img src="https://i.ibb.co/WvJ3VsWx/8-confusion-matrix-python.webp" width="600">
#   </p>

# %% [markdown]
# ## ExtraTreesClassifier

# %%
param_etc = {
"n_estimators": 277,
"max_depth": 49,
"min_samples_split": 2,
"min_samples_leaf": 1,
"max_features": "log2",
"bootstrap": False,
"random_state": Config.seed,
"n_jobs": -1
}

best_model_etc = ExtraTreesClassifier(**param_etc)
evaluate_model(model = best_model_etc, X_train=X_resampled, X_test=X_test_prepared,
               y_train=y_resampled, y_test=y_test, figsize=(15, 10), show_threshold_analysis=True, metric="recall", show_shap_plot=False)
print("*"*100)
print("\n")
predict_with_threshold(model=best_model_etc, X = X_test_prepared, y_true = y_test, threshold=best_threshold)
# Out:
# Evaluating ExtraTreesClassifier...
# [i] Classification Report (Threshold = 0.5):
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       250
#            1       0.71      0.39      0.50        44
#
#     accuracy                           0.88       294
#    macro avg       0.80      0.68      0.72       294
# weighted avg       0.87      0.88      0.87       294
#
#
# [i] Threshold Tuning Table:
#
#     Threshold  Precision  Recall  F1-score  Accuracy
# 0        0.10      0.187   0.909     0.310     0.395
# 1        0.15      0.258   0.886     0.400     0.602
# 2        0.20      0.324   0.818     0.465     0.718
# 3        0.25      0.388   0.750     0.512     0.786
# 4        0.30      0.426   0.659     0.518     0.816
# 5        0.35      0.458   0.614     0.524     0.833
# 6        0.40      0.523   0.523     0.523     0.857
# 7        0.45      0.667   0.455     0.541     0.884
# ...

# %% [markdown]
# ## MLPClassifier

# %%
param_mlp = {
"solver": "adam",
"hidden_layer_sizes": (50,),
"activation": "tanh",
"alpha": 2.4375153952494754e-05,
"learning_rate_init": 0.021305144989660147,
"batch_size": 32,
"max_iter": Config.max_iter,
"early_stopping": True,
"random_state": Config.seed
}

best_model_mlpc = MLPClassifier(**param_mlp)
evaluate_model(model = best_model_mlpc, X_train=X_resampled, X_test=X_test_prepared,
               y_train=y_resampled, y_test=y_test, figsize=(15, 10), show_threshold_analysis=True, metric="recall", show_shap_plot=False)
print("*"*100)
print("\n")
predict_with_threshold(model=best_model_mlpc, X = X_test_prepared, y_true = y_test, threshold=best_threshold)
# Out:
# Evaluating MLPClassifier...
# [i] Classification Report (Threshold = 0.5):
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       250
#            1       0.56      0.57      0.56        44
#
#     accuracy                           0.87       294
#    macro avg       0.74      0.74      0.74       294
# weighted avg       0.87      0.87      0.87       294
#
#
# [i] Threshold Tuning Table:
#
#     Threshold  Precision  Recall  F1-score  Accuracy
# 0        0.10      0.427   0.795     0.556     0.810
# 1        0.15      0.452   0.750     0.564     0.827
# 2        0.20      0.493   0.750     0.595     0.847
# 3        0.25      0.500   0.659     0.569     0.850
# 4        0.30      0.500   0.614     0.551     0.850
# 5        0.35      0.540   0.614     0.574     0.864
# 6        0.40      0.553   0.591     0.571     0.867
# 7        0.45      0.556   0.568     0.562     0.867
# ...

# %% [markdown]
# ## CatBoostClassifier

# %%
param_cb = {
"iterations": 781,
"learning_rate": 0.010326043050108874,
"depth": 8,
"l2_leaf_reg": 0.030092995860914913,
"border_count": 128,
"random_strength": 2.5423554613863546,
"bagging_temperature": 0.5433651825614273,
"random_seed": Config.seed,
"eval_metric": "Accuracy",
"verbose": 0,
"thread_count": -1,
"grow_policy": "Lossguide",
"loss_function": "Logloss",
"bootstrap_type": "Bayesian",
"task_type": "CPU"
}

best_model_catboost = CatBoostClassifier(**param_cb)
evaluate_model(model = best_model_catboost, X_train=X_resampled, X_test=X_test_prepared,
               y_train=y_resampled, y_test=y_test, figsize=(15, 10), show_threshold_analysis=True, metric="recall", show_shap_plot=False)
print("*"*100)
print("\n")
predict_with_threshold(model=best_model_catboost, X = X_test_prepared, y_true = y_test, threshold=best_threshold)
# Out:
# Evaluating CatBoostClassifier...
# [i] Classification Report (Threshold = 0.5):
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       250
#            1       0.65      0.45      0.53        44
#
#     accuracy                           0.88       294
#    macro avg       0.78      0.71      0.73       294
# weighted avg       0.87      0.88      0.87       294
#
#
# [i] Threshold Tuning Table:
#
#     Threshold  Precision  Recall  F1-score  Accuracy
# 0        0.10      0.314   0.841     0.457     0.701
# 1        0.15      0.372   0.795     0.507     0.769
# 2        0.20      0.429   0.750     0.545     0.813
# 3        0.25      0.492   0.705     0.579     0.847
# 4        0.30      0.556   0.682     0.612     0.871
# 5        0.35      0.596   0.636     0.615     0.881
# 6        0.40      0.615   0.545     0.578     0.881
# 7        0.45      0.647   0.500     0.564     0.884
# ...

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Conclusion</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Conclusion
#     </h1>
# </div>

# %% [markdown]
# ## VotingClassifier

# %%
# 1. Collect predictions (proba)
ests = [
    ("cb", best_model_catboost),
    ("etc", best_model_etc),
    ("mlp", best_model_mlpc)
]

preds = {name: m.predict_proba(X_test_prepared)[:, 1] for name, m in ests}

# 2. Accuracy của từng model
# from sklearn.metrics import accuracy_score
acc_each = {name: accuracy_score(y_test, (preds[name] >= 0.5).astype(int))
            for name,_ in ests}
display(acc_each)

# 3. Prepare matrix
A = np.column_stack([preds[name] for name,_ in ests])

# 4. Optuna objective = maximize Accuracy
def obj_w(trial):
    w = np.array([trial.suggest_float(f"w_{i}", 0.0, 5.0) for i in range(A.shape[1])])
    if w.sum() == 0:
        return 0
    y_prob = A.dot(w / w.sum())
    y_pred = (y_prob >= 0.5).astype(int)
    return accuracy_score(y_test, y_pred)

# 5. Optimize
study_w = optuna.create_study(direction="maximize")
study_w.optimize(obj_w, n_trials=1000, show_progress_bar=True)

# 6. Best weights
w = np.array([study_w.best_params[f"w_{i}"] for i in range(A.shape[1])])
weights = (w / w.sum()).tolist()
print("Best weights (normalized):", weights)
print("Best ACC:", study_w.best_value)
# Out:
# {'cb': 0.8809523809523809,
#  'etc': 0.8843537414965986,
#  'mlp': 0.8673469387755102}
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Best weights (normalized): [0.5142097799744353, 0.16700790110239108, 0.31878231892317366]
# Best ACC: 0.8945578231292517

# %%
from sklearn.ensemble import VotingClassifier

voting_clf_soft = VotingClassifier(
    estimators=[
        ("etc", best_model_etc),
        ("mlp", best_model_mlpc),
        ("cb", best_model_catboost)
    ],
    voting="soft",
    weights=weights,
    n_jobs=-1
)

evaluate_model(model = voting_clf_soft, X_train=X_resampled, X_test=X_test_prepared,
               y_train=y_resampled, y_test=y_test, figsize=(15, 10), show_threshold_analysis=True, metric="recall", show_shap_plot=False)
print("*"*100)
print("\n")
predict_with_threshold(model=voting_clf_soft, X = X_test_prepared, y_true = y_test, threshold=best_threshold)
# Out:
# Evaluating VotingClassifier...
# [i] Classification Report (Threshold = 0.5):
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       250
#            1       0.66      0.43      0.52        44
#
#     accuracy                           0.88       294
#    macro avg       0.78      0.70      0.73       294
# weighted avg       0.87      0.88      0.87       294
#
#
# [i] Threshold Tuning Table:
#
#     Threshold  Precision  Recall  F1-score  Accuracy
# 0        0.10      0.235   0.864     0.369     0.558
# 1        0.15      0.319   0.818     0.459     0.711
# 2        0.20      0.395   0.773     0.523     0.789
# 3        0.25      0.434   0.750     0.550     0.816
# 4        0.30      0.508   0.727     0.598     0.854
# 5        0.35      0.585   0.705     0.639     0.881
# 6        0.40      0.643   0.614     0.628     0.891
# 7        0.45      0.636   0.477     0.545     0.881
# ...

# %%
shap_sample = X_test_prepared.iloc if isinstance(X_test_prepared, pd.DataFrame) else X_test_prepared
shap_plot(model=voting_clf_soft, X_test=shap_sample, list_feature=clean_features, type="bar")
# Out:
# PermutationExplainer explainer: 295it [02:50,  1.70it/s]

# %%
shap_plot(model=voting_clf_soft, X_test=shap_sample, list_feature=clean_features)
# Out:
# PermutationExplainer explainer: 295it [02:47,  1.65it/s]

# %% [markdown]
# **Analysis:**
#
# ***Overtime, job level, job satisfaction, and environment satisfaction are the strongest predictors of attrition. Employees under high workload stress or low satisfaction are significantly more likely to leave, while those with good work conditions and stability tend to stay.***

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Recommendations</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #8B4513;
#     padding: 10px;
#     background: linear-gradient(135deg, #d73027, #fdae61 40%, #a6d96a 80%, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Recommendations
#     </h1>
# </div>

# %% [markdown]
# **Key Takeaways to Reduce Attrition**
#
# * Turnover is concentrated among **low-income, young, single, overtime workers**, Level 1 staff, and Sales/Lab roles.
# * **Low job satisfaction and poor work environment** are the strongest attrition drivers.
# * **Poor work–life balance** and **weak manager relationships** significantly increase quitting risk.
# * Priorities: reduce overtime, improve compensation for low-income staff, strengthen manager capability, and support early-career employees.

# %%
from IPython.display import IFrame

IFrame(
    src="https://app.powerbi.com/view?r=eyJrIjoiN2NhOTQ0NDEtNzBjZS00ODkwLWI1YzQtNmI1ZTYyNWU0ZGJmIiwidCI6ImFmMWYzNzUzLTM5MjUtNGU2Zi05NDliLTk3YzAwNzMyMDgwMyIsImMiOjEwfQ%3D%3D&pageName=ca2971bb70600422506a",   # link report
    width="600",
    height="373.5"
)
# Out:
#         <iframe
#             width="600"
#             height="373.5"
#             src="https://app.powerbi.com/view?r=eyJrIjoiN2NhOTQ0NDEtNzBjZS00ODkwLWI1YzQtNmI1ZTYyNWU0ZGJmIiwidCI6ImFmMWYzNzUzLTM5MjUtNGU2Zi05NDliLTk3YzAwNzMyMDgwMyIsImMiOjEwfQ%3D%3D&pageName=ca2971bb70600422506a"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #a63603; /* Darker warm brown to match palette */
#     padding: 20px;
#     background: linear-gradient(135deg, #d73027, #fdae61, #a6d96a, #1a9850);
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #ffffff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#     ">
#         🙏 Thanks for Reading! 🚀
#     </h1>
#     <p style="color: #ffffff; font-size: 18px; text-align: center;">
#         Happy Coding! 🙌😊
#     </p>
# </div>
