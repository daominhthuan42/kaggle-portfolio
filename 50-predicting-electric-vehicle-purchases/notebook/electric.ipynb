# %% [markdown]
# <div style="
#     border-radius: 15px;
#     border: 2px solid #006064;
#     padding: 10px;
#     background: linear-gradient(
#         135deg,
#         #003B5C,
#         #0077B6 35%,
#         #00B4D8 65%,
#         #2A9D8F 100%
#     );
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         🚗 Predicting Electric Vehicle Purchases ⚡
#     </h1>
# </div>

# %% [markdown]
# # 📂 Overview
#
# * ****Background**** <br>
#
#   The adoption of ****electric vehicles (EVs)**** is becoming increasingly important as consumers and governments move toward more sustainable transportation. However, EV adoption decisions can be influenced by several factors, including ****income****, ****daily commuting needs****, ****charging infrastructure****, ****environmental concerns****, ****government subsidies****, and ****range anxiety****. Understanding these factors can help identify the characteristics and conditions that influence a consumer's decision to purchase an electric vehicle.
#
# * ****Goal of the Project**** <br>
#
#   Using demographic information, financial characteristics, driving behavior, charging infrastructure, environmental attitudes, and range anxiety indicators, this project aims to build a predictive model that determines whether a consumer is likely to ****purchase an electric vehicle****. The analysis also helps uncover the key factors associated with EV adoption and provides insights into consumer preferences and barriers to EV ownership.
#
# 🎯 **Key Features**
#
# ****Target Variable****
#
# * `Will_Buy_EV`: Whether the consumer will purchase an electric vehicle (`Yes` / `No`)
#
# ****Buyer Demographics**** <br>
#
# * `Age`: Age of the buyer
#
# * `Gender`: Gender of the buyer
#
# ****Financial & Geographic Characteristics**** <br>
#
# * `Annual_Income_USD`: Annual income of the buyer in USD
#
# * `City_Type`: Type of city where the buyer lives
#
# ****Driving & Vehicle Ownership**** <br>
#
# * `Daily_Commute_km`: Average daily commuting distance in kilometers
#
# * `Number_of_Cars_Owned`: Number of cars currently owned
#
# * `Current_Car_Type`: Type of vehicle currently owned
#
# ****Charging Infrastructure**** <br>
#
# * `Charging_Stations_Near_Home`: Number of charging stations available near the buyer's home
#
# * `Charging_Stations_Near_Work`: Number of charging stations available near the buyer's workplace
#
# * `Home_Charging_Possible`: Whether home charging is possible (`Yes` / `No`)
#
# ****Environmental & Policy Factors**** <br>
#
# * `Environmental_Concern_Level`: Buyer's level of concern about environmental issues
#
# * `Subsidy_Available`: Whether an EV purchase subsidy is available (`Yes` / `No`)
#
# ****EV Adoption Barriers**** <br>
#
# * `Range_Anxiety_Level`: Buyer's level of concern about EV driving range
#
# 📁 ****Files Provided****
#
# * `EV_Adoption_and_Range_Anxiety_Dataset.csv`: Dataset containing buyer characteristics, driving behavior, charging infrastructure, environmental concerns, range anxiety, and EV purchase decisions
#
# 🚀 ****Project Objective****
#
# The primary objective of this project is to ****perform exploratory data analysis (EDA)**** and develop machine learning models capable of predicting whether a consumer will purchase an electric vehicle.
#
# Through this analysis, we aim to:
#
# * Understand ****EV adoption patterns**** across different consumer groups
#
# * Identify the ****key factors influencing EV purchase decisions****
#
# * Analyze how ****income, commuting distance, and vehicle ownership**** relate to EV adoption
#
# * Evaluate the impact of ****charging infrastructure and home charging availability**** on purchase intention
#
# * Investigate the relationship between ****environmental concern, subsidies, and range anxiety**** and EV adoption
#
# * Build an accurate **classification model** for predicting EV purchase decisions.

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Import Libraries</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#     background: linear-gradient(
#         135deg,
#         #003B5C,
#         #0077B6 35%,
#         #00B4D8 65%,
#         #2A9D8F 100%
#     );
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Import Libraries
#     </h1>
# </div>

# %%
import sys
from pathlib import Path

# Add project root to PYTHONPATH
ROOT_DIR = Path.cwd().parent
sys.path.append(str(ROOT_DIR))

# Core Libraries
import pandas as pd              # Data handling
import numpy as np               # Numerical operations
import seaborn as sns            # Statistical plots
import matplotlib.pyplot as plt  # Visualization
from visualization.visualization_plots import (
    plot_numerical_features_v3,
    categorical_distribution_across_datasets,
    plot_feature_importance_comparison
)

# Project Utilities
from utils.logger import LoggerConfig
from utils.utils import Utils
from config.config import CFG
from utils.stats_utils import StatUtils
from preprocessing.validation import DataValidator

# Modeling Utilities
from models.benchmark import *
from models.oof import *

# Hyperparameter Tuning
from models.catboost_tuning import *
from models.lgbm_tunning import *
from models.xgboost_tuning import *

# Notebook Display
from IPython.display import display, HTML

# Data Splitting & Preprocessing
from sklearn.model_selection import StratifiedShuffleSplit

# Evaluation
from sklearn.metrics import classification_report

# Optimization
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Environment Settings
import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", 500)
pd.set_option("display.max_colwidth", None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Load Data</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#     background: linear-gradient(
#         135deg,
#         #003B5C,
#         #0077B6 35%,
#         #00B4D8 65%,
#         #2A9D8F 100%
#     );
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Load Data
#     </h1>
# </div>

# %%
# Set a consistent dark plotting style for Matplotlib and Seaborn.
CFG.setup_plot_style()

# Initialize notebook logger
logger = LoggerConfig.setup_logger()

# Load datasets safely
df_train = Utils.read_csv_safe(path=CFG.DATA_PATH_TRAIN, logger=logger,
                         encodings=CFG.DEFAULT_ENCODING).pipe(Utils.clean_columns)
df_original = Utils.read_csv_safe(path=CFG.DATA_PATH_ORIGINAL, logger=logger,
                         encodings=CFG.DEFAULT_ENCODING).pipe(Utils.clean_columns)
df_test = Utils.read_csv_safe(path=CFG.DATA_PATH_TEST, logger=logger,
                         encodings=CFG.DEFAULT_ENCODING).pipe(Utils.clean_columns)
# Out:
# 2026-09-03 18:21:28 | INFO     | Logging configured: level=DEBUG, format=colored
# 2026-09-03 18:21:29 | INFO     | Loaded file with encoding: utf-8 | Shape: (668665, 15)
# 2026-09-03 18:21:29 | INFO     | Loaded file with encoding: utf-8 | Shape: (10000, 15)
# 2026-09-03 18:21:29 | INFO     | Loaded file with encoding: utf-8 | Shape: (286571, 14)

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Preview and Info</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#     background: linear-gradient(
#         135deg,
#         #003B5C,
#         #0077B6 35%,
#         #00B4D8 65%,
#         #2A9D8F 100%
#     );
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Data Preview and Info
#     </h1>
# </div>

# %%
datasets = {"Train": df_train, "Test": df_test, "Original": df_original}

for name, df in datasets.items():
    logger.info(f"{name} Data Preview")
    display(df.head())
# Out:
# 2026-09-03 18:21:29 | INFO     | Train Data Preview
#    id  Age  Annual_Income_USD  Daily_Commute_km  Number_of_Cars_Owned  \
# 0   0   66            92887.0              23.4                     2
# 1   1   38            30000.0               5.0                     1
# 2   2   26            94389.0              36.8                     1
# 3   3   66            73580.0              23.7                     2
# 4   4   54            57898.0              50.8                     1
#
#    Charging_Stations_Near_Home  Charging_Stations_Near_Work  \
# 0                            3                            7
# 1                            2                            2
# 2                            8                           15
# 3                            6                            9
# 4                            2                            3
#
#    Environmental_Concern_Level  Gender City_Type Current_Car_Type  \
# 0                          1.0    Male  Suburban            Sedan
# 1                          4.0    Male     Rural              SUV
# 2                          5.0  Female     Urban            Sedan
# 3                          3.0    Male  Suburban        Hatchback
# 4                          3.0    Male  Suburban        Hatchback
#
#   Home_Charging_Possible Subsidy_Available Range_Anxiety_Level Will_Buy_EV
# 0                    Yes                No                 Low          No
# 1                    Yes                No                 Low          No
# 2                     No               Yes                 Low         Yes
# 3                    Yes                No                 Low          No
# 4                    Yes                No                 Low          No
# 2026-09-03 18:21:29 | INFO     | Test Data Preview
#        id  Age  Annual_Income_USD  Daily_Commute_km  Number_of_Cars_Owned  \
# 0  668665   61            67725.0              16.9                     2
# 1  668666   42           152835.0              41.9                     2
# 2  668667   68            86877.0              53.3                     1
# 3  668668   39            46794.0              34.1                     2
# 4  668669   55           112172.0              57.2                     1
#
#    Charging_Stations_Near_Home  Charging_Stations_Near_Work  \
# 0                            7                            4
# 1                            9                            9
# 2                           10                           11
# 3                            4                            8
# 4                            6                            4
#
#    Environmental_Concern_Level  Gender City_Type Current_Car_Type  \
# 0                          4.0    Male  Suburban            Sedan
# 1                          4.0    Male     Urban              SUV
# 2                          4.0  Female     Urban            Sedan
# 3                          4.0  Female  Suburban            Sedan
# 4                          1.0  Female  Suburban            Sedan
#
#   Home_Charging_Possible Subsidy_Available Range_Anxiety_Level
# 0                    Yes                No                 Low
# 1                     No                No                 Low
# 2                     No                No                 Low
# 3                    Yes                No                 Low
# 4                    Yes               Yes                 Low
# 2026-09-03 18:21:29 | INFO     | Original Data Preview
#   Buyer_ID  Age  Gender  Annual_Income_USD City_Type  Daily_Commute_km  \
# 0  EV00001   56    Male            44906.0     Rural              18.1
# 1  EV00002   36    Male            88754.0     Rural               5.0
# 2  EV00003   42    Male           155958.0     Urban              32.2
# 3  EV00004   31    Male            37059.0     Rural              89.9
# 4  EV00005   48  Female            48552.0     Rural              71.0
#
#    Number_of_Cars_Owned Current_Car_Type  Charging_Stations_Near_Home  \
# 0                     1            Truck                            1
# 1                     1              SUV                            2
# 2                     2            Sedan                           14
# 3                     1            Sedan                            2
# 4                     1            Sedan                            2
#
#    Charging_Stations_Near_Work Home_Charging_Possible  \
# 0                            0                    Yes
# 1                            3                    Yes
# 2                            3                     No
# 3                            1                    Yes
# 4                            0                    Yes
#
#    Environmental_Concern_Level Subsidy_Available Range_Anxiety_Level  \
# 0                          4.0               Yes                 Low
# 1                          1.0               Yes                 Low
# 2                          2.0               Yes              Medium
# 3                          4.0                No                 Low
# 4                          3.0               Yes                 Low
#
#   Will_Buy_EV
# 0          No
# 1          No
# 2         Yes
# 3          No
# 4          No

# %%
# Display information about the DataFrames
for name, df in datasets.items():
    logger.info(f"{name} Data Info")
    df.info()
# Out:
# 2026-09-03 18:21:29 | INFO     | Train Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668665 entries, 0 to 668664
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           668665 non-null  int64
#  1   Age                          668665 non-null  int64
#  2   Annual_Income_USD            668665 non-null  float64
#  3   Daily_Commute_km             668665 non-null  float64
#  4   Number_of_Cars_Owned         668665 non-null  int64
#  5   Charging_Stations_Near_Home  668665 non-null  int64
#  6   Charging_Stations_Near_Work  668665 non-null  int64
#  7   Environmental_Concern_Level  668665 non-null  float64
#  8   Gender                       668665 non-null  object
#  9   City_Type                    668665 non-null  object
#  10  Current_Car_Type             668665 non-null  object
#  11  Home_Charging_Possible       668665 non-null  object
#  12  Subsidy_Available            668665 non-null  object
#  13  Range_Anxiety_Level          668665 non-null  object
#  14  Will_Buy_EV                  668665 non-null  object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 76.5+ MB
# 2026-09-03 18:21:29 | INFO     | Test Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286571 entries, 0 to 286570
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           286571 non-null  int64
#  1   Age                          286571 non-null  int64
#  2   Annual_Income_USD            286571 non-null  float64
#  3   Daily_Commute_km             286571 non-null  float64
#  4   Number_of_Cars_Owned         286571 non-null  int64
#  5   Charging_Stations_Near_Home  286571 non-null  int64
#  6   Charging_Stations_Near_Work  286571 non-null  int64
#  7   Environmental_Concern_Level  286571 non-null  float64
#  8   Gender                       286571 non-null  object
#  9   City_Type                    286571 non-null  object
#  10  Current_Car_Type             286571 non-null  object
#  11  Home_Charging_Possible       286571 non-null  object
#  12  Subsidy_Available            286571 non-null  object
#  13  Range_Anxiety_Level          286571 non-null  object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 30.6+ MB
# 2026-09-03 18:21:29 | INFO     | Original Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Buyer_ID                     10000 non-null  object
#  1   Age                          10000 non-null  int64
#  2   Gender                       10000 non-null  object
#  3   Annual_Income_USD            9822 non-null   float64
#  4   City_Type                    10000 non-null  object
#  5   Daily_Commute_km             9819 non-null   float64
#  6   Number_of_Cars_Owned         10000 non-null  int64
#  7   Current_Car_Type             10000 non-null  object
#  8   Charging_Stations_Near_Home  10000 non-null  int64
#  9   Charging_Stations_Near_Work  10000 non-null  int64
#  10  Home_Charging_Possible       10000 non-null  object
#  11  Environmental_Concern_Level  9816 non-null   float64
#  12  Subsidy_Available            10000 non-null  object
#  13  Range_Anxiety_Level          10000 non-null  object
#  14  Will_Buy_EV                  10000 non-null  object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <h2 style="color:#90E0EF; margin-top:0;">🚗 Insights from Initial Data Exploration</h2>
#
# <h3>Dataset Overview</h3>
# <ul>
#   <li><b>Training dataset:</b> 668,665 samples with 15 columns, including the target <code>Will_Buy_EV</code>.</li>
#   <li><b>Test dataset:</b> 286,571 samples with 14 columns, with the target variable excluded.</li>
#   <li><b>Original dataset:</b> 10,000 observations with 15 columns, using <code>Buyer_ID</code> as the identifier and containing the original target <code>Will_Buy_EV</code>.</li>
#   <li>The competition datasets contain a combined <b>955,236 observations</b>, substantially larger than the original 10,000-row dataset.</li>
# </ul>
#
# <h3>Feature Overview</h3>
# <ul>
#   <li><b>Numerical features (8):</b> <code>Age</code>, <code>Annual_Income_USD</code>, <code>Daily_Commute_km</code>, <code>Number_of_Cars_Owned</code>, <code>Charging_Stations_Near_Home</code>, <code>Charging_Stations_Near_Work</code>, and <code>Environmental_Concern_Level</code>, together with the numerical identifier <code>id</code>.</li>
#   <li><b>Categorical features (6):</b> <code>Gender</code>, <code>City_Type</code>, <code>Current_Car_Type</code>, <code>Home_Charging_Possible</code>, <code>Subsidy_Available</code>, and <code>Range_Anxiety_Level</code>.</li>
#   <li><code>Will_Buy_EV</code> is the binary classification target indicating whether a consumer is likely to purchase an electric vehicle.</li>
# </ul>
#
# <h3>Data Quality</h3>
# <ul>
#   <li>The <b>competition train and test datasets are complete</b>, with no missing values across any of the predictor variables.</li>
#   <li>In contrast, the <b>original dataset contains missing values</b> in <code>Annual_Income_USD</code>, <code>Daily_Commute_km</code>, and <code>Environmental_Concern_Level</code>.</li>
#   <li>The competition version therefore appears to have undergone <b>data preprocessing or transformation</b> compared with the original dataset, resulting in a much larger dataset with no missing values.</li>
#   <li>Numerical variables are stored as <code>int64</code> or <code>float64</code>, while categorical variables are stored as <code>object</code> and will require appropriate encoding for machine learning models.</li>
# </ul>
#
# <h3>Memory and Efficiency</h3>
# <ul>
#   <li>The training dataset occupies approximately <b>76.5 MB</b> of memory, while the test dataset occupies approximately <b>30.6 MB</b>.</li>
#   <li>Given the combined dataset size of more than <b>955,000 observations</b>, memory-efficient data processing becomes important during EDA and model development.</li>
#   <li>Converting categorical variables to the <code>category</code> dtype can help reduce memory usage and improve computational efficiency.</li>
# </ul>
#
# <h3>Initial Observations</h3>
# <ul>
#   <li>The dataset combines <b>demographic</b>, <b>financial</b>, <b>driving</b>, <b>charging infrastructure</b>, <b>environmental</b>, and <b>behavioral</b> factors, providing multiple perspectives for predicting EV purchase decisions.</li>
#   <li>Features such as <code>Annual_Income_USD</code>, <code>Daily_Commute_km</code>, and <code>Number_of_Cars_Owned</code> may capture the consumer's financial capacity and transportation needs.</li>
#   <li>Charging-related variables, particularly <code>Charging_Stations_Near_Home</code>, <code>Charging_Stations_Near_Work</code>, and <code>Home_Charging_Possible</code>, may provide important signals about the practicality of EV ownership.</li>
#   <li><code>Environmental_Concern_Level</code>, <code>Subsidy_Available</code>, and <code>Range_Anxiety_Level</code> represent important behavioral and policy-related factors that may influence EV adoption.</li>
#   <li>The identifier <code>id</code>, <code>Buyer_ID</code> do not represent a meaningful consumer characteristic and should be <b>excluded from model training</b> to avoid introducing non-predictive information.</li>
# </ul>
#
# </div>

# %%
# Drop columns id
df_train.drop(columns=CFG.COLUMNS_TRAIN_TEST, inplace=True)
list_test_id = df_test[CFG.COLUMNS_TRAIN_TEST[0]].copy().to_list()
df_test.drop(columns=CFG.COLUMNS_TRAIN_TEST, inplace=True)
df_original.drop(columns=CFG.COLUMNS_ORIGINAL, inplace=True)

# Numerical features
num_features = [
    "Age",
    "Annual_Income_USD",
    "Daily_Commute_km",
    "Charging_Stations_Near_Home",
    "Charging_Stations_Near_Work"
]

# Categorical features
cat_features = [
    "Gender",
    "City_Type",
    "Current_Car_Type",
    "Home_Charging_Possible",
    "Subsidy_Available",
    "Environmental_Concern_Level",
    "Range_Anxiety_Level",
    "Number_of_Cars_Owned"
]

# Reduce memory and convert to category
df_train = Utils.reduce_mem_usage(cols=num_features, df=df_train)
df_test = Utils.reduce_mem_usage(cols=num_features, df=df_test)
df_original = Utils.reduce_mem_usage(cols=num_features, df=df_original)

df_train = Utils.convert_cat(features=cat_features, df=df_train)
df_test = Utils.convert_cat(features=cat_features, df=df_test)
df_original = Utils.convert_cat(features=cat_features, df=df_original)

# Display information about the DataFrames
for name, df in datasets.items():
    logger.info(f"{name} Data Info After Reducing")
    df.info()
# Out:
# 2026-09-03 18:21:30 | INFO     | Train Data Info After Reducing
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668665 entries, 0 to 668664
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Age                          668665 non-null  int8
#  1   Annual_Income_USD            668665 non-null  float32
#  2   Daily_Commute_km             668665 non-null  float32
#  3   Number_of_Cars_Owned         668665 non-null  category
#  4   Charging_Stations_Near_Home  668665 non-null  int8
#  5   Charging_Stations_Near_Work  668665 non-null  int8
#  6   Environmental_Concern_Level  668665 non-null  category
#  7   Gender                       668665 non-null  category
#  8   City_Type                    668665 non-null  category
#  9   Current_Car_Type             668665 non-null  category
#  10  Home_Charging_Possible       668665 non-null  category
#  11  Subsidy_Available            668665 non-null  category
#  12  Range_Anxiety_Level          668665 non-null  category
#  13  Will_Buy_EV                  668665 non-null  object
# dtypes: category(8), float32(2), int8(3), object(1)
# memory usage: 17.2+ MB
# 2026-09-03 18:21:30 | INFO     | Test Data Info After Reducing
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286571 entries, 0 to 286570
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Age                          286571 non-null  int8
#  1   Annual_Income_USD            286571 non-null  float32
#  2   Daily_Commute_km             286571 non-null  float32
#  3   Number_of_Cars_Owned         286571 non-null  category
#  4   Charging_Stations_Near_Home  286571 non-null  int8
#  5   Charging_Stations_Near_Work  286571 non-null  int8
#  6   Environmental_Concern_Level  286571 non-null  category
#  7   Gender                       286571 non-null  category
#  8   City_Type                    286571 non-null  category
#  9   Current_Car_Type             286571 non-null  category
#  10  Home_Charging_Possible       286571 non-null  category
#  11  Subsidy_Available            286571 non-null  category
#  12  Range_Anxiety_Level          286571 non-null  category
# dtypes: category(8), float32(2), int8(3)
# memory usage: 5.2 MB
# 2026-09-03 18:21:30 | INFO     | Original Data Info After Reducing
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          10000 non-null  int8
#  1   Gender                       10000 non-null  category
#  2   Annual_Income_USD            9822 non-null   float32
#  3   City_Type                    10000 non-null  category
#  4   Daily_Commute_km             9819 non-null   float32
#  5   Number_of_Cars_Owned         10000 non-null  category
#  6   Current_Car_Type             10000 non-null  category
#  7   Charging_Stations_Near_Home  10000 non-null  int8
#  8   Charging_Stations_Near_Work  10000 non-null  int8
#  9   Home_Charging_Possible       10000 non-null  category
#  10  Environmental_Concern_Level  9816 non-null   category
#  11  Subsidy_Available            10000 non-null  category
#  12  Range_Anxiety_Level          10000 non-null  category
#  13  Will_Buy_EV                  10000 non-null  object
# dtypes: category(8), float32(2), int8(3), object(1)
# memory usage: 265.0+ KB

# %% [markdown]
# ## Numerical Feature Summary — Data Analyst Perspective

# %%
cm = sns.light_palette("blue", as_cmap=True)
for name, df in datasets.items():
    logger.info(f"{name} Data Describe:")
    display(df[num_features].describe().T.style.background_gradient(cmap=cm))
# Out:
# 2026-09-03 18:21:30 | INFO     | Train Data Describe:
# <style type="text/css">
# #T_521b7_row0_col0, #T_521b7_row0_col1, #T_521b7_row0_col2, #T_521b7_row0_col3, #T_521b7_row0_col4, #T_521b7_row0_col5, #T_521b7_row0_col6, #T_521b7_row0_col7, #T_521b7_row1_col0, #T_521b7_row2_col0, #T_521b7_row2_col1, #T_521b7_row2_col2, #T_521b7_row2_col3, #T_521b7_row2_col4, #T_521b7_row2_col5, #T_521b7_row2_col6, #T_521b7_row2_col7, #T_521b7_row3_col0, #T_521b7_row3_col1, #T_521b7_row3_col2, #T_521b7_row3_col3, #T_521b7_row3_col4, #T_521b7_row3_col5, #T_521b7_row3_col6, #T_521b7_row3_col7, #T_521b7_row4_col0, #T_521b7_row4_col1, #T_521b7_row4_col2, #T_521b7_row4_col3, #T_521b7_row4_col4, #T_521b7_row4_col5, #T_521b7_row4_col6, #T_521b7_row4_col7 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_521b7_row1_col1, #T_521b7_row1_col2, #T_521b7_row1_col3, #T_521b7_row1_col4, #T_521b7_row1_col5, #T_521b7_row1_col6, #T_521b7_row1_col7 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_521b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_521b7_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_521b7_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_521b7_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_521b7_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_521b7_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_521b7_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_521b7_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_521b7_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_521b7_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_521b7_row0_col0" class="data row0 col0" >668665.000000</td>
#       <td id="T_521b7_row0_col1" class="data row0 col1" >47.039171</td>
#       <td id="T_521b7_row0_col2" class="data row0 col2" >12.875448</td>
#       <td id="T_521b7_row0_col3" class="data row0 col3" >25.000000</td>
#       <td id="T_521b7_row0_col4" class="data row0 col4" >36.000000</td>
#       <td id="T_521b7_row0_col5" class="data row0 col5" >47.000000</td>
#       <td id="T_521b7_row0_col6" class="data row0 col6" >58.000000</td>
#       <td id="T_521b7_row0_col7" class="data row0 col7" >69.000000</td>
#     </tr>
#     <tr>
#       <th id="T_521b7_level0_row1" class="row_heading level0 row1" >Annual_Income_USD</th>
#       <td id="T_521b7_row1_col0" class="data row1 col0" >668665.000000</td>
#       <td id="T_521b7_row1_col1" class="data row1 col1" >84769.289062</td>
#       <td id="T_521b7_row1_col2" class="data row1 col2" >28648.029297</td>
#       <td id="T_521b7_row1_col3" class="data row1 col3" >30000.000000</td>
#       <td id="T_521b7_row1_col4" class="data row1 col4" >67376.000000</td>
#       <td id="T_521b7_row1_col5" class="data row1 col5" >84880.000000</td>
#       <td id="T_521b7_row1_col6" class="data row1 col6" >102753.000000</td>
#       <td id="T_521b7_row1_col7" class="data row1 col7" >188549.000000</td>
#     </tr>
#     <tr>
#       <th id="T_521b7_level0_row2" class="row_heading level0 row2" >Daily_Commute_km</th>
#       <td id="T_521b7_row2_col0" class="data row2 col0" >668665.000000</td>
#       <td id="T_521b7_row2_col1" class="data row2 col1" >32.158298</td>
#       <td id="T_521b7_row2_col2" class="data row2 col2" >18.730474</td>
#       <td id="T_521b7_row2_col3" class="data row2 col3" >5.000000</td>
#       <td id="T_521b7_row2_col4" class="data row2 col4" >17.200001</td>
#       <td id="T_521b7_row2_col5" class="data row2 col5" >33.599998</td>
#       <td id="T_521b7_row2_col6" class="data row2 col6" >47.400002</td>
#       <td id="T_521b7_row2_col7" class="data row2 col7" >98.699997</td>
#     </tr>
#     <tr>
#       <th id="T_521b7_level0_row3" class="row_heading level0 row3" >Charging_Stations_Near_Home</th>
#       <td id="T_521b7_row3_col0" class="data row3 col0" >668665.000000</td>
#       <td id="T_521b7_row3_col1" class="data row3 col1" >4.960408</td>
#       <td id="T_521b7_row3_col2" class="data row3 col2" >3.926843</td>
#       <td id="T_521b7_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_521b7_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_521b7_row3_col5" class="data row3 col5" >4.000000</td>
#       <td id="T_521b7_row3_col6" class="data row3 col6" >7.000000</td>
#       <td id="T_521b7_row3_col7" class="data row3 col7" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_521b7_level0_row4" class="row_heading level0 row4" >Charging_Stations_Near_Work</th>
#       <td id="T_521b7_row4_col0" class="data row4 col0" >668665.000000</td>
#       <td id="T_521b7_row4_col1" class="data row4 col1" >7.176314</td>
#       <td id="T_521b7_row4_col2" class="data row4 col2" >5.186627</td>
#       <td id="T_521b7_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_521b7_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_521b7_row4_col5" class="data row4 col5" >6.000000</td>
#       <td id="T_521b7_row4_col6" class="data row4 col6" >10.000000</td>
#       <td id="T_521b7_row4_col7" class="data row4 col7" >19.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:21:30 | INFO     | Test Data Describe:
# <style type="text/css">
# #T_88eb4_row0_col0, #T_88eb4_row0_col1, #T_88eb4_row0_col2, #T_88eb4_row0_col3, #T_88eb4_row0_col4, #T_88eb4_row0_col5, #T_88eb4_row0_col6, #T_88eb4_row0_col7, #T_88eb4_row1_col0, #T_88eb4_row2_col0, #T_88eb4_row2_col1, #T_88eb4_row2_col2, #T_88eb4_row2_col3, #T_88eb4_row2_col4, #T_88eb4_row2_col5, #T_88eb4_row2_col6, #T_88eb4_row2_col7, #T_88eb4_row3_col0, #T_88eb4_row3_col1, #T_88eb4_row3_col2, #T_88eb4_row3_col3, #T_88eb4_row3_col4, #T_88eb4_row3_col5, #T_88eb4_row3_col6, #T_88eb4_row3_col7, #T_88eb4_row4_col0, #T_88eb4_row4_col1, #T_88eb4_row4_col2, #T_88eb4_row4_col3, #T_88eb4_row4_col4, #T_88eb4_row4_col5, #T_88eb4_row4_col6, #T_88eb4_row4_col7 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_88eb4_row1_col1, #T_88eb4_row1_col2, #T_88eb4_row1_col3, #T_88eb4_row1_col4, #T_88eb4_row1_col5, #T_88eb4_row1_col6, #T_88eb4_row1_col7 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_88eb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88eb4_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_88eb4_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_88eb4_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_88eb4_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_88eb4_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_88eb4_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_88eb4_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_88eb4_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88eb4_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_88eb4_row0_col0" class="data row0 col0" >286571.000000</td>
#       <td id="T_88eb4_row0_col1" class="data row0 col1" >47.070824</td>
#       <td id="T_88eb4_row0_col2" class="data row0 col2" >12.864850</td>
#       <td id="T_88eb4_row0_col3" class="data row0 col3" >25.000000</td>
#       <td id="T_88eb4_row0_col4" class="data row0 col4" >36.000000</td>
#       <td id="T_88eb4_row0_col5" class="data row0 col5" >47.000000</td>
#       <td id="T_88eb4_row0_col6" class="data row0 col6" >58.000000</td>
#       <td id="T_88eb4_row0_col7" class="data row0 col7" >69.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88eb4_level0_row1" class="row_heading level0 row1" >Annual_Income_USD</th>
#       <td id="T_88eb4_row1_col0" class="data row1 col0" >286571.000000</td>
#       <td id="T_88eb4_row1_col1" class="data row1 col1" >84799.515625</td>
#       <td id="T_88eb4_row1_col2" class="data row1 col2" >28626.851562</td>
#       <td id="T_88eb4_row1_col3" class="data row1 col3" >30000.000000</td>
#       <td id="T_88eb4_row1_col4" class="data row1 col4" >67380.000000</td>
#       <td id="T_88eb4_row1_col5" class="data row1 col5" >84926.000000</td>
#       <td id="T_88eb4_row1_col6" class="data row1 col6" >102751.000000</td>
#       <td id="T_88eb4_row1_col7" class="data row1 col7" >186936.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88eb4_level0_row2" class="row_heading level0 row2" >Daily_Commute_km</th>
#       <td id="T_88eb4_row2_col0" class="data row2 col0" >286571.000000</td>
#       <td id="T_88eb4_row2_col1" class="data row2 col1" >32.159302</td>
#       <td id="T_88eb4_row2_col2" class="data row2 col2" >18.724436</td>
#       <td id="T_88eb4_row2_col3" class="data row2 col3" >5.000000</td>
#       <td id="T_88eb4_row2_col4" class="data row2 col4" >17.200001</td>
#       <td id="T_88eb4_row2_col5" class="data row2 col5" >33.599998</td>
#       <td id="T_88eb4_row2_col6" class="data row2 col6" >47.299999</td>
#       <td id="T_88eb4_row2_col7" class="data row2 col7" >103.900002</td>
#     </tr>
#     <tr>
#       <th id="T_88eb4_level0_row3" class="row_heading level0 row3" >Charging_Stations_Near_Home</th>
#       <td id="T_88eb4_row3_col0" class="data row3 col0" >286571.000000</td>
#       <td id="T_88eb4_row3_col1" class="data row3 col1" >4.950693</td>
#       <td id="T_88eb4_row3_col2" class="data row3 col2" >3.928626</td>
#       <td id="T_88eb4_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_88eb4_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_88eb4_row3_col5" class="data row3 col5" >4.000000</td>
#       <td id="T_88eb4_row3_col6" class="data row3 col6" >7.000000</td>
#       <td id="T_88eb4_row3_col7" class="data row3 col7" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88eb4_level0_row4" class="row_heading level0 row4" >Charging_Stations_Near_Work</th>
#       <td id="T_88eb4_row4_col0" class="data row4 col0" >286571.000000</td>
#       <td id="T_88eb4_row4_col1" class="data row4 col1" >7.155626</td>
#       <td id="T_88eb4_row4_col2" class="data row4 col2" >5.186880</td>
#       <td id="T_88eb4_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_88eb4_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_88eb4_row4_col5" class="data row4 col5" >6.000000</td>
#       <td id="T_88eb4_row4_col6" class="data row4 col6" >10.000000</td>
#       <td id="T_88eb4_row4_col7" class="data row4 col7" >19.000000</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:21:30 | INFO     | Original Data Describe:
# <style type="text/css">
# #T_88311_row0_col0, #T_88311_row1_col1, #T_88311_row1_col2, #T_88311_row1_col3, #T_88311_row1_col4, #T_88311_row1_col5, #T_88311_row1_col6, #T_88311_row1_col7, #T_88311_row3_col0, #T_88311_row4_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_88311_row0_col1, #T_88311_row0_col2, #T_88311_row0_col3, #T_88311_row0_col4, #T_88311_row0_col5, #T_88311_row0_col6, #T_88311_row0_col7, #T_88311_row2_col0, #T_88311_row2_col1, #T_88311_row2_col2, #T_88311_row2_col3, #T_88311_row2_col4, #T_88311_row2_col5, #T_88311_row2_col6, #T_88311_row2_col7, #T_88311_row3_col1, #T_88311_row3_col2, #T_88311_row3_col3, #T_88311_row3_col4, #T_88311_row3_col5, #T_88311_row3_col6, #T_88311_row3_col7, #T_88311_row4_col1, #T_88311_row4_col2, #T_88311_row4_col3, #T_88311_row4_col4, #T_88311_row4_col5, #T_88311_row4_col6, #T_88311_row4_col7 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_88311_row1_col0 {
#   background-color: #ededf3;
#   color: #000000;
# }
# </style>
# <table id="T_88311">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88311_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_88311_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_88311_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_88311_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_88311_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_88311_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_88311_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_88311_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88311_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_88311_row0_col0" class="data row0 col0" >10000.000000</td>
#       <td id="T_88311_row0_col1" class="data row0 col1" >46.936200</td>
#       <td id="T_88311_row0_col2" class="data row0 col2" >12.945968</td>
#       <td id="T_88311_row0_col3" class="data row0 col3" >25.000000</td>
#       <td id="T_88311_row0_col4" class="data row0 col4" >36.000000</td>
#       <td id="T_88311_row0_col5" class="data row0 col5" >47.000000</td>
#       <td id="T_88311_row0_col6" class="data row0 col6" >58.000000</td>
#       <td id="T_88311_row0_col7" class="data row0 col7" >69.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88311_level0_row1" class="row_heading level0 row1" >Annual_Income_USD</th>
#       <td id="T_88311_row1_col0" class="data row1 col0" >9822.000000</td>
#       <td id="T_88311_row1_col1" class="data row1 col1" >85378.492188</td>
#       <td id="T_88311_row1_col2" class="data row1 col2" >32838.683594</td>
#       <td id="T_88311_row1_col3" class="data row1 col3" >30000.000000</td>
#       <td id="T_88311_row1_col4" class="data row1 col4" >61369.500000</td>
#       <td id="T_88311_row1_col5" class="data row1 col5" >84708.000000</td>
#       <td id="T_88311_row1_col6" class="data row1 col6" >107383.250000</td>
#       <td id="T_88311_row1_col7" class="data row1 col7" >223345.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88311_level0_row2" class="row_heading level0 row2" >Daily_Commute_km</th>
#       <td id="T_88311_row2_col0" class="data row2 col0" >9819.000000</td>
#       <td id="T_88311_row2_col1" class="data row2 col1" >41.105415</td>
#       <td id="T_88311_row2_col2" class="data row2 col2" >23.351276</td>
#       <td id="T_88311_row2_col3" class="data row2 col3" >5.000000</td>
#       <td id="T_88311_row2_col4" class="data row2 col4" >23.250000</td>
#       <td id="T_88311_row2_col5" class="data row2 col5" >40.200001</td>
#       <td id="T_88311_row2_col6" class="data row2 col6" >57.000000</td>
#       <td id="T_88311_row2_col7" class="data row2 col7" >135.500000</td>
#     </tr>
#     <tr>
#       <th id="T_88311_level0_row3" class="row_heading level0 row3" >Charging_Stations_Near_Home</th>
#       <td id="T_88311_row3_col0" class="data row3 col0" >10000.000000</td>
#       <td id="T_88311_row3_col1" class="data row3 col1" >5.346900</td>
#       <td id="T_88311_row3_col2" class="data row3 col2" >4.049074</td>
#       <td id="T_88311_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_88311_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_88311_row3_col5" class="data row3 col5" >5.000000</td>
#       <td id="T_88311_row3_col6" class="data row3 col6" >8.000000</td>
#       <td id="T_88311_row3_col7" class="data row3 col7" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88311_level0_row4" class="row_heading level0 row4" >Charging_Stations_Near_Work</th>
#       <td id="T_88311_row4_col0" class="data row4 col0" >10000.000000</td>
#       <td id="T_88311_row4_col1" class="data row4 col1" >7.458200</td>
#       <td id="T_88311_row4_col2" class="data row4 col2" >5.259374</td>
#       <td id="T_88311_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_88311_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_88311_row4_col5" class="data row4 col5" >6.000000</td>
#       <td id="T_88311_row4_col6" class="data row4 col6" >11.000000</td>
#       <td id="T_88311_row4_col7" class="data row4 col7" >19.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#90E0EF;
#     margin:0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 🚗 Descriptive Statistics
# </div>
#
# <ul style="line-height:1.8; padding-left:20px;">
#
# <li><code>Age</code>: Consumers have an average age of approximately <b>47 years</b>, with the middle 50% ranging from <b>36 to 58 years</b>. The distribution is highly consistent across the Train, Test, and Original datasets, indicating a stable consumer age profile.</li>
#
# <li><code>Annual_Income_USD</code>: Average annual income is approximately <b>$84,769</b> in the Train dataset and <b>$84,800</b> in the Test dataset, with median income around <b>$84,880–$84,926</b>. The middle 50% of consumers earn roughly between <b>$67,400 and $102,753</b>, suggesting a relatively broad income range across the population.</li>
#
# <li><code>Daily_Commute_km</code>: Consumers travel approximately <b>32.2 km per day</b> on average in the Train dataset, with the middle 50% commuting between <b>17.0 and 47.4 km</b>. The Test dataset shows a very similar distribution, while the Original dataset has a noticeably higher average commute of approximately <b>41.1 km</b>, indicating some distribution differences between the original and competition data.</li>
#
# <li><code>Charging_Stations_Near_Home</code>: Consumers have approximately <b>5 charging stations</b> near their homes on average, with a median of <b>4 stations</b>. Around 75% of observations have no more than <b>7 stations</b> nearby, indicating relatively moderate access to home-area charging infrastructure.</li>
#
# <li><code>Charging_Stations_Near_Work</code>: The average number of charging stations near the workplace is approximately <b>7.2</b>, with a median of <b>6 stations</b>. The higher availability compared with home charging suggests that workplace areas may provide broader access to charging infrastructure.</li>
#
# <li><code>Train vs Test</code>: The Train and Test datasets show <b>highly consistent descriptive statistics</b> across age, income, commuting distance, and charging infrastructure. The close alignment of means, medians, quartiles, and standard deviations suggests <b>no major distribution shift</b> between the competition training and test sets.</li>
#
# <li><code>Train/Test vs Original</code>: The competition datasets generally preserve the overall characteristics of the Original dataset, particularly for <code>Age</code> and <code>Annual_Income_USD</code>. However, <code>Daily_Commute_km</code> shows a noticeable difference, with the Original dataset having a higher average and wider upper range than the competition data.</li>
#
# <li><code>Overall</code>: The numerical variables capture several important dimensions of EV adoption, including <b>consumer demographics</b>, <b>financial capacity</b>, <b>daily transportation needs</b>, and <b>charging infrastructure availability</b>. These characteristics provide a strong foundation for analyzing and predicting electric vehicle purchase decisions.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# ## Categorical Feature Summary — Data Analyst Perspective

# %%
for name, df in datasets.items():
    logger.info(f"{name} Data Describe:")
    display(df[cat_features].astype("category").describe().T.style.background_gradient(cmap="Blues", subset=["unique", "freq"]))
# Out:
# 2026-09-03 18:21:30 | INFO     | Train Data Describe:
# <style type="text/css">
# #T_94aa7_row0_col1, #T_94aa7_row1_col1, #T_94aa7_row6_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_94aa7_row0_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_94aa7_row1_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_94aa7_row2_col1, #T_94aa7_row7_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_94aa7_row2_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_94aa7_row3_col1, #T_94aa7_row4_col1, #T_94aa7_row5_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_94aa7_row3_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_94aa7_row4_col3 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_94aa7_row5_col1, #T_94aa7_row6_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_94aa7_row7_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# </style>
# <table id="T_94aa7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94aa7_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_94aa7_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_94aa7_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_94aa7_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94aa7_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_94aa7_row0_col0" class="data row0 col0" >668665</td>
#       <td id="T_94aa7_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_94aa7_row0_col2" class="data row0 col2" >Male</td>
#       <td id="T_94aa7_row0_col3" class="data row0 col3" >367954</td>
#     </tr>
#     <tr>
#       <th id="T_94aa7_level0_row1" class="row_heading level0 row1" >City_Type</th>
#       <td id="T_94aa7_row1_col0" class="data row1 col0" >668665</td>
#       <td id="T_94aa7_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_94aa7_row1_col2" class="data row1 col2" >Urban</td>
#       <td id="T_94aa7_row1_col3" class="data row1 col3" >289305</td>
#     </tr>
#     <tr>
#       <th id="T_94aa7_level0_row2" class="row_heading level0 row2" >Current_Car_Type</th>
#       <td id="T_94aa7_row2_col0" class="data row2 col0" >668665</td>
#       <td id="T_94aa7_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_94aa7_row2_col2" class="data row2 col2" >Sedan</td>
#       <td id="T_94aa7_row2_col3" class="data row2 col3" >303459</td>
#     </tr>
#     <tr>
#       <th id="T_94aa7_level0_row3" class="row_heading level0 row3" >Home_Charging_Possible</th>
#       <td id="T_94aa7_row3_col0" class="data row3 col0" >668665</td>
#       <td id="T_94aa7_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_94aa7_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_94aa7_row3_col3" class="data row3 col3" >462677</td>
#     </tr>
#     <tr>
#       <th id="T_94aa7_level0_row4" class="row_heading level0 row4" >Subsidy_Available</th>
#       <td id="T_94aa7_row4_col0" class="data row4 col0" >668665</td>
#       <td id="T_94aa7_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_94aa7_row4_col2" class="data row4 col2" >Yes</td>
#       <td id="T_94aa7_row4_col3" class="data row4 col3" >419909</td>
#     </tr>
#     <tr>
#       <th id="T_94aa7_level0_row5" class="row_heading level0 row5" >Environmental_Concern_Level</th>
#       <td id="T_94aa7_row5_col0" class="data row5 col0" >668665.000000</td>
#       <td id="T_94aa7_row5_col1" class="data row5 col1" >5.000000</td>
#       <td id="T_94aa7_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_94aa7_row5_col3" class="data row5 col3" >147476.000000</td>
#     </tr>
#     <tr>
#       <th id="T_94aa7_level0_row6" class="row_heading level0 row6" >Range_Anxiety_Level</th>
#       <td id="T_94aa7_row6_col0" class="data row6 col0" >668665</td>
#       <td id="T_94aa7_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_94aa7_row6_col2" class="data row6 col2" >Low</td>
#       <td id="T_94aa7_row6_col3" class="data row6 col3" >603972</td>
#     </tr>
#     <tr>
#       <th id="T_94aa7_level0_row7" class="row_heading level0 row7" >Number_of_Cars_Owned</th>
#       <td id="T_94aa7_row7_col0" class="data row7 col0" >668665</td>
#       <td id="T_94aa7_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_94aa7_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_94aa7_row7_col3" class="data row7 col3" >298287</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:21:30 | INFO     | Test Data Describe:
# <style type="text/css">
# #T_37cbd_row0_col1, #T_37cbd_row1_col1, #T_37cbd_row6_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_37cbd_row0_col3 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_37cbd_row1_col3 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_37cbd_row2_col1, #T_37cbd_row7_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_37cbd_row2_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_37cbd_row3_col1, #T_37cbd_row4_col1, #T_37cbd_row5_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_37cbd_row3_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_37cbd_row4_col3 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_37cbd_row5_col1, #T_37cbd_row6_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_37cbd_row7_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# </style>
# <table id="T_37cbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37cbd_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_37cbd_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_37cbd_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_37cbd_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37cbd_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_37cbd_row0_col0" class="data row0 col0" >286571</td>
#       <td id="T_37cbd_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_37cbd_row0_col2" class="data row0 col2" >Male</td>
#       <td id="T_37cbd_row0_col3" class="data row0 col3" >157647</td>
#     </tr>
#     <tr>
#       <th id="T_37cbd_level0_row1" class="row_heading level0 row1" >City_Type</th>
#       <td id="T_37cbd_row1_col0" class="data row1 col0" >286571</td>
#       <td id="T_37cbd_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_37cbd_row1_col2" class="data row1 col2" >Urban</td>
#       <td id="T_37cbd_row1_col3" class="data row1 col3" >123602</td>
#     </tr>
#     <tr>
#       <th id="T_37cbd_level0_row2" class="row_heading level0 row2" >Current_Car_Type</th>
#       <td id="T_37cbd_row2_col0" class="data row2 col0" >286571</td>
#       <td id="T_37cbd_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_37cbd_row2_col2" class="data row2 col2" >Sedan</td>
#       <td id="T_37cbd_row2_col3" class="data row2 col3" >130185</td>
#     </tr>
#     <tr>
#       <th id="T_37cbd_level0_row3" class="row_heading level0 row3" >Home_Charging_Possible</th>
#       <td id="T_37cbd_row3_col0" class="data row3 col0" >286571</td>
#       <td id="T_37cbd_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_37cbd_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_37cbd_row3_col3" class="data row3 col3" >198480</td>
#     </tr>
#     <tr>
#       <th id="T_37cbd_level0_row4" class="row_heading level0 row4" >Subsidy_Available</th>
#       <td id="T_37cbd_row4_col0" class="data row4 col0" >286571</td>
#       <td id="T_37cbd_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_37cbd_row4_col2" class="data row4 col2" >Yes</td>
#       <td id="T_37cbd_row4_col3" class="data row4 col3" >180378</td>
#     </tr>
#     <tr>
#       <th id="T_37cbd_level0_row5" class="row_heading level0 row5" >Environmental_Concern_Level</th>
#       <td id="T_37cbd_row5_col0" class="data row5 col0" >286571.000000</td>
#       <td id="T_37cbd_row5_col1" class="data row5 col1" >5.000000</td>
#       <td id="T_37cbd_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_37cbd_row5_col3" class="data row5 col3" >63125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_37cbd_level0_row6" class="row_heading level0 row6" >Range_Anxiety_Level</th>
#       <td id="T_37cbd_row6_col0" class="data row6 col0" >286571</td>
#       <td id="T_37cbd_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_37cbd_row6_col2" class="data row6 col2" >Low</td>
#       <td id="T_37cbd_row6_col3" class="data row6 col3" >259247</td>
#     </tr>
#     <tr>
#       <th id="T_37cbd_level0_row7" class="row_heading level0 row7" >Number_of_Cars_Owned</th>
#       <td id="T_37cbd_row7_col0" class="data row7 col0" >286571</td>
#       <td id="T_37cbd_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_37cbd_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_37cbd_row7_col3" class="data row7 col3" >127869</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:21:30 | INFO     | Original Data Describe:
# <style type="text/css">
# #T_03906_row0_col1, #T_03906_row1_col1, #T_03906_row6_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_03906_row0_col3 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_03906_row1_col3 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_03906_row2_col1, #T_03906_row7_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_03906_row2_col3 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_03906_row3_col1, #T_03906_row4_col1, #T_03906_row5_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_03906_row3_col3 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_03906_row4_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_03906_row5_col1, #T_03906_row6_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_03906_row7_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# </style>
# <table id="T_03906">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03906_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_03906_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_03906_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_03906_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03906_level0_row0" class="row_heading level0 row0" >Gender</th>
#       <td id="T_03906_row0_col0" class="data row0 col0" >10000</td>
#       <td id="T_03906_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_03906_row0_col2" class="data row0 col2" >Male</td>
#       <td id="T_03906_row0_col3" class="data row0 col3" >5201</td>
#     </tr>
#     <tr>
#       <th id="T_03906_level0_row1" class="row_heading level0 row1" >City_Type</th>
#       <td id="T_03906_row1_col0" class="data row1 col0" >10000</td>
#       <td id="T_03906_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_03906_row1_col2" class="data row1 col2" >Urban</td>
#       <td id="T_03906_row1_col3" class="data row1 col3" >4941</td>
#     </tr>
#     <tr>
#       <th id="T_03906_level0_row2" class="row_heading level0 row2" >Current_Car_Type</th>
#       <td id="T_03906_row2_col0" class="data row2 col0" >10000</td>
#       <td id="T_03906_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_03906_row2_col2" class="data row2 col2" >Sedan</td>
#       <td id="T_03906_row2_col3" class="data row2 col3" >4000</td>
#     </tr>
#     <tr>
#       <th id="T_03906_level0_row3" class="row_heading level0 row3" >Home_Charging_Possible</th>
#       <td id="T_03906_row3_col0" class="data row3 col0" >10000</td>
#       <td id="T_03906_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_03906_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_03906_row3_col3" class="data row3 col3" >6163</td>
#     </tr>
#     <tr>
#       <th id="T_03906_level0_row4" class="row_heading level0 row4" >Subsidy_Available</th>
#       <td id="T_03906_row4_col0" class="data row4 col0" >10000</td>
#       <td id="T_03906_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_03906_row4_col2" class="data row4 col2" >Yes</td>
#       <td id="T_03906_row4_col3" class="data row4 col3" >6008</td>
#     </tr>
#     <tr>
#       <th id="T_03906_level0_row5" class="row_heading level0 row5" >Environmental_Concern_Level</th>
#       <td id="T_03906_row5_col0" class="data row5 col0" >9816.000000</td>
#       <td id="T_03906_row5_col1" class="data row5 col1" >5.000000</td>
#       <td id="T_03906_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_03906_row5_col3" class="data row5 col3" >2013.000000</td>
#     </tr>
#     <tr>
#       <th id="T_03906_level0_row6" class="row_heading level0 row6" >Range_Anxiety_Level</th>
#       <td id="T_03906_row6_col0" class="data row6 col0" >10000</td>
#       <td id="T_03906_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_03906_row6_col2" class="data row6 col2" >Low</td>
#       <td id="T_03906_row6_col3" class="data row6 col3" >8310</td>
#     </tr>
#     <tr>
#       <th id="T_03906_level0_row7" class="row_heading level0 row7" >Number_of_Cars_Owned</th>
#       <td id="T_03906_row7_col0" class="data row7 col0" >10000</td>
#       <td id="T_03906_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_03906_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_03906_row7_col3" class="data row7 col3" >4020</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#90E0EF;
#     margin:0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 🚗 Categorical Feature Insights
# </div>
#
# <ul style="line-height:1.8; padding-left:20px;">
#
# <li><b>Gender</b>: All datasets contain <b>three gender categories</b>, with <code>Male</code> being the most frequently observed group. In the Train and Test datasets, males account for approximately <b>55%</b> of observations, while the Original dataset shows a slightly more balanced distribution with males representing <b>52%</b>.</li>
#
# <li><b>City_Type</b>: Three city categories are represented, with <code>Urban</code> being the dominant category. It accounts for approximately <b>43%</b> of the Train and Test datasets and nearly <b>49%</b> of the Original dataset, suggesting that urban consumers form an important segment of the population.</li>
#
# <li><b>Current_Car_Type</b>: Four vehicle categories are present, with <code>Sedan</code> being the most common current vehicle type. Sedans represent approximately <b>45%</b> of both the Train and Test datasets, compared with <b>40%</b> in the Original dataset.</li>
#
# <li><b>Home_Charging_Possible</b>: This binary feature is moderately concentrated toward <code>Yes</code>, which represents approximately <b>69%</b> of the Train and Test observations. The Original dataset has a lower proportion of consumers with home charging availability at approximately <b>62%</b>.</li>
#
# <li><b>Subsidy_Available</b>: Approximately <b>63%</b> of consumers in the Train and Test datasets have access to an available subsidy, compared with approximately <b>60%</b> in the Original dataset. This indicates that government incentives are available to a substantial proportion of the observed consumers.</li>
#
# <li><b>Environmental_Concern_Level</b>: This ordinal feature contains <b>five levels</b>. Level <code>1</code> is the most frequently observed category, accounting for approximately <b>22%</b> of the Train and Test observations. The distribution across the five levels should be examined further because the feature represents ordered levels of environmental concern rather than purely nominal categories.</li>
#
# <li><b>Range_Anxiety_Level</b>: The distribution is strongly concentrated in the <code>Low</code> category, representing approximately <b>90%</b> of both the Train and Test datasets. The Original dataset has a lower proportion of <code>Low</code> range anxiety at approximately <b>83%</b>, indicating a noticeable distribution difference between the original and competition datasets.</li>
#
# <li><b>Number_of_Cars_Owned</b>: Four ownership levels are represented, with consumers owning <code>2</code> cars being the most common group. This category accounts for approximately <b>45%</b> of the Train and Test datasets and <b>40%</b> of the Original dataset. Although this variable is numerical in storage, its low number of discrete values makes categorical treatment a reasonable modeling approach to evaluate.</li>
#
# <li><b>Low-cardinality features</b>: Most categorical variables contain only <b>2–4 categories</b>, making them straightforward to encode using One-Hot Encoding or other appropriate categorical encoding techniques. The ordinal variables <code>Environmental_Concern_Level</code> and <code>Range_Anxiety_Level</code> should preserve their inherent ordering during preprocessing.</li>
#
# <li><b>Distribution consistency</b>: The Train and Test datasets show <b>highly consistent categorical distributions</b> across all examined variables. However, several differences can be observed when compared with the Original dataset, particularly for <code>Range_Anxiety_Level</code>, <code>Home_Charging_Possible</code>, and <code>Current_Car_Type</code>.</li>
#
# <li><b>Overall</b>: These categorical and ordinal variables capture important aspects of <b>consumer demographics</b>, <b>vehicle ownership</b>, <b>charging accessibility</b>, <b>government incentives</b>, <b>environmental attitudes</b>, and <b>range anxiety</b>. Together, they provide important behavioral and contextual signals for predicting electric vehicle purchase decisions.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Data Quality Checks</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#     background: linear-gradient(
#     135deg,
#     #003B5C,
#     #0077B6 35%,
#     #00B4D8 65%,
#     #2A9D8F 100%
# );
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Data Quality Checks
#     </h1>
# </div>

# %% [markdown]
# ## Missing Value

# %%
logger.info("Start checking NULL values")
logger.info("-" * 80)
logger.info(f"Checking missing values for {CFG.DATASET_NAME}...")
for name, df in datasets.items():
    logger.info(f"{name} Data Checking:")
    DataValidator.checkNULL(df=df, logger=logger)
logger.info("-" * 80)
logger.info("Completed checking for NULL values across datasets.")
# Out:
# 2026-09-03 18:21:30 | INFO     | Start checking NULL values
# 2026-09-03 18:21:30 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:30 | INFO     | Checking missing values for EV Adoption Prediction Dataset...
# 2026-09-03 18:21:30 | INFO     | Train Data Checking:
# 2026-09-03 18:21:33 | INFO     | No missing values detected in 668,665 rows.
# 2026-09-03 18:21:33 | INFO     | Test Data Checking:
# 2026-09-03 18:21:34 | INFO     | No missing values detected in 286,571 rows.
# 2026-09-03 18:21:34 | INFO     | Original Data Checking:
# 2026-09-03 18:21:34 | WARNING  |
# +-----------------------------+---------------+-----------+
# | Feature                     | Missing_Count | Missing_% |
# +-----------------------------+---------------+-----------+
# | Environmental_Concern_Level | 184           | 1.84      |
# | Daily_Commute_km            | 181           | 1.81      |
# | Annual_Income_USD           | 178           | 1.78      |
# +-----------------------------+---------------+-----------+
# 2026-09-03 18:21:34 | WARNING  | Total missing values: 543 out of 10,000 rows.
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | INFO     | Completed checking for NULL values across datasets.

# %% [markdown]
# ## Checking duplicate Value

# %%
logger.info("Start checking duplicate values")
logger.info("-" * 80)
logger.info(f"Data duplicate Analysis...")
for name, df in datasets.items():
    logger.info(f"{name} Data Checking:")
    DataValidator.checkDuplicate(df=df, logger=logger)
logger.info("-" * 80)
logger.info("Duplicate value inspection successfully completed across datasets.")
# Out:
# 2026-09-03 18:21:34 | INFO     | Start checking duplicate values
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | INFO     | Data duplicate Analysis...
# 2026-09-03 18:21:34 | INFO     | Train Data Checking:
# 2026-09-03 18:21:34 | INFO     | No duplicate rows found out of 668,665 total rows.
# 2026-09-03 18:21:34 | INFO     | Test Data Checking:
# 2026-09-03 18:21:34 | INFO     | No duplicate rows found out of 286,571 total rows.
# 2026-09-03 18:21:34 | INFO     | Original Data Checking:
# 2026-09-03 18:21:34 | INFO     | No duplicate rows found out of 10,000 total rows.
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | INFO     | Duplicate value inspection successfully completed across datasets.

# %% [markdown]
# ## Checking Outlier Value

# %%
logger.info("-" * 80)
outlier_data = []
for name, df in datasets.items():
    logger.info(f"{name} Data Checking:")
    outlier_data.append(DataValidator.checkOutlier(df=df, dataset_name=CFG.DATASET_NAME, 
                                              list_feature=num_features, logger=logger))
if outlier_data:
    for outlier in outlier_data:
        logger.warning("\n" + outlier.to_string())

logger.info("-" * 80)
logger.info("Outlier checking successfully completed across datasets.")
# Out:
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | INFO     | Train Data Checking:
# 2026-09-03 18:21:34 | INFO     | Checking outliers for EV Adoption Prediction Dataset...
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Age: No outliers detected
# 2026-09-03 18:21:34 | WARNING  | [EV Adoption Prediction Dataset] Annual_Income_USD: 3,678 outliers detected (lower=14310.500, upper=155818.500)
# 2026-09-03 18:21:34 | WARNING  | [EV Adoption Prediction Dataset] Daily_Commute_km: 41 outliers detected (lower=-28.100, upper=92.700)
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Charging_Stations_Near_Home: No outliers detected
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Charging_Stations_Near_Work: No outliers detected
# 2026-09-03 18:21:34 | INFO     | Test Data Checking:
# 2026-09-03 18:21:34 | INFO     | Checking outliers for EV Adoption Prediction Dataset...
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Age: No outliers detected
# 2026-09-03 18:21:34 | WARNING  | [EV Adoption Prediction Dataset] Annual_Income_USD: 1,538 outliers detected (lower=14323.500, upper=155807.500)
# 2026-09-03 18:21:34 | WARNING  | [EV Adoption Prediction Dataset] Daily_Commute_km: 16 outliers detected (lower=-27.950, upper=92.450)
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Charging_Stations_Near_Home: No outliers detected
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Charging_Stations_Near_Work: No outliers detected
# 2026-09-03 18:21:34 | INFO     | Original Data Checking:
# 2026-09-03 18:21:34 | INFO     | Checking outliers for EV Adoption Prediction Dataset...
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Age: No outliers detected
# 2026-09-03 18:21:34 | WARNING  | [EV Adoption Prediction Dataset] Annual_Income_USD: 55 outliers detected (lower=-7651.125, upper=176403.875)
# 2026-09-03 18:21:34 | WARNING  | [EV Adoption Prediction Dataset] Daily_Commute_km: 39 outliers detected (lower=-27.375, upper=107.625)
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Charging_Stations_Near_Home: No outliers detected
# 2026-09-03 18:21:34 | DEBUG    | [EV Adoption Prediction Dataset] Charging_Stations_Near_Work: No outliers detected
# 2026-09-03 18:21:34 | WARNING  |
#              Feature  Outlier_Count
# 0  Annual_Income_USD           3678
# 1   Daily_Commute_km             41
# 2026-09-03 18:21:34 | WARNING  |
#              Feature  Outlier_Count
# 0  Annual_Income_USD           1538
# 1   Daily_Commute_km             16
# 2026-09-03 18:21:34 | WARNING  |
#              Feature  Outlier_Count
# 0  Annual_Income_USD             55
# 1   Daily_Commute_km             39
# 2026-09-03 18:21:34 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:21:34 | INFO     | Outlier checking successfully completed across datasets.

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Exploratory Data Analysis</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#         background: linear-gradient(
#     135deg,
#     #003B5C,
#     #0077B6 35%,
#     #00B4D8 65%,
#     #2A9D8F 100%
# );
#     text-align: center;
#     box-shadow: 0px 6px 15px rgba(6, 78, 59, 0.35);
# ">
#     <h1 style="
#         color: #fff;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 10px;
#         font-size: 36px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Exploratory Data Analysis
#     </h1>
# </div>

# %% [markdown]
# ## Class Distribution

# %%
# Target Distribution Comparison
order = ["No", "Yes"]
colors = ["#16A34A", "#DC2626"]
datasets = {"Train Dataset": df_train, "Original Dataset": df_original}

fig, axes = plt.subplots(1, 2, figsize=(16, 7), facecolor="#181818")
distribution_summary = {}
for ax, (dataset_name, df) in zip(axes, datasets.items()):
    # Copy dataframe
    df_plot = df.copy()

    # Target distribution
    target_distribution = (
        df_plot[CFG.TARGET_FEATURE]
        .value_counts()
        .reindex(order, fill_value=0)
    )

    total = len(df_plot)

    distribution_summary[dataset_name] = {
        "No": target_distribution["No"] / total * 100,
        "Yes": target_distribution["Yes"] / total * 100
    }

    # Count Plot
    sns.countplot(
        data=df_plot,
        x=CFG.TARGET_FEATURE,
        order=order,
        hue=CFG.TARGET_FEATURE,
        palette=colors,
        legend=False,
        ax=ax
    )

    ax.set_title(
        dataset_name,
        fontsize=12,
        fontweight="bold",
        pad=15
    )

    ax.set_xlabel("")
    ax.set_ylabel(
        "Number of Consumers",
        fontsize=11
    )

    sns.despine(ax=ax)

    # Count + Percentage Labels
    for container in ax.containers:
        labels = [
            f"{int(bar.get_height()):,}\n"
            f"({bar.get_height() / total:.1%})"
            for bar in container
        ]
        ax.bar_label(container, labels=labels, fontsize=10, fontweight="bold", padding=3)

# Disable grid
for ax in axes:
    ax.grid(False)

# Overall Title
plt.suptitle(
    "Target Distribution Comparison",
    fontsize=18,
    fontweight="bold"
)

# Overall Insight
train_no = distribution_summary["Train Dataset"]["No"]
train_yes = distribution_summary["Train Dataset"]["Yes"]

original_no = distribution_summary["Original Dataset"]["No"]
original_yes = distribution_summary["Original Dataset"]["Yes"]

insight = (
    "Key Insights:\n"
    f"• Train Dataset: {train_yes:.1f}% Yes | {train_no:.1f}% No\n"
    f"• Original Dataset: {original_yes:.1f}% Yes | {original_no:.1f}% No\n"
    "• The target distributions can be compared to assess whether "
    "the competition data preserves the original purchase behavior.\n"
    "• Any substantial difference in the proportion of consumers "
    "willing to buy an EV may indicate a potential target distribution shift."
)

fig.text(
    0.5,
    0.01,
    insight,
    ha="center",
    va="bottom",
    multialignment="left",
    fontsize=10,
    bbox=dict(
        boxstyle="round,pad=0.8",
        facecolor="#181818",
        edgecolor="#16A34A",
        alpha=0.95
    )
)

# Leave space for insight box
plt.tight_layout(
    rect=[0, 0.14, 1, 0.93]
)
plt.show()

# %% [markdown]
# ## Numerical Feature Distributions

# %%
plot_numerical_features_v3(df_train=df_train, df_test=df_test, df_original=df_original, num_features=num_features)

# %% [markdown]
# ### Analyze skewness

# %%
logger.info("-" * 80)
skew_feature = []
for name, df in datasets.items():
    logger.info(f"{name} Data Checking Skewness:")
    skew_feature.append(DataValidator.check_skewness(data=df, dataset_name= CFG.DATASET_NAME, 
                                                     numerical_features=num_features, logger=logger))
logger.info("-" * 80)
logger.info("Checking skewness successfully completed the dataset.")
# Out:
# 2026-09-03 18:22:21 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:22:21 | INFO     | Train Dataset Data Checking Skewness:
# 2026-09-03 18:22:21 | INFO     | Skewness analysis for EV Adoption Prediction Dataset
# 2026-09-03 18:22:21 | INFO     | Total numerical features checked: 5
# 2026-09-03 18:22:21 | DEBUG    | ----------------------------------------------------------------------
# 2026-09-03 18:22:21 | DEBUG    | Feature                        | Skewness  | Remark
# 2026-09-03 18:22:21 | DEBUG    | ----------------------------------------------------------------------
# 2026-09-03 18:22:21 | DEBUG    | Charging_Stations_Near_Work    |   +0.7002 | Moderately skewed
# 2026-09-03 18:22:21 | DEBUG    | Charging_Stations_Near_Home    |   +0.6987 | Moderately skewed
# 2026-09-03 18:22:21 | DEBUG    | Daily_Commute_km               |   -0.0846 | Approximately symmetric
# 2026-09-03 18:22:21 | DEBUG    | Annual_Income_USD              |   -0.0131 | Approximately symmetric
# 2026-09-03 18:22:21 | DEBUG    | Age                            |   -0.0038 | Approximately symmetric
# 2026-09-03 18:22:21 | DEBUG    | ----------------------------------------------------------------------
# 2026-09-03 18:22:21 | INFO     | 2 features are skewed (|skew| > 0.5).
# 2026-09-03 18:22:21 | INFO     | Recommendation: Consider log / Box-Cox / Yeo-Johnson transformation.
# 2026-09-03 18:22:21 | INFO     | Original Dataset Data Checking Skewness:
# 2026-09-03 18:22:21 | INFO     | Skewness analysis for EV Adoption Prediction Dataset
# 2026-09-03 18:22:21 | INFO     | Total numerical features checked: 5
# 2026-09-03 18:22:21 | DEBUG    | ----------------------------------------------------------------------
# 2026-09-03 18:22:21 | DEBUG    | Feature                        | Skewness  | Remark
# 2026-09-03 18:22:21 | DEBUG    | ----------------------------------------------------------------------
# 2026-09-03 18:22:21 | DEBUG    | Charging_Stations_Near_Work    |   +0.6080 | Moderately skewed
# 2026-09-03 18:22:21 | DEBUG    | Charging_Stations_Near_Home    |   +0.5712 | Moderately skewed
# 2026-09-03 18:22:21 | DEBUG    | Daily_Commute_km               |   +0.3361 | Approximately symmetric
# 2026-09-03 18:22:21 | DEBUG    | Annual_Income_USD              |   +0.3052 | Approximately symmetric
# 2026-09-03 18:22:21 | DEBUG    | Age                            |   +0.0090 | Approximately symmetric
# 2026-09-03 18:22:21 | DEBUG    | ----------------------------------------------------------------------
# 2026-09-03 18:22:21 | INFO     | 2 features are skewed (|skew| > 0.5).
# 2026-09-03 18:22:21 | INFO     | Recommendation: Consider log / Box-Cox / Yeo-Johnson transformation.
# 2026-09-03 18:22:21 | INFO     | --------------------------------------------------------------------------------
# 2026-09-03 18:22:21 | INFO     | Checking skewness successfully completed the dataset.

# %% [markdown]
# <div style="
#      background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#90E0EF;
#     margin:0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 📊 Distribution & Skewness Insights
# </div>
#
# <ul style="line-height:1.8; padding-left:20px;">
#
# <li>The <b>training and test datasets</b> exhibit highly consistent numerical distributions across most features, with nearly identical medians, quartiles, and value ranges. This suggests <b>no meaningful distribution shift</b> between the competition training and test sets.</li>
#
# <li><code>Age</code> is approximately symmetric in the training dataset (<code>skew ≈ -0.004</code>), with a median of <b>47 years</b>. The distributions across Train, Test, and Original datasets are highly similar.</li>
#
# <li><code>Annual_Income_USD</code> is also approximately symmetric in the training dataset (<code>skew ≈ -0.013</code>). The Train and Test datasets show very similar income distributions, while the Original dataset exhibits a slightly more right-skewed distribution (<code>skew ≈ 0.305</code>) with a broader upper range.</li>
#
# <li><code>Daily_Commute_km</code> is approximately symmetric in the training dataset (<code>skew ≈ -0.085</code>). However, the Original dataset has a higher median of approximately <b>40.2 km</b>, compared with approximately <b>33.6 km</b> in Train and Test, indicating a noticeable distribution difference in commuting distance.</li>
#
# <li><code>Charging_Stations_Near_Home</code> and <code>Charging_Stations_Near_Work</code> are <b>moderately right-skewed</b> in the training dataset, with skewness values of approximately <code>0.70</code> and <code>0.70</code>, respectively. This indicates that most consumers have relatively moderate charging availability, while a smaller group has access to substantially more charging stations.</li>
#
# <li>The same charging-related variables remain moderately right-skewed in the Original dataset, with skewness of approximately <code>0.57</code> for <code>Charging_Stations_Near_Home</code> and <code>0.61</code> for <code>Charging_Stations_Near_Work</code>. The overall distribution patterns remain comparable despite differences in skewness magnitude.</li>
#
# <li><b>No highly skewed numerical features</b> were identified, as all observed skewness values remain below <code>|1|</code>. Therefore, there is no strong statistical requirement for logarithmic or Box-Cox transformation based solely on skewness.</li>
#
# <li>For the charging-related count variables, the observed skewness is <b>structurally reasonable</b> because the number of available charging stations is a discrete count variable bounded within a relatively small range.</li>
#
# <li><b>Overall</b>: The numerical features show generally stable and well-behaved distributions in the competition datasets. The main distribution difference compared with the Original dataset is observed in <code>Daily_Commute_km</code>, while the charging infrastructure variables exhibit moderate positive skewness that should be considered during modeling.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# ### Correlation Analysis of Numerical Features

# %%
mapping = {"No": 0, "Yes": 1}
df_train[CFG.TARGET_FEATURE] = df_train[CFG.TARGET_FEATURE].map(mapping)
df_original[CFG.TARGET_FEATURE] = df_original[CFG.TARGET_FEATURE].map(mapping)

StatUtils.plot_correlation_with_pvalue(df_train=df_train, df_test=df_test, df_origin=df_original)

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#fde68a;
#     margin:0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 📊 Correlation Analysis Insights
# </div>
#
# <ul style="line-height:1.8; padding-left:20px;">
#
# <li>The <b>training, test, and original datasets</b> exhibit highly consistent correlation patterns, with similar correlation directions and magnitudes across the numerical features. This suggests <b>no meaningful structural shift</b> between the competition datasets and the original data.</li>
#
# <li><code>Charging_Stations_Near_Home</code> and <code>Charging_Stations_Near_Work</code> show the strongest feature-to-feature relationship, with a moderate positive correlation of approximately <b>r ≈ 0.48–0.52</b> across the three datasets. This indicates that consumers living in areas with better charging infrastructure near home also tend to have greater charging availability near their workplace.</li>
#
# <li><code>Will_Buy_EV</code> has the strongest relationship with <code>Annual_Income_USD</code>, with a positive correlation of approximately <b>r ≈ 0.18–0.23</b>. This suggests that higher-income consumers tend to show a greater likelihood of purchasing an electric vehicle.</li>
#
# <li><code>Daily_Commute_km</code> has a <b>weak negative correlation</b> with <code>Will_Buy_EV</code> (<b>r ≈ -0.03 to -0.05</b>). Although statistically significant in the larger datasets, the small correlation magnitude indicates that commuting distance alone has <b>limited linear association</b> with EV purchase intention.</li>
#
# <li>The remaining numerical features, including <code>Age</code>, <code>Charging_Stations_Near_Home</code>, and <code>Charging_Stations_Near_Work</code>, show <b>very weak correlations</b> with <code>Will_Buy_EV</code> (approximately <code>|r| &lt; 0.03</code>). These variables may still provide predictive value through nonlinear relationships or interactions with other features.</li>
#
# <li>Most feature pairs have correlations close to <b>zero</b>, indicating generally <b>low multicollinearity</b>. The main exception is the relationship between the two charging infrastructure variables, which should be considered when interpreting feature importance or coefficients.</li>
#
# <li>The <b>large training and test sample sizes</b> make even relatively weak correlations statistically significant (<code>p &lt; 0.05</code>). Therefore, statistical significance should not be confused with practical importance; the <b>correlation magnitude</b> remains important when evaluating predictive relevance.</li>
#
# <li>Compared with the competition datasets, the <b>original dataset shows fewer statistically significant weak relationships</b>, which is expected given its substantially smaller sample size. However, the major correlation patterns remain consistent.</li>
#
# <li><b>Overall</b>: <code>Annual_Income_USD</code> appears to be the strongest numerical indicator associated with EV purchase intention, while charging infrastructure variables show moderate correlation with each other. Overall multicollinearity is limited, providing a relatively clean numerical feature set for subsequent modeling.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# ## Categorical Feature Distributions

# %%
# ----- Run for all categorical features -----
for feature in cat_features:
    categorical_distribution_across_datasets(df_train=df_train, df_test=df_test, df_original=df_original, 
                                             feature=feature, logger=logger)
# Out:
# 2026-09-03 18:22:26 | INFO     | Analyzing categorical feature: Gender
# 2026-09-03 18:22:27 | DEBUG    | Gender: 3 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: Gender:
#   Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 1     Male       367954    55.03      157647   55.01            5201       52.01
# 0   Female       295427    44.18      126669   44.20            4498       44.98
# 2    Other         5284     0.79        2255    0.79             301        3.01
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: Gender
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************
# 2026-09-03 18:22:27 | INFO     | Analyzing categorical feature: City_Type
# 2026-09-03 18:22:27 | DEBUG    | City_Type: 3 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: City_Type:
#    Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 2     Urban       289305    43.27      123602   43.13            4941       49.41
# 1  Suburban       255377    38.19      109676   38.27            3563       35.63
# 0     Rural       123983    18.54       53293   18.60            1496       14.96
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: City_Type
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************
# 2026-09-03 18:22:27 | INFO     | Analyzing categorical feature: Current_Car_Type
# 2026-09-03 18:22:27 | DEBUG    | Current_Car_Type: 4 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: Current_Car_Type:
#     Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 2      Sedan       303459    45.38      130185   45.43            4000       40.00
# 1        SUV       246545    36.87      105687   36.88            3486       34.86
# 0  Hatchback        79438    11.88       34104   11.90            1523       15.23
# 3      Truck        39223     5.87       16595    5.79             991        9.91
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: Current_Car_Type
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************
# 2026-09-03 18:22:27 | INFO     | Analyzing categorical feature: Home_Charging_Possible
# 2026-09-03 18:22:27 | DEBUG    | Home_Charging_Possible: 2 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: Home_Charging_Possible:
#   Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 1      Yes       462677    69.19      198480   69.26            6163       61.63
# 0       No       205988    30.81       88091   30.74            3837       38.37
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: Home_Charging_Possible
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************
# 2026-09-03 18:22:27 | INFO     | Analyzing categorical feature: Subsidy_Available
# 2026-09-03 18:22:27 | DEBUG    | Subsidy_Available: 2 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: Subsidy_Available:
#   Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 1      Yes       419909     62.8      180378   62.94            6008       60.08
# 0       No       248756     37.2      106193   37.06            3992       39.92
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: Subsidy_Available
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************
# 2026-09-03 18:22:27 | INFO     | Analyzing categorical feature: Environmental_Concern_Level
# 2026-09-03 18:22:27 | DEBUG    | Environmental_Concern_Level: 5 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: Environmental_Concern_Level:
#   Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 0      1.0       147476    22.06       63125   22.03            2013       20.51
# 1      2.0       135133    20.21       58019   20.25            1948       19.85
# 3      4.0       130469    19.51       56326   19.66            1989       20.26
# 4      5.0       128236    19.18       54594   19.05            1908       19.44
# 2      3.0       127351    19.05       54507   19.02            1958       19.95
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: Environmental_Concern_Level
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************
# 2026-09-03 18:22:27 | INFO     | Analyzing categorical feature: Range_Anxiety_Level
# 2026-09-03 18:22:27 | DEBUG    | Range_Anxiety_Level: 3 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: Range_Anxiety_Level:
#   Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 1      Low       603972    90.33      259247   90.47            8310       83.10
# 2   Medium        62499     9.35       26295    9.18            1523       15.23
# 0     High         2194     0.33        1029    0.36             167        1.67
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: Range_Anxiety_Level
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************
# 2026-09-03 18:22:27 | INFO     | Analyzing categorical feature: Number_of_Cars_Owned
# 2026-09-03 18:22:27 | DEBUG    | Number_of_Cars_Owned: 4 categories detected
# 2026-09-03 18:22:27 | INFO     | Categorical Feature Distribution: Number_of_Cars_Owned:
#   Category  Train_Count  Train_%  Test_Count  Test_%  Original_Count  Original_%
# 1        2       298287    44.61      127869   44.62            4020       40.20
# 0        1       288012    43.07      122958   42.91            3946       39.46
# 2        3        68877    10.30       29889   10.43            1523       15.23
# 3        4        13489     2.02        5855    2.04             511        5.11
# 2026-09-03 18:22:27 | INFO     | Completed analysis for: Number_of_Cars_Owned
# 2026-09-03 18:22:27 | INFO     | ********************************************************************************

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#fde68a;
#     margin:0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 📊 Categorical Feature Insights
# </div>
#
# <ul style="line-height:1.8; padding-left:20px;">
#
# <li><code>Gender</code> is moderately dominated by <code>Male</code> consumers in the competition datasets, representing approximately <b>55%</b> of Train and Test observations, while <code>Female</code> accounts for approximately <b>44%</b>. The <code>Other</code> category is relatively rare at only <b>0.79%</b>. The Original dataset shows a similar Male/Female distribution, but a noticeably higher proportion of <code>Other</code> consumers (<b>3.01%</b>).</li>
#
# <li><code>City_Type</code> is dominated by <code>Urban</code> consumers, accounting for approximately <b>43%</b> of both Train and Test datasets, followed by <code>Suburban</code> at approximately <b>38%</b>. <code>Rural</code> consumers represent around <b>19%</b>. Compared with the competition datasets, the Original dataset contains a higher proportion of <code>Urban</code> consumers (<b>49.41%</b>) and a lower proportion of <code>Rural</code> consumers (<b>14.96%</b>).</li>
#
# <li><code>Current_Car_Type</code> is dominated by <code>Sedan</code> and <code>SUV</code> owners, which together account for more than <b>82%</b> of Train and Test observations. The Original dataset has a somewhat higher proportion of <code>Truck</code> and <code>Hatchback</code> owners, indicating a moderate difference in the current vehicle composition.</li>
#
# <li><code>Home_Charging_Possible</code> is predominantly <code>Yes</code> in the competition datasets, representing approximately <b>69%</b> of both Train and Test consumers. However, this proportion decreases to <b>61.63%</b> in the Original dataset, suggesting a noticeable difference in home-charging availability between the original and competition data.</li>
#
# <li><code>Subsidy_Available</code> is also dominated by <code>Yes</code>, accounting for approximately <b>63%</b> of Train and Test observations. The Original dataset shows a very similar distribution at approximately <b>60%</b>, indicating only a relatively small shift in subsidy availability.</li>
#
# <li><code>Environmental_Concern_Level</code> has a <b>well-balanced distribution across all five levels</b>. In the Train and Test datasets, each category represents approximately <b>19–22%</b> of observations, suggesting that no particular environmental concern level dominates the competition data.</li>
#
# <li><code>Range_Anxiety_Level</code> is highly concentrated in the <code>Low</code> category, representing approximately <b>90%</b> of Train and Test observations. The Original dataset has a lower proportion of <code>Low</code> range anxiety (<b>83.10%</b>) and higher proportions of <code>Medium</code> and <code>High</code>, indicating a noticeable distribution shift.</li>
#
# <li><code>Number_of_Cars_Owned</code> is concentrated around <b>1–2 cars per consumer</b>, with these two categories accounting for approximately <b>88%</b> of Train and Test observations. The Original dataset contains relatively more consumers owning <b>3–4 cars</b>, indicating a moderate difference in vehicle ownership patterns.</li>
#
# <li>The <b>training and test datasets exhibit highly consistent categorical distributions</b> across all features, with almost identical category proportions. This is a positive sign for competition modeling because the test set appears to closely represent the training population.</li>
#
# <li>However, several categorical features show noticeable differences between the <b>competition datasets and the Original dataset</b>, particularly <code>Gender</code>, <code>Home_Charging_Possible</code>, <code>Range_Anxiety_Level</code>, and <code>Number_of_Cars_Owned</code>. These differences should be considered when interpreting how well the competition data represents the original population.</li>
#
# <li><b>Overall</b>: The competition datasets provide stable categorical distributions between Train and Test, while the Original dataset reveals several population-level differences. Features related to <b>home charging, range anxiety, vehicle ownership, and urbanization</b> may therefore capture important differences in EV adoption behavior.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# ## Multivariate Statistical Analysis

# %%
mapping = {0: "No", 1: "Yes"}
df_plot = df_train.copy()
df_plot[CFG.TARGET_FEATURE] = df_plot[CFG.TARGET_FEATURE].map(mapping)

for feature in num_features:
    display(HTML(
        f"<h2 style='text-align:center; font-size:22px; color:#fde68a;'>"
        f"<b>Distribution of {feature} by EV Purchase Decision</b>"
        f"</h2>"
    ))
    StatUtils.analyze_numeric_feature_by_target(feature=feature, df = df_plot, logger=logger, target_feature=CFG.TARGET_FEATURE)
# Out:
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Age by EV Purchase Decision</b></h2>
# <ul><li><b>Overall Mean:</b> 47.04</li><li><b>Overall Median:</b> 47.0</li><li><b>Overall Std:</b> 12.88</li></ul>
# <style type="text/css">
# #T_0fea2_row0_col1, #T_0fea2_row0_col2, #T_0fea2_row0_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_0fea2_row0_col3, #T_0fea2_row1_col1, #T_0fea2_row1_col2, #T_0fea2_row1_col3, #T_0fea2_row1_col4 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_0fea2" style="width:75%; margin:auto;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fea2_level0_col0" class="col_heading level0 col0" >Will_Buy_EV</th>
#       <th id="T_0fea2_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_0fea2_level0_col2" class="col_heading level0 col2" >Mean</th>
#       <th id="T_0fea2_level0_col3" class="col_heading level0 col3" >Median</th>
#       <th id="T_0fea2_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fea2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0fea2_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_0fea2_row0_col1" class="data row0 col1" >551886</td>
#       <td id="T_0fea2_row0_col2" class="data row0 col2" >47.083293</td>
#       <td id="T_0fea2_row0_col3" class="data row0 col3" >47.000000</td>
#       <td id="T_0fea2_row0_col4" class="data row0 col4" >12.896488</td>
#     </tr>
#     <tr>
#       <th id="T_0fea2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0fea2_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_0fea2_row1_col1" class="data row1 col1" >116779</td>
#       <td id="T_0fea2_row1_col2" class="data row1 col2" >46.830654</td>
#       <td id="T_0fea2_row1_col3" class="data row1 col3" >47.000000</td>
#       <td id="T_0fea2_row1_col4" class="data row1 col4" >12.773543</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:27 | INFO     | Checking normality of feature 'Age' by groups of 'Will_Buy_EV'...
# 2026-09-03 18:22:27 | INFO     | Evaluating distribution characteristics (skewness & kurtosis)...
# 2026-09-03 18:22:27 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:27 | DEBUG    | Thresholds → |skew|≤0.5, |kurtosis|≤1.5
# 2026-09-03 18:22:27 | DEBUG    | [Will_Buy_EV=No] skew=-0.0022, kurtosis=-1.1814 → Approximately symmetric, Normal tails
# 2026-09-03 18:22:27 | DEBUG    | [Will_Buy_EV=Yes] skew=-0.0126, kurtosis=-1.1396 → Approximately symmetric, Normal tails
# 2026-09-03 18:22:27 | INFO     | Generating Q–Q plots for visual assessment...
# <style type="text/css">
# #T_88caa_row0_col2 {
#   background-color: #7979f9;
#   color: #f1f1f1;
# }
# #T_88caa_row0_col3 {
#   background-color: #d7d7f4;
#   color: #000000;
# }
# #T_88caa_row1_col2 {
#   background-color: #7a7af9;
#   color: #f1f1f1;
# }
# #T_88caa_row1_col3 {
#   background-color: #d4d4f4;
#   color: #000000;
# }
# </style>
# <table id="T_88caa" style="width:80%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Skewness & Kurtosis of Age by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88caa_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_88caa_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_88caa_level0_col2" class="col_heading level0 col2" >Skewness</th>
#       <th id="T_88caa_level0_col3" class="col_heading level0 col3" >Kurtosis</th>
#       <th id="T_88caa_level0_col4" class="col_heading level0 col4" >Remark</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88caa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88caa_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_88caa_row0_col1" class="data row0 col1" >No</td>
#       <td id="T_88caa_row0_col2" class="data row0 col2" >-0.0022</td>
#       <td id="T_88caa_row0_col3" class="data row0 col3" >-1.1814</td>
#       <td id="T_88caa_row0_col4" class="data row0 col4" >Approximately symmetric, Normal tails</td>
#     </tr>
#     <tr>
#       <th id="T_88caa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88caa_row1_col0" class="data row1 col0" >Age</td>
#       <td id="T_88caa_row1_col1" class="data row1 col1" >Yes</td>
#       <td id="T_88caa_row1_col2" class="data row1 col2" >-0.0126</td>
#       <td id="T_88caa_row1_col3" class="data row1 col3" >-1.1396</td>
#       <td id="T_88caa_row1_col4" class="data row1 col4" >Approximately symmetric, Normal tails</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:29 | INFO     | All groups approximately follow a normal distribution.
# 2026-09-03 18:22:29 | INFO     | Check homogeneity of variances across groups using Levene’s test (median-centered)
# 2026-09-03 18:22:29 | DEBUG    | Number of groups detected: 2
# <style type="text/css">
# #T_4322c_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4322c_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4322c_row2_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_4322c" style="width:70%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Homogeneity of Variance — Age by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4322c_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_4322c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4322c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4322c_row0_col0" class="data row0 col0" >Levene’s Statistic</td>
#       <td id="T_4322c_row0_col1" class="data row0 col1" >53.7311</td>
#     </tr>
#     <tr>
#       <th id="T_4322c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4322c_row1_col0" class="data row1 col0" >p-value</td>
#       <td id="T_4322c_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4322c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4322c_row2_col0" class="data row2 col0" >Max/Min Variance Ratio</td>
#       <td id="T_4322c_row2_col1" class="data row2 col1" >1.02</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:29 | INFO     | Interpretation:
# 2026-09-03 18:22:29 | INFO     | - Status: Statistically different variances, but practical difference is small.
# 2026-09-03 18:22:29 | INFO     | - Recommendation: ANOVA or T-Test are acceptable, but Welch’s ANOVA or Welch’s T-Test is recommended.
# 2026-09-03 18:22:30 | INFO     | Running Independent Two-Sample T-Test: 'Age' ~ 'Will_Buy_EV'
# 2026-09-03 18:22:30 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:30 | DEBUG    | Test Type: Welch’s T-Test (unequal variances)
# 2026-09-03 18:22:30 | INFO     | Comparing groups: 'No' vs 'Yes'
# 2026-09-03 18:22:30 | INFO     | p-value: 0.000000
# 2026-09-03 18:22:30 | INFO     | Cohen's d: 0.020
# 2026-09-03 18:22:30 | DEBUG    | t-statistic: 6.130
# 2026-09-03 18:22:30 | DEBUG    | Group means → No: 47.083, Yes: 46.831
# 2026-09-03 18:22:30 | INFO     | Result: p-value ≤ 0.05 → Reject H0
# 2026-09-03 18:22:30 | INFO     | Conclusion: Significant difference between the two groups.
# 2026-09-03 18:22:30 | INFO     | Effect size interpretation: small effect (|d| = 0.020)
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Annual_Income_USD by EV Purchase Decision</b></h2>
# <ul><li><b>Overall Mean:</b> 84769.29</li><li><b>Overall Median:</b> 84880.0</li><li><b>Overall Std:</b> 28648.03</li></ul>
# <style type="text/css">
# #T_b3f01_row0_col1, #T_b3f01_row0_col4, #T_b3f01_row1_col2, #T_b3f01_row1_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_b3f01_row0_col2, #T_b3f01_row0_col3, #T_b3f01_row1_col1, #T_b3f01_row1_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b3f01" style="width:75%; margin:auto;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3f01_level0_col0" class="col_heading level0 col0" >Will_Buy_EV</th>
#       <th id="T_b3f01_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_b3f01_level0_col2" class="col_heading level0 col2" >Mean</th>
#       <th id="T_b3f01_level0_col3" class="col_heading level0 col3" >Median</th>
#       <th id="T_b3f01_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3f01_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b3f01_row0_col0" class="data row0 col0" >Yes</td>
#       <td id="T_b3f01_row0_col1" class="data row0 col1" >116779</td>
#       <td id="T_b3f01_row0_col2" class="data row0 col2" >98827.304688</td>
#       <td id="T_b3f01_row0_col3" class="data row0 col3" >96167.000000</td>
#       <td id="T_b3f01_row0_col4" class="data row0 col4" >26300.675910</td>
#     </tr>
#     <tr>
#       <th id="T_b3f01_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b3f01_row1_col0" class="data row1 col0" >No</td>
#       <td id="T_b3f01_row1_col1" class="data row1 col1" >551886</td>
#       <td id="T_b3f01_row1_col2" class="data row1 col2" >81794.585938</td>
#       <td id="T_b3f01_row1_col3" class="data row1 col3" >82844.000000</td>
#       <td id="T_b3f01_row1_col4" class="data row1 col4" >28237.155138</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:34 | INFO     | Checking normality of feature 'Annual_Income_USD' by groups of 'Will_Buy_EV'...
# 2026-09-03 18:22:34 | INFO     | Evaluating distribution characteristics (skewness & kurtosis)...
# 2026-09-03 18:22:34 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:34 | DEBUG    | Thresholds → |skew|≤0.5, |kurtosis|≤1.5
# 2026-09-03 18:22:34 | DEBUG    | [Will_Buy_EV=No] skew=0.0042, kurtosis=-0.1797 → Approximately symmetric, Normal tails
# 2026-09-03 18:22:34 | DEBUG    | [Will_Buy_EV=Yes] skew=-0.0226, kurtosis=0.1137 → Approximately symmetric, Normal tails
# 2026-09-03 18:22:34 | INFO     | Generating Q–Q plots for visual assessment...
# <style type="text/css">
# #T_8ca95_row0_col2 {
#   background-color: #7878f9;
#   color: #f1f1f1;
# }
# #T_8ca95_row0_col3 {
#   background-color: #8787f8;
#   color: #f1f1f1;
# }
# #T_8ca95_row1_col2 {
#   background-color: #7b7bf9;
#   color: #f1f1f1;
# }
# #T_8ca95_row1_col3 {
#   background-color: #6f6ff9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ca95" style="width:80%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Skewness & Kurtosis of Annual_Income_USD by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ca95_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_8ca95_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_8ca95_level0_col2" class="col_heading level0 col2" >Skewness</th>
#       <th id="T_8ca95_level0_col3" class="col_heading level0 col3" >Kurtosis</th>
#       <th id="T_8ca95_level0_col4" class="col_heading level0 col4" >Remark</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ca95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ca95_row0_col0" class="data row0 col0" >Annual_Income_USD</td>
#       <td id="T_8ca95_row0_col1" class="data row0 col1" >No</td>
#       <td id="T_8ca95_row0_col2" class="data row0 col2" >0.0042</td>
#       <td id="T_8ca95_row0_col3" class="data row0 col3" >-0.1797</td>
#       <td id="T_8ca95_row0_col4" class="data row0 col4" >Approximately symmetric, Normal tails</td>
#     </tr>
#     <tr>
#       <th id="T_8ca95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ca95_row1_col0" class="data row1 col0" >Annual_Income_USD</td>
#       <td id="T_8ca95_row1_col1" class="data row1 col1" >Yes</td>
#       <td id="T_8ca95_row1_col2" class="data row1 col2" >-0.0226</td>
#       <td id="T_8ca95_row1_col3" class="data row1 col3" >0.1137</td>
#       <td id="T_8ca95_row1_col4" class="data row1 col4" >Approximately symmetric, Normal tails</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:36 | INFO     | All groups approximately follow a normal distribution.
# 2026-09-03 18:22:36 | INFO     | Check homogeneity of variances across groups using Levene’s test (median-centered)
# 2026-09-03 18:22:36 | DEBUG    | Number of groups detected: 2
# <style type="text/css">
# #T_07539_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_07539_row1_col1, #T_07539_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_07539" style="width:70%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Homogeneity of Variance — Annual_Income_USD by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07539_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_07539_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07539_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07539_row0_col0" class="data row0 col0" >Levene’s Statistic</td>
#       <td id="T_07539_row0_col1" class="data row0 col1" >506.1259</td>
#     </tr>
#     <tr>
#       <th id="T_07539_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07539_row1_col0" class="data row1 col0" >p-value</td>
#       <td id="T_07539_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_07539_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07539_row2_col0" class="data row2 col0" >Max/Min Variance Ratio</td>
#       <td id="T_07539_row2_col1" class="data row2 col1" >1.15</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:36 | INFO     | Interpretation:
# 2026-09-03 18:22:36 | INFO     | - Status: Statistically different variances, but practical difference is small.
# 2026-09-03 18:22:36 | INFO     | - Recommendation: ANOVA or T-Test are acceptable, but Welch’s ANOVA or Welch’s T-Test is recommended.
# 2026-09-03 18:22:36 | INFO     | Running Independent Two-Sample T-Test: 'Annual_Income_USD' ~ 'Will_Buy_EV'
# 2026-09-03 18:22:36 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:36 | DEBUG    | Test Type: Welch’s T-Test (unequal variances)
# 2026-09-03 18:22:36 | INFO     | Comparing groups: 'No' vs 'Yes'
# 2026-09-03 18:22:36 | INFO     | p-value: 0.000000
# 2026-09-03 18:22:36 | INFO     | Cohen's d: -0.624
# 2026-09-03 18:22:36 | DEBUG    | t-statistic: -198.429
# 2026-09-03 18:22:36 | DEBUG    | Group means → No: 81794.570, Yes: 98827.305
# 2026-09-03 18:22:36 | INFO     | Result: p-value ≤ 0.05 → Reject H0
# 2026-09-03 18:22:36 | INFO     | Conclusion: Significant difference between the two groups.
# 2026-09-03 18:22:36 | INFO     | Effect size interpretation: large effect (|d| = 0.624)
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Daily_Commute_km by EV Purchase Decision</b></h2>
# <ul><li><b>Overall Mean:</b> 32.16</li><li><b>Overall Median:</b> 33.599998474121094</li><li><b>Overall Std:</b> 18.73</li></ul>
# <style type="text/css">
# #T_282cd_row0_col1, #T_282cd_row0_col2, #T_282cd_row0_col3, #T_282cd_row0_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_282cd_row1_col1, #T_282cd_row1_col2, #T_282cd_row1_col3, #T_282cd_row1_col4 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_282cd" style="width:75%; margin:auto;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_282cd_level0_col0" class="col_heading level0 col0" >Will_Buy_EV</th>
#       <th id="T_282cd_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_282cd_level0_col2" class="col_heading level0 col2" >Mean</th>
#       <th id="T_282cd_level0_col3" class="col_heading level0 col3" >Median</th>
#       <th id="T_282cd_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_282cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_282cd_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_282cd_row0_col1" class="data row0 col1" >551886</td>
#       <td id="T_282cd_row0_col2" class="data row0 col2" >32.553478</td>
#       <td id="T_282cd_row0_col3" class="data row0 col3" >34.000000</td>
#       <td id="T_282cd_row0_col4" class="data row0 col4" >18.820772</td>
#     </tr>
#     <tr>
#       <th id="T_282cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_282cd_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_282cd_row1_col1" class="data row1 col1" >116779</td>
#       <td id="T_282cd_row1_col2" class="data row1 col2" >30.290714</td>
#       <td id="T_282cd_row1_col3" class="data row1 col3" >31.700001</td>
#       <td id="T_282cd_row1_col4" class="data row1 col4" >18.181942</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:40 | INFO     | Checking normality of feature 'Daily_Commute_km' by groups of 'Will_Buy_EV'...
# 2026-09-03 18:22:40 | INFO     | Evaluating distribution characteristics (skewness & kurtosis)...
# 2026-09-03 18:22:40 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:40 | DEBUG    | Thresholds → |skew|≤0.5, |kurtosis|≤1.5
# 2026-09-03 18:22:41 | DEBUG    | [Will_Buy_EV=No] skew=-0.0993, kurtosis=-1.0422 → Approximately symmetric, Normal tails
# 2026-09-03 18:22:41 | DEBUG    | [Will_Buy_EV=Yes] skew=-0.0299, kurtosis=-1.1629 → Approximately symmetric, Normal tails
# 2026-09-03 18:22:41 | INFO     | Generating Q–Q plots for visual assessment...
# <style type="text/css">
# #T_75faf_row0_col2 {
#   background-color: #8484f8;
#   color: #f1f1f1;
# }
# #T_75faf_row0_col3 {
#   background-color: #ccccf5;
#   color: #000000;
# }
# #T_75faf_row1_col2 {
#   background-color: #7c7cf9;
#   color: #f1f1f1;
# }
# #T_75faf_row1_col3 {
#   background-color: #d6d6f4;
#   color: #000000;
# }
# </style>
# <table id="T_75faf" style="width:80%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Skewness & Kurtosis of Daily_Commute_km by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75faf_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_75faf_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_75faf_level0_col2" class="col_heading level0 col2" >Skewness</th>
#       <th id="T_75faf_level0_col3" class="col_heading level0 col3" >Kurtosis</th>
#       <th id="T_75faf_level0_col4" class="col_heading level0 col4" >Remark</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75faf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75faf_row0_col0" class="data row0 col0" >Daily_Commute_km</td>
#       <td id="T_75faf_row0_col1" class="data row0 col1" >No</td>
#       <td id="T_75faf_row0_col2" class="data row0 col2" >-0.0993</td>
#       <td id="T_75faf_row0_col3" class="data row0 col3" >-1.0422</td>
#       <td id="T_75faf_row0_col4" class="data row0 col4" >Approximately symmetric, Normal tails</td>
#     </tr>
#     <tr>
#       <th id="T_75faf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75faf_row1_col0" class="data row1 col0" >Daily_Commute_km</td>
#       <td id="T_75faf_row1_col1" class="data row1 col1" >Yes</td>
#       <td id="T_75faf_row1_col2" class="data row1 col2" >-0.0299</td>
#       <td id="T_75faf_row1_col3" class="data row1 col3" >-1.1629</td>
#       <td id="T_75faf_row1_col4" class="data row1 col4" >Approximately symmetric, Normal tails</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:43 | INFO     | All groups approximately follow a normal distribution.
# 2026-09-03 18:22:43 | INFO     | Check homogeneity of variances across groups using Levene’s test (median-centered)
# 2026-09-03 18:22:43 | DEBUG    | Number of groups detected: 2
# <style type="text/css">
# #T_fb421_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fb421_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fb421_row2_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_fb421" style="width:70%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Homogeneity of Variance — Daily_Commute_km by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb421_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_fb421_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb421_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb421_row0_col0" class="data row0 col0" >Levene’s Statistic</td>
#       <td id="T_fb421_row0_col1" class="data row0 col1" >82.6103</td>
#     </tr>
#     <tr>
#       <th id="T_fb421_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb421_row1_col0" class="data row1 col0" >p-value</td>
#       <td id="T_fb421_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fb421_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb421_row2_col0" class="data row2 col0" >Max/Min Variance Ratio</td>
#       <td id="T_fb421_row2_col1" class="data row2 col1" >1.07</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:43 | INFO     | Interpretation:
# 2026-09-03 18:22:43 | INFO     | - Status: Statistically different variances, but practical difference is small.
# 2026-09-03 18:22:43 | INFO     | - Recommendation: ANOVA or T-Test are acceptable, but Welch’s ANOVA or Welch’s T-Test is recommended.
# 2026-09-03 18:22:43 | INFO     | Running Independent Two-Sample T-Test: 'Daily_Commute_km' ~ 'Will_Buy_EV'
# 2026-09-03 18:22:43 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:43 | DEBUG    | Test Type: Welch’s T-Test (unequal variances)
# 2026-09-03 18:22:43 | INFO     | Comparing groups: 'No' vs 'Yes'
# 2026-09-03 18:22:43 | INFO     | p-value: 0.000000
# 2026-09-03 18:22:43 | INFO     | Cohen's d: 0.122
# 2026-09-03 18:22:43 | DEBUG    | t-statistic: 38.398
# 2026-09-03 18:22:43 | DEBUG    | Group means → No: 32.553, Yes: 30.291
# 2026-09-03 18:22:43 | INFO     | Result: p-value ≤ 0.05 → Reject H0
# 2026-09-03 18:22:43 | INFO     | Conclusion: Significant difference between the two groups.
# 2026-09-03 18:22:43 | INFO     | Effect size interpretation: small effect (|d| = 0.122)
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Charging_Stations_Near_Home by EV Purchase Decision</b></h2>
# <ul><li><b>Overall Mean:</b> 4.96</li><li><b>Overall Median:</b> 4.0</li><li><b>Overall Std:</b> 3.93</li></ul>
# <style type="text/css">
# #T_2b496_row0_col1, #T_2b496_row0_col2, #T_2b496_row1_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_2b496_row0_col3, #T_2b496_row0_col4, #T_2b496_row1_col1, #T_2b496_row1_col2, #T_2b496_row1_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_2b496" style="width:75%; margin:auto;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b496_level0_col0" class="col_heading level0 col0" >Will_Buy_EV</th>
#       <th id="T_2b496_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_2b496_level0_col2" class="col_heading level0 col2" >Mean</th>
#       <th id="T_2b496_level0_col3" class="col_heading level0 col3" >Median</th>
#       <th id="T_2b496_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b496_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b496_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_2b496_row0_col1" class="data row0 col1" >551886</td>
#       <td id="T_2b496_row0_col2" class="data row0 col2" >4.989947</td>
#       <td id="T_2b496_row0_col3" class="data row0 col3" >4.000000</td>
#       <td id="T_2b496_row0_col4" class="data row0 col4" >3.919259</td>
#     </tr>
#     <tr>
#       <th id="T_2b496_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b496_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_2b496_row1_col1" class="data row1 col1" >116779</td>
#       <td id="T_2b496_row1_col2" class="data row1 col2" >4.820807</td>
#       <td id="T_2b496_row1_col3" class="data row1 col3" >4.000000</td>
#       <td id="T_2b496_row1_col4" class="data row1 col4" >3.959525</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:47 | INFO     | Checking normality of feature 'Charging_Stations_Near_Home' by groups of 'Will_Buy_EV'...
# 2026-09-03 18:22:47 | INFO     | Evaluating distribution characteristics (skewness & kurtosis)...
# 2026-09-03 18:22:47 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:47 | DEBUG    | Thresholds → |skew|≤0.5, |kurtosis|≤1.5
# 2026-09-03 18:22:47 | DEBUG    | [Will_Buy_EV=No] skew=0.6897, kurtosis=-0.4864 → Moderately skewed, Normal tails
# 2026-09-03 18:22:47 | DEBUG    | [Will_Buy_EV=Yes] skew=0.7438, kurtosis=-0.4564 → Moderately skewed, Normal tails
# 2026-09-03 18:22:47 | INFO     | Generating Q–Q plots for visual assessment...
# <style type="text/css">
# #T_8b699_row0_col2 {
#   background-color: #2525fd;
#   color: #f1f1f1;
# }
# #T_8b699_row0_col3 {
#   background-color: #9f9ff7;
#   color: #f1f1f1;
# }
# #T_8b699_row1_col2 {
#   background-color: #1e1efd;
#   color: #f1f1f1;
# }
# #T_8b699_row1_col3 {
#   background-color: #9d9df7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b699" style="width:80%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Skewness & Kurtosis of Charging_Stations_Near_Home by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b699_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_8b699_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_8b699_level0_col2" class="col_heading level0 col2" >Skewness</th>
#       <th id="T_8b699_level0_col3" class="col_heading level0 col3" >Kurtosis</th>
#       <th id="T_8b699_level0_col4" class="col_heading level0 col4" >Remark</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b699_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b699_row0_col0" class="data row0 col0" >Charging_Stations_Near_Home</td>
#       <td id="T_8b699_row0_col1" class="data row0 col1" >No</td>
#       <td id="T_8b699_row0_col2" class="data row0 col2" >0.6897</td>
#       <td id="T_8b699_row0_col3" class="data row0 col3" >-0.4864</td>
#       <td id="T_8b699_row0_col4" class="data row0 col4" >Moderately skewed, Normal tails</td>
#     </tr>
#     <tr>
#       <th id="T_8b699_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b699_row1_col0" class="data row1 col0" >Charging_Stations_Near_Home</td>
#       <td id="T_8b699_row1_col1" class="data row1 col1" >Yes</td>
#       <td id="T_8b699_row1_col2" class="data row1 col2" >0.7438</td>
#       <td id="T_8b699_row1_col3" class="data row1 col3" >-0.4564</td>
#       <td id="T_8b699_row1_col4" class="data row1 col4" >Moderately skewed, Normal tails</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:49 | WARNING  | Normality assumption violated in at least one group.
# 2026-09-03 18:22:49 | INFO     | Recommendation: Use non-parametric tests (Kruskal–Wallis / Mann–Whitney U).
# 2026-09-03 18:22:49 | INFO     | Running Mann–Whitney U Test: 'Charging_Stations_Near_Home' by 'Will_Buy_EV'...
# 2026-09-03 18:22:49 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:49 | INFO     | U statistic: 33248197432.0
# 2026-09-03 18:22:49 | INFO     | p-value    : 0.000000
# 2026-09-03 18:22:52 | INFO     | Result: p-value ≤ 0.05 → Reject H0
# 2026-09-03 18:22:52 | INFO     | Conclusion: Significant difference between the two groups.
# 2026-09-03 18:22:52 | INFO     | Effect size (r): 0.0209
# 2026-09-03 18:22:52 | INFO     | Effect size interpretation: Negligible
# 2026-09-03 18:22:52 | INFO     | Cliff's Delta: -0.0318
# 2026-09-03 18:22:52 | INFO     | Effect size (Cliff's Delta) interpretation: Negligible
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Charging_Stations_Near_Work by EV Purchase Decision</b></h2>
# <ul><li><b>Overall Mean:</b> 7.18</li><li><b>Overall Median:</b> 6.0</li><li><b>Overall Std:</b> 5.19</li></ul>
# <style type="text/css">
# #T_77793_row0_col1, #T_77793_row0_col2, #T_77793_row1_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_77793_row0_col3, #T_77793_row0_col4, #T_77793_row1_col1, #T_77793_row1_col2, #T_77793_row1_col3 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_77793" style="width:75%; margin:auto;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77793_level0_col0" class="col_heading level0 col0" >Will_Buy_EV</th>
#       <th id="T_77793_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_77793_level0_col2" class="col_heading level0 col2" >Mean</th>
#       <th id="T_77793_level0_col3" class="col_heading level0 col3" >Median</th>
#       <th id="T_77793_level0_col4" class="col_heading level0 col4" >Std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77793_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77793_row0_col0" class="data row0 col0" >No</td>
#       <td id="T_77793_row0_col1" class="data row0 col1" >551886</td>
#       <td id="T_77793_row0_col2" class="data row0 col2" >7.205490</td>
#       <td id="T_77793_row0_col3" class="data row0 col3" >6.000000</td>
#       <td id="T_77793_row0_col4" class="data row0 col4" >5.185977</td>
#     </tr>
#     <tr>
#       <th id="T_77793_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77793_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_77793_row1_col1" class="data row1 col1" >116779</td>
#       <td id="T_77793_row1_col2" class="data row1 col2" >7.038432</td>
#       <td id="T_77793_row1_col3" class="data row1 col3" >6.000000</td>
#       <td id="T_77793_row1_col4" class="data row1 col4" >5.187498</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:55 | INFO     | Checking normality of feature 'Charging_Stations_Near_Work' by groups of 'Will_Buy_EV'...
# 2026-09-03 18:22:55 | INFO     | Evaluating distribution characteristics (skewness & kurtosis)...
# 2026-09-03 18:22:56 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:56 | DEBUG    | Thresholds → |skew|≤0.5, |kurtosis|≤1.5
# 2026-09-03 18:22:56 | DEBUG    | [Will_Buy_EV=No] skew=0.6944, kurtosis=-0.4975 → Moderately skewed, Normal tails
# 2026-09-03 18:22:56 | DEBUG    | [Will_Buy_EV=Yes] skew=0.7283, kurtosis=-0.4476 → Moderately skewed, Normal tails
# 2026-09-03 18:22:56 | INFO     | Generating Q–Q plots for visual assessment...
# <style type="text/css">
# #T_b45e4_row0_col2 {
#   background-color: #2525fd;
#   color: #f1f1f1;
# }
# #T_b45e4_row0_col3 {
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# #T_b45e4_row1_col2 {
#   background-color: #2020fd;
#   color: #f1f1f1;
# }
# #T_b45e4_row1_col3 {
#   background-color: #9d9df7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b45e4" style="width:80%; margin:auto;">
#   <caption><b><span style="font-size:14px; text-align:center; display:block;">Skewness & Kurtosis of Charging_Stations_Near_Work by Will_Buy_EV</span></b></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b45e4_level0_col0" class="col_heading level0 col0" >Feature</th>
#       <th id="T_b45e4_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_b45e4_level0_col2" class="col_heading level0 col2" >Skewness</th>
#       <th id="T_b45e4_level0_col3" class="col_heading level0 col3" >Kurtosis</th>
#       <th id="T_b45e4_level0_col4" class="col_heading level0 col4" >Remark</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b45e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b45e4_row0_col0" class="data row0 col0" >Charging_Stations_Near_Work</td>
#       <td id="T_b45e4_row0_col1" class="data row0 col1" >No</td>
#       <td id="T_b45e4_row0_col2" class="data row0 col2" >0.6944</td>
#       <td id="T_b45e4_row0_col3" class="data row0 col3" >-0.4975</td>
#       <td id="T_b45e4_row0_col4" class="data row0 col4" >Moderately skewed, Normal tails</td>
#     </tr>
#     <tr>
#       <th id="T_b45e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b45e4_row1_col0" class="data row1 col0" >Charging_Stations_Near_Work</td>
#       <td id="T_b45e4_row1_col1" class="data row1 col1" >Yes</td>
#       <td id="T_b45e4_row1_col2" class="data row1 col2" >0.7283</td>
#       <td id="T_b45e4_row1_col3" class="data row1 col3" >-0.4476</td>
#       <td id="T_b45e4_row1_col4" class="data row1 col4" >Moderately skewed, Normal tails</td>
#     </tr>
#   </tbody>
# </table>
# 2026-09-03 18:22:58 | WARNING  | Normality assumption violated in at least one group.
# 2026-09-03 18:22:58 | INFO     | Recommendation: Use non-parametric tests (Kruskal–Wallis / Mann–Whitney U).
# 2026-09-03 18:22:58 | INFO     | Running Mann–Whitney U Test: 'Charging_Stations_Near_Work' by 'Will_Buy_EV'...
# 2026-09-03 18:22:58 | DEBUG    | Number of groups detected: 2
# 2026-09-03 18:22:58 | INFO     | U statistic: 32908779219.5
# 2026-09-03 18:22:58 | INFO     | p-value    : 0.000000
# 2026-09-03 18:23:00 | INFO     | Result: p-value ≤ 0.05 → Reject H0
# 2026-09-03 18:23:00 | INFO     | Conclusion: Significant difference between the two groups.
# 2026-09-03 18:23:00 | INFO     | Effect size (r): 0.0140
# 2026-09-03 18:23:00 | INFO     | Effect size interpretation: Negligible
# 2026-09-03 18:23:00 | INFO     | Cliff's Delta: -0.0212
# 2026-09-03 18:23:00 | INFO     | Effect size (Cliff's Delta) interpretation: Negligible

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#fde68a;
#     margin:0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 📊 Numerical Features by EV Purchase Decision
# </div>
#
# <ul style="line-height:1.8; padding-left:20px;">
#
# <li><b>Age:</b> Age differs statistically between EV buyers and non-buyers (p &lt; 0.001), but the mean difference is only <b>~0.25 years</b> with a negligible effect size (Cohen’s d = <b>0.020</b>), suggesting that <b>age has limited practical impact on EV purchase decisions</b>.</li>
#
# <li><b>Annual_Income_USD:</b> Income differs significantly between the two groups (p &lt; 0.001), with EV buyers having substantially higher average income (<b>~$98,827 vs. ~$81,795</b>) and a large effect size (Cohen’s d = <b>0.624</b>), suggesting that <b>income is an important factor in EV purchase decisions</b>.</li>
#
# <li><b>Daily_Commute_km:</b> Daily commuting distance differs significantly (p &lt; 0.001), but the effect size is small (Cohen’s d = <b>0.122</b>); non-EV buyers have a slightly longer average commute (<b>~32.55 km vs. ~30.29 km</b>), suggesting that <b>Daily_Commute_km has limited practical impact on EV purchase decisions</b>.</li>
#
# <li><b>Charging_Stations_Near_Home:</b> The number of charging stations near home differs significantly between the two groups (p &lt; 0.001), but the effect size is negligible (r = <b>0.021</b>; Cliff’s δ = <b>-0.032</b>), suggesting <b>very limited practical impact on EV purchase decisions</b>.</li>
#
# <li><b>Charging_Stations_Near_Work:</b> The number of charging stations near work differs significantly between the two groups (p &lt; 0.001), but the effect size is negligible (r = <b>0.014</b>; Cliff’s δ = <b>-0.021</b>), suggesting <b>very limited practical impact on EV purchase decisions</b>.</li>
#
# </ul>
#
# </div>

# %%
for feature in cat_features:
    display(HTML(
        f"<h2 style='text-align:center; font-size:22px; color:#fde68a;'>"
        f"<b>Distribution of {feature.title()} by EV Purchase Decision</b>"
        f"</h2>"
    ))
    StatUtils.analyze_categorical_feature_vs_target(cat = feature, target_feature=CFG.TARGET_FEATURE,
                                                    logger=logger, df=df_plot)
# Out:
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Gender by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:05 | INFO     | Chi-Square Test of Independence: 'Gender' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:05 | INFO     | Chi-squared statistic: 33.041
# 2026-09-03 18:23:05 | INFO     | Degrees of freedom: 2
# 2026-09-03 18:23:05 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:05 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:05 | INFO     | Variables 'Gender' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:05 | DEBUG    | Displaying standardized residuals heatmap.
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of City_Type by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:07 | INFO     | Chi-Square Test of Independence: 'City_Type' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:07 | INFO     | Chi-squared statistic: 742.830
# 2026-09-03 18:23:07 | INFO     | Degrees of freedom: 2
# 2026-09-03 18:23:07 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:07 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:07 | INFO     | Variables 'City_Type' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:07 | DEBUG    | Displaying standardized residuals heatmap.
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Current_Car_Type by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:08 | INFO     | Chi-Square Test of Independence: 'Current_Car_Type' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:08 | INFO     | Chi-squared statistic: 173.663
# 2026-09-03 18:23:08 | INFO     | Degrees of freedom: 3
# 2026-09-03 18:23:08 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:08 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:08 | INFO     | Variables 'Current_Car_Type' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:08 | DEBUG    | Displaying standardized residuals heatmap.
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Home_Charging_Possible by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:09 | INFO     | Chi-Square Test of Independence: 'Home_Charging_Possible' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:09 | INFO     | Chi-squared statistic: 4671.041
# 2026-09-03 18:23:09 | INFO     | Degrees of freedom: 1
# 2026-09-03 18:23:09 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:09 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:09 | INFO     | Variables 'Home_Charging_Possible' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:09 | DEBUG    | Displaying standardized residuals heatmap.
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Subsidy_Available by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:11 | INFO     | Chi-Square Test of Independence: 'Subsidy_Available' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:11 | INFO     | Chi-squared statistic: 78382.500
# 2026-09-03 18:23:11 | INFO     | Degrees of freedom: 1
# 2026-09-03 18:23:11 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:11 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:11 | INFO     | Variables 'Subsidy_Available' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:11 | DEBUG    | Displaying standardized residuals heatmap.
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Environmental_Concern_Level by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:12 | INFO     | Chi-Square Test of Independence: 'Environmental_Concern_Level' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:12 | INFO     | Chi-squared statistic: 164867.872
# 2026-09-03 18:23:12 | INFO     | Degrees of freedom: 4
# 2026-09-03 18:23:12 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:12 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:12 | INFO     | Variables 'Environmental_Concern_Level' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:12 | DEBUG    | Displaying standardized residuals heatmap.
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Range_Anxiety_Level by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:14 | INFO     | Chi-Square Test of Independence: 'Range_Anxiety_Level' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:14 | INFO     | Chi-squared statistic: 8981.913
# 2026-09-03 18:23:14 | INFO     | Degrees of freedom: 2
# 2026-09-03 18:23:14 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:14 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:14 | INFO     | Variables 'Range_Anxiety_Level' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:14 | DEBUG    | Displaying standardized residuals heatmap.
# <h2 style='text-align:center; font-size:22px; color:#fde68a;'><b>Distribution of Number_Of_Cars_Owned by EV Purchase Decision</b></h2>
# 2026-09-03 18:23:15 | INFO     | Chi-Square Test of Independence: 'Number_of_Cars_Owned' vs. 'Will_Buy_EV'...
# 2026-09-03 18:23:15 | INFO     | Chi-squared statistic: 55.129
# 2026-09-03 18:23:15 | INFO     | Degrees of freedom: 3
# 2026-09-03 18:23:15 | INFO     | p-value: 0.000000
# 2026-09-03 18:23:15 | INFO     | Result: p-value < 0.05 → Reject H₀
# 2026-09-03 18:23:15 | INFO     | Variables 'Number_of_Cars_Owned' and 'Will_Buy_EV' are statistically associated.
# 2026-09-03 18:23:15 | DEBUG    | Displaying standardized residuals heatmap.

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#fde68a;
#     margin:0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 📊 Categorical Features by EV Purchase Decision
# </div>
#
# <ul style="line-height:1.8; padding-left:20px;">
#
# <li><b>Gender:</b> Significantly associated with EV purchase decisions (χ² = 33.04, p &lt; 0.001); <b>Female</b> shows higher-than-expected purchases, while <b>Male</b> is lower than expected.</li>
#
# <li><b>City_Type:</b> Significantly associated with EV purchase decisions (χ² = 742.83, p &lt; 0.001); <b>Rural and Suburban</b> show higher-than-expected purchases, while <b>Urban</b> is substantially lower than expected.</li>
#
# <li><b>Current_Car_Type:</b> Significantly associated with EV purchase decisions (χ² = 173.66, p &lt; 0.001); <b>SUV</b> shows higher-than-expected purchases, while <b>Truck</b> is substantially lower than expected.</li>
#
# <li><b>Home_Charging_Possible:</b> Strongly differentiated across purchase decisions (χ² = 4671.04, p &lt; 0.001); EV purchase rate increases from approximately <b>13% to 20%</b> when home charging is available.</li>
#
# <li><b>Subsidy_Available:</b> Shows a pronounced relationship with EV purchase decisions (χ² = 78,382.5, p &lt; 0.001); purchase rate rises sharply from approximately <b>1% without a subsidy to 27% with a subsidy</b>.</li>
#
# <li><b>Environmental_Concern_Level:</b> Shows a pronounced relationship with EV purchase decisions (χ² = 164,867.87, p &lt; 0.001); purchase rate increases sharply from approximately <b>1% at level 1 to 52% at level 5</b>, indicating a strong positive adoption pattern.</li>
#
# <li><b>Range_Anxiety_Level:</b> Significantly associated with EV purchase decisions (χ² = 8,981.91, p &lt; 0.001); purchase rate is highest for <b>Low</b> anxiety (~19%) and falls sharply for <b>Medium (~4%)</b> and <b>High (~0%)</b>.</li>
#
# <li><b>Number_of_Cars_Owned:</b> Significantly associated with EV purchase decisions (χ² = 55.13, p &lt; 0.001); consumers owning <b>2 cars</b> show higher-than-expected purchases, while <b>1 and 4 cars</b> are lower than expected.</li>
#
# <li><b>Overall:</b> Among the categorical variables, <code>Subsidy_Available</code>, <code>Environmental_Concern_Level</code>, <code>Home_Charging_Possible</code>, and <code>Range_Anxiety_Level</code> show the most pronounced differences in EV purchase rates across groups.</li>
#
# </ul>
#
# </div>

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Overall Picture</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#         background: linear-gradient(
#     135deg,
#     #003B5C,
#     #0077B6 35%,
#     #00B4D8 65%,
#     #2A9D8F 100%
# );
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Overall Picture
#     </h1>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #1f2a44, #2c3e50);
#     color: #ecf0f1;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 6px 18px rgba(0,0,0,0.25);
# ">
#
# <div style="
#     color:#f9e79f;
#     margin: 0 0 20px 0;
#     font-size:22px;
#     font-weight:600;
#     letter-spacing:0.5px;
# ">
# 🚗 Overall Picture
# </div>
#
# <table style="
#     width:100%;
#     border-collapse:collapse;
#     background-color:rgba(255,255,255,0.04);
#     font-size:14px;
# ">
#
# <tr style="background-color:rgba(249,231,159,0.15);">
#     <th style="padding:12px;border:1px solid #5d8a72;text-align:left;">Feature</th>
#     <th style="padding:12px;border:1px solid #5d8a72;text-align:left;">Key Insight</th>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;"><b>Age</b></td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Statistically different between buyers and non-buyers, but the effect is negligible; age has <b>limited practical impact</b> on EV purchase decisions.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#ff6b6b;">Annual Income</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# EV buyers have substantially higher income, with a <b>large effect size</b>; income is an <b>important factor</b> in EV purchase decisions.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#f9e79f;">Daily Commute</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Non-buyers commute slightly farther on average, but the effect is small, indicating <b>limited practical impact</b>.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b>Charging Stations Near Home</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Statistically different across groups, but the effect is negligible, suggesting <b>limited practical impact</b> on EV adoption.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b>Charging Stations Near Work</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Also statistically significant but with a negligible effect, indicating <b>limited practical impact</b>.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;"><b>Gender</b></td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Gender is significantly associated with EV purchase decisions, with <b>Female</b> purchases higher than expected and <b>Male</b> purchases lower than expected.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#f9e79f;">City Type</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# EV purchase patterns differ by residential area, with <b>Rural and Suburban</b> above expected levels and <b>Urban</b> below expected levels.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#f9e79f;">Current Car Type</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# SUV owners show higher-than-expected EV purchases, while <b>Truck</b> owners are substantially lower than expected.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#ff6b6b;">Home Charging Possible</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# EV purchase rates increase from approximately <b>13% to 20%</b> when home charging is possible, highlighting an <b>important adoption factor</b>.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#ff6b6b;">Subsidy Available</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Purchase rates rise sharply from approximately <b>1% to 27%</b> when subsidies are available, indicating a <b>major adoption driver</b>.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#ff6b6b;">Environmental Concern</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# EV purchase rates increase from approximately <b>1% at level 1 to 52% at level 5</b>, showing a <b>strong positive adoption pattern</b>.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b style="color:#ff6b6b;">Range Anxiety</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Purchase rates are highest for <b>Low</b> anxiety (~19%) and fall sharply for <b>Medium (~4%)</b> and <b>High (~0%)</b>, highlighting range anxiety as a <b>major adoption barrier</b>.
# </td>
# </tr>
#
# <tr>
# <td style="padding:10px;border:1px solid #5d8a72;">
# <b>Number of Cars Owned</b>
# </td>
# <td style="padding:10px;border:1px solid #5d8a72;">
# Ownership is significantly associated with EV adoption, with the <b>2-car group</b> above expected levels, while the overall differences are relatively modest.
# </td>
# </tr>
#
# </table>
#
# <div style="
#     margin-top:18px;
#     padding:12px 15px;
#     background-color:rgba(0,0,0,0.15);
#     border-radius:8px;
#     font-size:13px;
# ">
# <span style="color:#ff6b6b;"><b>● Strong practical relationship</b></span>
# &nbsp;&nbsp;|&nbsp;&nbsp;
# <span style="color:#f9e79f;"><b>● Moderate / noticeable relationship</b></span>
# &nbsp;&nbsp;|&nbsp;&nbsp;
# <span style="color:#ecf0f1;"><b>● Limited practical impact</b></span>
# </div>
#
# </div>

# %%
logger.info("=" * 80)
logger.info("DATA PREPROCESSING")
logger.info("=" * 80)

# Prepare Base Features
logger.info("Preparing base features...")
BASE = [
    c for c in df_train.columns
    if c not in [CFG.COLUMNS_TRAIN_TEST, CFG.TARGET_FEATURE, CFG.COLUMNS_ORIGINAL]
]

logger.info(
    f"Data loaded | "
    f"Train: {df_train.shape} | "
    f"Test: {df_test.shape} | "
    f"Original: {df_original.shape}"
)

logger.info(f"Base features: {len(BASE)}")
logger.debug(f"Base feature list: {BASE}")

# Combine Train + Original Dataset
logger.info("Combining train and original datasets...")

train_before = len(df_train)

df_train = pd.concat([df_train, df_original], ignore_index=True)
logger.info(
    f"Train dataset combined | "
    f"Rows: {train_before:,} -> {len(df_train):,}"
)

# Feature Engineering
logger.info("Starting feature engineering...")

for df_name, df in [("Train", df_train), ("Test", df_test)]:

    logger.info(f"[{df_name}] Creating engineered features...")

    df["Total_Charging_Stations"] = (
        df["Charging_Stations_Near_Home"]
        + df["Charging_Stations_Near_Work"]
    )

    df["Charging_Station_Difference"] = (
        df["Charging_Stations_Near_Work"]
        - df["Charging_Stations_Near_Home"]
    )

    df["Commute_per_Charging_Station"] = (
        df["Daily_Commute_km"]
        / (df["Total_Charging_Stations"] + 1)
    )

    df["Range_Anxiety_Score"] = (
        df["Range_Anxiety_Level"]
        .map({"Low": 1, "Medium": 2, "High": 3})
    )

    # Interaction:
    # Long commute + high range anxiety
    df["Range_Anxiety_Commute"] = (
        df["Range_Anxiety_Score"].astype("float32")
        * df["Daily_Commute_km"]
    )

    df["Home_Charging_Score"] = (
        df["Charging_Stations_Near_Home"]
        * df["Home_Charging_Possible"].eq("Yes").astype("int8")
    )

# Final Preprocessing Summary
logger.info("=" * 80)
logger.info("DATA PREPROCESSING COMPLETED")
logger.info("=" * 80)

logger.info(
    f"Final dataset shapes | "
    f"Train: {df_train.shape} | "
    f"Test: {df_test.shape}"
)

logger.info(f"Categorical features processed: {len(cat_features)}")
# Out:
# 2026-09-03 18:41:24 | INFO     | ================================================================================
# 2026-09-03 18:41:24 | INFO     | DATA PREPROCESSING
# 2026-09-03 18:41:24 | INFO     | ================================================================================
# 2026-09-03 18:41:24 | INFO     | Preparing base features...
# 2026-09-03 18:41:24 | INFO     | Data loaded | Train: (718665, 20) | Test: (286571, 13) | Original: (10000, 14)
# 2026-09-03 18:41:24 | INFO     | Base features: 19
# 2026-09-03 18:41:24 | DEBUG    | Base feature list: ['Age', 'Annual_Income_USD', 'Daily_Commute_km', 'Number_of_Cars_Owned', 'Charging_Stations_Near_Home', 'Charging_Stations_Near_Work', 'Environmental_Concern_Level', 'Gender', 'City_Type', 'Current_Car_Type', 'Home_Charging_Possible', 'Subsidy_Available', 'Range_Anxiety_Level', 'Total_Charging_Stations', 'Charging_Station_Difference', 'Commute_per_Charging_Station', 'Range_Anxiety_Score', 'Range_Anxiety_Commute', 'Home_Charging_Score']
# 2026-09-03 18:41:24 | INFO     | Combining train and original datasets...
# 2026-09-03 18:41:24 | INFO     | Train dataset combined | Rows: 718,665 -> 728,665
# 2026-09-03 18:41:24 | INFO     | Starting feature engineering...
# 2026-09-03 18:41:24 | INFO     | [Train] Creating engineered features...
# 2026-09-03 18:41:24 | INFO     | [Test] Creating engineered features...
# 2026-09-03 18:41:24 | INFO     | ================================================================================
# 2026-09-03 18:41:24 | INFO     | DATA PREPROCESSING COMPLETED
# 2026-09-03 18:41:24 | INFO     | ================================================================================
# 2026-09-03 18:41:24 | INFO     | Final dataset shapes | Train: (728665, 20) | Test: (286571, 19)
# 2026-09-03 18:41:24 | INFO     | Categorical features processed: 8

# %% [markdown]
# <!-- Include Google Fonts for a modern font -->
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@700&display=swap" rel="stylesheet">
#
# # <span style="color:transparent;">Modeling</span>
#
# <div style="
#     border-radius: 15px;
#     border: 2px solid #003366;
#     padding: 10px;
#         background: linear-gradient(
#     135deg,
#     #003B5C,
#     #0077B6 35%,
#     #00B4D8 65%,
#     #2A9D8F 100%
# );
#     text-align: center;
#     box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.5);
# ">
#     <h1 style="
#         color: #FFFFFF;
#         text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
#         font-weight: bold;
#         margin-bottom: 5px;
#         font-size: 28px;
#         font-family: 'Roboto', sans-serif;
#         letter-spacing: 1px;
#     ">
#         Modeling
#     </h1>
# </div>

# %%
# Training Data
X = df_train[FEATURES]
y = df_train[CFG.TARGET_FEATURE]
logger.info(f"X Shape: {X.shape}")
logger.info(f"y Shape: {y.shape}")

split = StratifiedShuffleSplit(n_splits=CFG.SPLIT["n_splits"], test_size=CFG.SPLIT["test_size"], 
                               random_state=CFG.RANDOM_STATE)

for train_idx, test_idx in split.split(X, y):
    X_train = X.iloc[train_idx]
    X_test = X.iloc[test_idx]
    y_train = y.iloc[train_idx]
    y_test = y.iloc[test_idx]
